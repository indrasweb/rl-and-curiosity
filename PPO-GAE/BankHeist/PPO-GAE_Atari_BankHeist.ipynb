# %%
# !pip install stable-baselines==2.9.0

# %%
import datetime
from time import time
from collections import deque

import numpy as np

import torch as T
from torch.autograd import Variable
import torch.nn as nn
from torch.distributions import Categorical
from torch.optim import Adam
from torch.optim.lr_scheduler import LambdaLR

from stable_baselines.common.misc_util import set_global_seeds
from stable_baselines.common.cmd_util import make_atari_env
from stable_baselines.common.vec_env import VecFrameStack, VecNormalize

from tqdm import trange
from google.colab import drive
from itertools import count

# %%
drive.mount('/content/gdrive')

# %%
ENV_NAME = 'BankHeistNoFrameskip-v4'
SAVE_PATH = '/content/gdrive/My Drive/PPO-GAE/'

TOTAL_FRAMES = 5e6    # 5 million frames
ROLLOUT_LENGTH = 128  # transitions in each rollout
NENV = 8              # parallel environments; increase to decorrolate batches
GAMMA = 0.99          # reward discounting coefficient
LAMBDA = 0.95         # GAE discounting coefficient
SEED = 420            # blaze it
MB_SPLIT = 4          # split minibatch into quarters for surrogate calculation
MB_EPOCHS = 4         # epochs per minibatch (4 weight updates on policy per mb)
CLIP = 0.2            # clip the surrogate objective so updates are not too big

STEPS_PER_ROLLOUT = ROLLOUT_LENGTH*NENV
TOTAL_UPDATES = int(TOTAL_FRAMES // STEPS_PER_ROLLOUT)
SPLIT_LEN = int(STEPS_PER_ROLLOUT//MB_SPLIT)
DEVICE = T.device('cuda' if T.cuda.is_available() else 'cpu')

set_global_seeds(SEED)

# %% [markdown]
# # Neural Net Definitions

# %%
def conv_size(net, in_shape):
    """ util for calculating flat output shape of a given net """
    x = Variable(T.rand(1, *in_shape))
    o = net(x)
    b = (-1, o.size(1), o.size(2), o.size(3))
    return b, o.data.view(1, -1).size(1)

# %%
class AC(nn.Module):
  
    def __init__(self, input_shape, num_actions):
        super().__init__()
        h, w, c = input_shape

        self.conv = nn.Sequential(
            nn.Conv2d(c, 32, 8, 4),
            nn.ReLU(True),
            nn.Conv2d(32, 64, 4, 2),
            nn.ReLU(True),
            nn.Conv2d(64, 64, 3, 1),
            nn.ReLU(True),
        )
        
        _, f = conv_size(self.conv, (c,h,w))
        self.backbone = nn.Sequential(self.conv, nn.Flatten())
        self.actor = nn.Linear(f, num_actions)
        self.critic = nn.Linear(f, 1)

    def forward(self, x):
        latent = self.backbone(x)
        return self.actor(latent), self.critic(latent)

# %% [markdown]
# # Logging utils

# %%
class Logger:

    def __init__(self, print_rate):
        self.log = {'ep_r':[], 'ep_l':[], 'loss':[], 'pgloss':[], 
                    'vloss':[], 'ent':[], 'cf':[]}
        self.n_ep = 0              # total games/episodes
        self.n_update = 1          # total weight updates
        self.n_frames = 0          # env steps (total from checkpoint)
        self.run_frames = 0        # env steps (for this run)
        self.max_rwd = -np.inf     # max rwd out of all games played
        self.start_time = time()   # time we started *this* run
        self.last_checkpoint = 0   # total_frames at last checkpoint
        self.print_rate = print_rate

    def eta(self):  # get hh:mm:ss left to train
        elapsed_time = time() - self.start_time
        frames_left = TOTAL_FRAMES - self.n_frames
        sec_per_frame = elapsed_time / self.n_frames
        sec_left = int(frames_left * sec_per_frame)
        eta_str = str(datetime.timedelta(seconds=sec_left))
        return eta_str

    def fps(self):  # get frames per second
        elapsed_time = time() - self.start_time
        fps = int(self.run_frames / elapsed_time)
        return fps

    def sma(self, x):  # simple moving average
        if len(x) == 0: return 'NaN'
        div = 200 if len(x) > 200 else len(x)
        return sum(list(zip(*x[-div:]))[-1])/div

    def print_log(self):
        fps = self.fps()
        eta = self.eta()
        print('-'*10, self.n_update, '/', TOTAL_UPDATES, '-'*10)
        print('Num Games:', self.n_ep)
        print('Num Frames:', self.n_frames)
        print('FPS:', fps)
        print('ETA:', eta)
        print('SMA Length:', self.sma(self.log['ep_l']))
        print('SMA Reward:', self.sma(self.log['ep_r']))
        print('SMA Entropy:', self.sma(self.log['ent']))
        print('SMA Clip %:', self.sma(self.log['cf']))
        print('SMA Loss:', self.sma(self.log['loss']))
        print('SMA PG Loss:', self.sma(self.log['pgloss']))
        print('SMA V Loss:', self.sma(self.log['vloss']))
        print('Max reward:', self.max_rwd)

    def record(self, ep, loss, pgloss, vloss, ent, cf):
        
        self.n_update += 1
        self.n_frames += STEPS_PER_ROLLOUT
        self.run_frames += STEPS_PER_ROLLOUT
        fr = (self.n_frames, self.n_update)

        # stats about finished episodes/games
        for l, r in zip(ep['l'], ep['r']):
            self.log['ep_l'].append(fr+(l,))
            self.log['ep_r'].append(fr+(r,))
            if r > self.max_rwd: self.max_rwd = r
            self.n_ep += 1
             
        # nn training statistics
        self.log['loss'].append(fr+(loss,))
        self.log['pgloss'].append(fr+(pgloss,))
        self.log['vloss'].append(fr+(vloss,))
        self.log['ent'].append(fr+(ent,))
        self.log['cf'].append(fr+(cf,))
        
        # print log
        if self.n_update % self.print_rate == 0:
            self.print_log()

# %% [markdown]
# # Rollout handling

# %%
def ob_to_torch(x):
    x = np.moveaxis(x, -1, 1)
    x = T.from_numpy(x).float()
    x = x.to(DEVICE)
    return x

# %%
def GAE(rwds, vals, next_val, dones=None):
    """ GAE lambda. vals is full batch, next_val is singular """
    returns = T.empty_like(rwds).to(DEVICE)
    if dones is None: dones = T.ones_like(rwds, dtype=T.bool)
    g = 0
    for i in reversed(range(ROLLOUT_LENGTH)):
        d = rwds[i] + (GAMMA * next_val * ~dones[i]) - vals[i]
        g = d + (GAMMA * LAMBDA * ~dones[i] * g)
        returns[i] = g + vals[i]
        next_val = vals[i]
    adv = returns - vals
    return returns, adv

# %%
def rollout_generator(env, policy):

    ob = ob_to_torch(env.reset())
    mb = {'obs':[], 'act':[], 'logp':[], 'rwd':[], 'done':[], 'val':[]}
    ep = {'l':[], 'r':[]}  # len & total reward of done eps 
    
    for step in count(1):

        # we compute gradients in the train loop
        with T.no_grad():
            logits, val = policy(ob)
            dist = Categorical(logits=logits)
            action = dist.sample()
            logp = dist.log_prob(action)
        
        new_ob, rwd, done, info = env.step(action)
        
        # store transition
        mb['obs'].append(ob)
        mb['act'].append(action)
        mb['logp'].append(logp)
        mb['rwd'].append(T.from_numpy(rwd))
        mb['val'].append(val.view(-1))
        mb['done'].append(T.from_numpy(done))
        for t in info:
            if t.get('episode'):
                ep['l'].append(t['episode']['l'])
                ep['r'].append(t['episode']['r'])

        ob = ob_to_torch(new_ob)

        if step % ROLLOUT_LENGTH != 0:
            continue

        ########################################################
        ###   Flatten rollout & assign credit w/ GAE         ###
        ########################################################

        for k in mb.keys():
            mb[k] = T.stack(mb[k]).to(DEVICE)

        # bootstap generalized advantages
        with T.no_grad():
            next_val = policy(ob)[1].view(-1) * ~mb['done'][-1]
            mb['rtn'], mb['gae'] = GAE(mb['rwd'], mb['val'], next_val, mb['done'])

        # flatten to (NENV*ROLLOUT_LENGTH, ...)
        for k in mb.keys():
            s = mb[k].size()
            mb[k] = mb[k].view(STEPS_PER_ROLLOUT, *s[2:])
        
        yield mb, ep
        mb = {'obs':[], 'act':[], 'logp':[], 'rwd':[], 'done':[], 'val':[]}
        ep = {'l':[], 'r':[]}

# %% [markdown]
# # Checkpoint loading and saving

# %%
def new_run():
    """ setup parallelised gym environments (MaxAndSkip=4 by default) """
    env = make_atari_env(ENV_NAME, num_env=NENV, seed=SEED)
    env._max_episode_steps = 4500*4
    env = VecFrameStack(env, n_stack=4)
    in_dim = env.observation_space.shape
    policy_dim = env.action_space.n

    # get actor + critic || learning rate is SO important (see README)
    ac = AC(in_dim, policy_dim).to(DEVICE)
    ac_optimizer = Adam(ac.parameters(), 1e-4, eps=1e-5)
    logger = Logger(15)

    return env, ac, ac_optimizer, logger

# %%
def save_checkpoint(checkpoint_id):
    checkpoint = {
        'ac': ac.state_dict(),
        'ac_opt': ac_optimizer.state_dict(),
        'logger': logger
    }
    X = str(checkpoint_id)
    T.save(checkpoint, SAVE_PATH+X+'.'+ENV_NAME+'.checkpoint')

# %%
def load_checkpoint(file_name):
    checkpoint = T.load(file_name, map_location=DEVICE)

    env = make_atari_env(ENV_NAME, num_env=NENV, seed=SEED)
    env = VecFrameStack(env, n_stack=4)
    in_dim = env.observation_space.shape
    policy_dim = env.action_space.n
    
    ac = AC(in_dim, policy_dim).to(DEVICE)
    ac.load_state_dict(checkpoint['ac'])
    ac_optimizer = Adam(ac.parameters())
    ac_optimizer.load_state_dict(checkpoint['ac_opt'])
    logger = checkpoint['logger']

    return env, ac, ac_optimizer, logger

# %% [markdown]
# # Load checkpoint or begin new run

# %%
# env, ac, ac_optimizer, logger = new_run()
env, ac, ac_optimizer, logger = load_checkpoint(SAVE_PATH+'3001344.BankHeistNoFrameskip-v4.checkpoint')

rollouts = rollout_generator(env, ac)
lr_scheduler = LambdaLR(ac_optimizer, lambda i: max(0.1, 1 - i/TOTAL_UPDATES))

# %% [markdown]
# # Train!

# %%
for i_update in range(logger.n_update, TOTAL_UPDATES):

    mb, ep = next(rollouts)
    
    # randomly split mb for surrogate calculation
    ixs = np.arange(STEPS_PER_ROLLOUT)
    
    # multiple updates using each minibatch
    for epoch in range(MB_EPOCHS):
        
        np.random.shuffle(ixs)
        
        for s in range(MB_SPLIT):

            # split minibatch into chunks
            ix = ixs[s*SPLIT_LEN:s*SPLIT_LEN+SPLIT_LEN]
            s_obs = mb['obs'][ix]        # observations (states)
            s_logp_old = mb['logp'][ix]  # log probs
            s_act = mb['act'][ix]        # actions
            s_rtn = mb['rtn'][ix]        # returns (not baselined)
            s_adv = mb['gae'][ix]        # generalized advantages

            # normalized split advantange
            s_adv = (s_adv - s_adv.mean()) / (s_adv.std() + 1e-8)

            # policy gradient + entropy
            logits, val = ac(s_obs)
            dist = Categorical(logits=logits)
            s_ent = dist.entropy().mean()
            s_logp_new = dist.log_prob(s_act)

            # surrogate loss (ratio == 1 on first iter, ln cancels)
            ratio = (s_logp_new - s_logp_old).exp() # e^x / e^x == e^(x-y)
            L_CPI = -s_adv * ratio
            L_CLAMP = -s_adv * ratio.clamp(1-CLIP, 1+CLIP)
            L_CLIP = T.max(L_CPI, L_CLAMP).mean()
            
            # fraction of clipped samples; ensure this is < ~0.15
            # whilst training, else your policy will collapse
            r = ratio.detach()
            clip_frac = ((r < 1-CLIP) | (r > 1+CLIP)).float().mean()
            
            # value loss
            V_L = 0.5 * (val - s_rtn).pow(2).mean()

            # step
            loss = L_CLIP + V_L - 0.01*s_ent
            ac_optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(ac.parameters(), 0.5)
            ac_optimizer.step()

    # decay lr and log training stats
    lr_scheduler.step(i_update)
    logger.record(ep, loss.item(), L_CLIP.item(), V_L.item(),
                  s_ent.item(), clip_frac.item())
    
    # make a checkpoint every 1m frames
    if logger.n_frames - logger.last_checkpoint >= 1e6:
        save_checkpoint(logger.n_frames)
        logger.last_checkpoint = logger.n_frames
# Out:
# ---------- 2940 / 4882 ----------
# Num Games: 4903
# Num Frames: 3009536
# FPS: 78
# ETA: 7:04:09
# SMA Length: 594.145
# SMA Reward: 105.25
# SMA Entropy: 1.246917884349823
# SMA Clip %: 0.178515625
# SMA Loss: 0.02839697285089642
# SMA PG Loss: -0.016685193767771125
# SMA V Loss: 0.05755134518258274
# Max reward: 220.0
# ---------- 2955 / 4882 ----------
# Num Games: 4933
# Num Frames: 3024896
# FPS: 78
# ETA: 6:59:11
# SMA Length: 588.935
# SMA Reward: 103.6
# SMA Entropy: 1.2617153015732765
# SMA Clip %: 0.178515625
# SMA Loss: 0.028112251036800442
# SMA PG Loss: -0.016726897694170476
# SMA V Loss: 0.0574563014972955
# Max reward: 220.0
# ---------- 2970 / 4882 ----------
# Num Games: 4958
# Num Frames: 3040256
# FPS: 78
# ETA: 6:54:14
# SMA Length: 590.71
# SMA Reward: 104.4
# SMA Entropy: 1.2790737909078598
# SMA Clip %: 0.17326171875
# SMA Loss: 0.02804039543494582
# SMA PG Loss: -0.016503343181684612
# SMA V Loss: 0.057334476234391335
# Max reward: 220.0
# ---------- 2985 / 4882 ----------
# Num Games: 4984
# Num Frames: 3055616
# FPS: 79
# ETA: 6:49:20
# SMA Length: 588.33
# SMA Reward: 105.7
# SMA Entropy: 1.2922001850605012
# SMA Clip %: 0.1715234375
# SMA Loss: 0.028450269275344907
# SMA PG Loss: -0.016486799516715108
# SMA V Loss: 0.057859070347622034
# Max reward: 220.0
# ---------- 3000 / 4882 ----------
# Num Games: 5010
# Num Frames: 3070976
# FPS: 79
# ETA: 6:44:29
# SMA Length: 588.485
# SMA Reward: 105.5
# SMA Entropy: 1.2968999773263932
# SMA Clip %: 0.16890625
# SMA Loss: 0.02832425312604755
# SMA PG Loss: -0.016652844101190566
# SMA V Loss: 0.05794609668664634
# Max reward: 220.0
# ---------- 3015 / 4882 ----------
# Num Games: 5035
# Num Frames: 3086336
# FPS: 79
# ETA: 6:39:37
# SMA Length: 590.12
# SMA Reward: 105.25
# SMA Entropy: 1.3067754554748534
# SMA Clip %: 0.1683984375
# SMA Loss: 0.028303496157750487
# SMA PG Loss: -0.01679041333962232
# SMA V Loss: 0.05816166373901069
# Max reward: 220.0
# ---------- 3030 / 4882 ----------
# Num Games: 5059
# Num Frames: 3101696
# FPS: 80
# ETA: 6:34:49
# SMA Length: 596.185
# SMA Reward: 105.55
# SMA Entropy: 1.3153040760755539
# SMA Clip %: 0.16818359375
# SMA Loss: 0.028092473996803164
# SMA PG Loss: -0.01686735958326608
# SMA V Loss: 0.05811287404038012
# Max reward: 220.0
# ---------- 3045 / 4882 ----------
# Num Games: 5086
# Num Frames: 3117056
# FPS: 80
# ETA: 6:30:05
# SMA Length: 600.42
# SMA Reward: 107.95
# SMA Entropy: 1.329305859208107
# SMA Clip %: 0.1696484375
# SMA Loss: 0.02822689187247306
# SMA PG Loss: -0.017084881393238903
# SMA V Loss: 0.05860483151860535
# Max reward: 220.0
# ---------- 3060 / 4882 ----------
# Num Games: 5110
# Num Frames: 3132416
# FPS: 80
# ETA: 6:25:24
# SMA Length: 606.12
# SMA Reward: 109.6
# SMA Entropy: 1.3375762820243835
# SMA Clip %: 0.17001953125
# SMA Loss: 0.02852570450399071
# SMA PG Loss: -0.01712594074662775
# SMA V Loss: 0.05902740769088268
# Max reward: 220.0
# ---------- 3075 / 4882 ----------
# Num Games: 5136
# Num Frames: 3147776
# FPS: 81
# ETA: 6:20:46
# SMA Length: 615.81
# SMA Reward: 111.05
# SMA Entropy: 1.34953547000885
# SMA Clip %: 0.16978515625
# SMA Loss: 0.028426649612374604
# SMA PG Loss: -0.0170152942603454
# SMA V Loss: 0.05893729817122221
# Max reward: 220.0
# ---------- 3090 / 4882 ----------
# Num Games: 5159
# Num Frames: 3163136
# FPS: 81
# ETA: 6:16:09
# SMA Length: 622.365
# SMA Reward: 111.75
# SMA Entropy: 1.3407897466421128
# SMA Clip %: 0.16822265625
# SMA Loss: 0.028943515820428728
# SMA PG Loss: -0.016893576178699733
# SMA V Loss: 0.059244989231228826
# Max reward: 220.0
# ---------- 3105 / 4882 ----------
# Num Games: 5185
# Num Frames: 3178496
# FPS: 81
# ETA: 6:11:35
# SMA Length: 622.145
# SMA Reward: 111.5
# SMA Entropy: 1.335254675745964
# SMA Clip %: 0.16841796875
# SMA Loss: 0.02953715164680034
# SMA PG Loss: -0.016930037147831173
# SMA V Loss: 0.05981973530724645
# Max reward: 220.0
# ---------- 3120 / 4882 ----------
# Num Games: 5211
# Num Frames: 3193856
# FPS: 82
# ETA: 6:07:03
# SMA Length: 625.55
# SMA Reward: 112.9
# SMA Entropy: 1.3235286211967467
# SMA Clip %: 0.1676171875
# SMA Loss: 0.02951342106796801
# SMA PG Loss: -0.01680799214867875
# SMA V Loss: 0.059556699134409426
# Max reward: 220.0
# ---------- 3135 / 4882 ----------
# Num Games: 5235
# Num Frames: 3209216
# FPS: 82
# ETA: 6:02:34
# SMA Length: 627.95
# SMA Reward: 114.3
# SMA Entropy: 1.3130743646621703
# SMA Clip %: 0.16607421875
# SMA Loss: 0.030004996336065234
# SMA PG Loss: -0.016790754727553578
# SMA V Loss: 0.059926494434475897
# Max reward: 220.0
# ---------- 3150 / 4882 ----------
# Num Games: 5259
# Num Frames: 3224576
# FPS: 82
# ETA: 5:58:07
# SMA Length: 625.15
# SMA Reward: 114.8
# SMA Entropy: 1.287352325618267
# SMA Clip %: 0.1627734375
# SMA Loss: 0.030566749814897775
# SMA PG Loss: -0.016458416131790728
# SMA V Loss: 0.05989868897013366
# Max reward: 220.0
# ---------- 3165 / 4882 ----------
# Num Games: 5286
# Num Frames: 3239936
# FPS: 82
# ETA: 5:53:42
# SMA Length: 624.715
# SMA Reward: 113.9
# SMA Entropy: 1.2907882863283158
# SMA Clip %: 0.16234375
# SMA Loss: 0.03103633174672723
# SMA PG Loss: -0.01655814176192507
# SMA V Loss: 0.06050235611386597
# Max reward: 220.0
# ---------- 3180 / 4882 ----------
# Num Games: 5312
# Num Frames: 3255296
# FPS: 83
# ETA: 5:49:18
# SMA Length: 621.77
# SMA Reward: 114.2
# SMA Entropy: 1.290710077881813
# SMA Clip %: 0.16419921875
# SMA Loss: 0.0308791732089594
# SMA PG Loss: -0.016491263785865157
# SMA V Loss: 0.06027753747068346
# Max reward: 220.0
# ---------- 3195 / 4882 ----------
# Num Games: 5338
# Num Frames: 3270656
# FPS: 83
# ETA: 5:44:57
# SMA Length: 616.42
# SMA Reward: 113.8
# SMA Entropy: 1.2984354627132415
# SMA Clip %: 0.16265625
# SMA Loss: 0.031026889267377556
# SMA PG Loss: -0.016521963702980428
# SMA V Loss: 0.060533207328990105
# Max reward: 220.0
# ---------- 3210 / 4882 ----------
# Num Games: 5362
# Num Frames: 3286016
# FPS: 83
# ETA: 5:40:38
# SMA Length: 612.855
# SMA Reward: 113.6
# SMA Entropy: 1.3009851792454719
# SMA Clip %: 0.1610546875
# SMA Loss: 0.03160361791495234
# SMA PG Loss: -0.01644781796494499
# SMA V Loss: 0.061061287401244044
# Max reward: 220.0
# ---------- 3225 / 4882 ----------
# Num Games: 5387
# Num Frames: 3301376
# FPS: 84
# ETA: 5:36:21
# SMA Length: 613.725
# SMA Reward: 113.25
# SMA Entropy: 1.2889444914460182
# SMA Clip %: 0.1613671875
# SMA Loss: 0.032716744942590595
# SMA PG Loss: -0.016260442298371345
# SMA V Loss: 0.06186663185246289
# Max reward: 220.0
# ---------- 3240 / 4882 ----------
# Num Games: 5414
# Num Frames: 3316736
# FPS: 84
# ETA: 5:32:06
# SMA Length: 610.975
# SMA Reward: 113.65
# SMA Entropy: 1.2841916313767434
# SMA Clip %: 0.15888671875
# SMA Loss: 0.03281611102633178
# SMA PG Loss: -0.016070499850902708
# SMA V Loss: 0.06172852692194283
# Max reward: 220.0
# ---------- 3255 / 4882 ----------
# Num Games: 5440
# Num Frames: 3332096
# FPS: 84
# ETA: 5:27:53
# SMA Length: 607.995
# SMA Reward: 113.05
# SMA Entropy: 1.283741508424282
# SMA Clip %: 0.15421875
# SMA Loss: 0.032884952686727045
# SMA PG Loss: -0.01604683047858998
# SMA V Loss: 0.061769198002293704
# Max reward: 220.0
# ---------- 3270 / 4882 ----------
# Num Games: 5466
# Num Frames: 3347456
# FPS: 85
# ETA: 5:23:41
# SMA Length: 606.995
# SMA Reward: 113.3
# SMA Entropy: 1.2682556819915771
# SMA Clip %: 0.15220703125
# SMA Loss: 0.03329051590990275
# SMA PG Loss: -0.016022538675460964
# SMA V Loss: 0.061995611181482675
# Max reward: 220.0
# ---------- 3285 / 4882 ----------
# Num Games: 5492
# Num Frames: 3362816
# FPS: 85
# ETA: 5:19:32
# SMA Length: 605.95
# SMA Reward: 113.55
# SMA Entropy: 1.258181192278862
# SMA Clip %: 0.1515625
# SMA Loss: 0.03396916147787124
# SMA PG Loss: -0.01600421074545011
# SMA V Loss: 0.06255518388934433
# Max reward: 220.0
# ---------- 3300 / 4882 ----------
# Num Games: 5519
# Num Frames: 3378176
# FPS: 85
# ETA: 5:15:24
# SMA Length: 605.11
# SMA Reward: 113.25
# SMA Entropy: 1.2577748692035675
# SMA Clip %: 0.153046875
# SMA Loss: 0.033241384127177295
# SMA PG Loss: -0.01626701672328636
# SMA V Loss: 0.06208614914678037
# Max reward: 220.0
# ---------- 3315 / 4882 ----------
# Num Games: 5544
# Num Frames: 3393536
# FPS: 86
# ETA: 5:11:16
# SMA Length: 605.21
# SMA Reward: 113.05
# SMA Entropy: 1.2654894882440566
# SMA Clip %: 0.15130859375
# SMA Loss: 0.033197582550346855
# SMA PG Loss: -0.01644747278187424
# SMA V Loss: 0.06229994979687035
# Max reward: 220.0
# ---------- 3330 / 4882 ----------
# Num Games: 5571
# Num Frames: 3408896
# FPS: 86
# ETA: 5:07:12
# SMA Length: 602.1
# SMA Reward: 113.05
# SMA Entropy: 1.2730243891477584
# SMA Clip %: 0.14921875
# SMA Loss: 0.033816639818251136
# SMA PG Loss: -0.01609438497107476
# SMA V Loss: 0.06264126828871668
# Max reward: 220.0
# ---------- 3345 / 4882 ----------
# Num Games: 5597
# Num Frames: 3424256
# FPS: 86
# ETA: 5:03:10
# SMA Length: 600.355
# SMA Reward: 113.6
# SMA Entropy: 1.2856813541054726
# SMA Clip %: 0.1484765625
# SMA Loss: 0.03469472055323422
# SMA PG Loss: -0.016521043132524938
# SMA V Loss: 0.06407257682643831
# Max reward: 220.0
# ---------- 3360 / 4882 ----------
# Num Games: 5623
# Num Frames: 3439616
# FPS: 86
# ETA: 4:59:10
# SMA Length: 603.13
# SMA Reward: 113.25
# SMA Entropy: 1.2877068990468978
# SMA Clip %: 0.15009765625
# SMA Loss: 0.03445534763857722
# SMA PG Loss: -0.016571039974223822
# SMA V Loss: 0.06390345623716712
# Max reward: 220.0
# ---------- 3375 / 4882 ----------
# Num Games: 5648
# Num Frames: 3454976
# FPS: 87
# ETA: 4:55:12
# SMA Length: 606.625
# SMA Reward: 114.2
# SMA Entropy: 1.28829345703125
# SMA Clip %: 0.15037109375
# SMA Loss: 0.03447754323482513
# SMA PG Loss: -0.016906937023159117
# SMA V Loss: 0.06426741445437073
# Max reward: 220.0
# ---------- 3390 / 4882 ----------
# Num Games: 5671
# Num Frames: 3470336
# FPS: 87
# ETA: 4:51:16
# SMA Length: 607.81
# SMA Reward: 115.7
# SMA Entropy: 1.273573079109192
# SMA Clip %: 0.15048828125
# SMA Loss: 0.03484081099741161
# SMA PG Loss: -0.01692480935016647
# SMA V Loss: 0.06450135076418519
# Max reward: 220.0
# ---------- 3405 / 4882 ----------
# Num Games: 5697
# Num Frames: 3485696
# FPS: 87
# ETA: 4:47:21
# SMA Length: 610.12
# SMA Reward: 117.35
# SMA Entropy: 1.262567281126976
# SMA Clip %: 0.14943359375
# SMA Loss: 0.035831804582849146
# SMA PG Loss: -0.016902448607143013
# SMA V Loss: 0.06535992562770844
# Max reward: 220.0
# ---------- 3420 / 4882 ----------
# Num Games: 5722
# Num Frames: 3501056
# FPS: 88
# ETA: 4:43:29
# SMA Length: 614.375
# SMA Reward: 118.5
# SMA Entropy: 1.26497214615345
# SMA Clip %: 0.14890625
# SMA Loss: 0.03570136477705091
# SMA PG Loss: -0.016978564902674406
# SMA V Loss: 0.06532965080812574
# Max reward: 220.0
# ---------- 3435 / 4882 ----------
# Num Games: 5746
# Num Frames: 3516416
# FPS: 88
# ETA: 4:39:38
# SMA Length: 618.745
# SMA Reward: 118.1
# SMA Entropy: 1.26457964271307
# SMA Clip %: 0.14875
# SMA Loss: 0.03460594340693206
# SMA PG Loss: -0.01719027112936601
# SMA V Loss: 0.06444201067090034
# Max reward: 220.0
# ---------- 3450 / 4882 ----------
# Num Games: 5772
# Num Frames: 3531776
# FPS: 88
# ETA: 4:35:49
# SMA Length: 619.19
# SMA Reward: 118.75
# SMA Entropy: 1.2557613238692285
# SMA Clip %: 0.1490625
# SMA Loss: 0.03510067093651742
# SMA PG Loss: -0.017337061592843383
# SMA V Loss: 0.06499534553848207
# Max reward: 220.0
# ---------- 3465 / 4882 ----------
# Num Games: 5798
# Num Frames: 3547136
# FPS: 89
# ETA: 4:32:01
# SMA Length: 621.545
# SMA Reward: 118.8
# SMA Entropy: 1.261756225824356
# SMA Clip %: 0.14921875
# SMA Loss: 0.035736693749204275
# SMA PG Loss: -0.017594067112077026
# SMA V Loss: 0.06594832285307348
# Max reward: 220.0
# ---------- 3480 / 4882 ----------
# Num Games: 5824
# Num Frames: 3562496
# FPS: 89
# ETA: 4:28:14
# SMA Length: 622.245
# SMA Reward: 119.8
# SMA Entropy: 1.281112409234047
# SMA Clip %: 0.14943359375
# SMA Loss: 0.03573540127836168
# SMA PG Loss: -0.01778215342434123
# SMA V Loss: 0.06632867847569286
# Max reward: 220.0
# ---------- 3495 / 4882 ----------
# Num Games: 5849
# Num Frames: 3577856
# FPS: 89
# ETA: 4:24:30
# SMA Length: 619.905
# SMA Reward: 118.1
# SMA Entropy: 1.2973726409673692
# SMA Clip %: 0.14763671875
# SMA Loss: 0.03497086113318801
# SMA PG Loss: -0.01766793891089037
# SMA V Loss: 0.06561252613551914
# Max reward: 220.0
# ---------- 3510 / 4882 ----------
# Num Games: 5874
# Num Frames: 3593216
# FPS: 89
# ETA: 4:20:47
# SMA Length: 617.56
# SMA Reward: 117.45
# SMA Entropy: 1.2910132831335068
# SMA Clip %: 0.14837890625
# SMA Loss: 0.035492289154790344
# SMA PG Loss: -0.01741761253448203
# SMA V Loss: 0.06582003426738084
# Max reward: 220.0
# ---------- 3525 / 4882 ----------
# Num Games: 5901
# Num Frames: 3608576
# FPS: 90
# ETA: 4:17:05
# SMA Length: 619.08
# SMA Reward: 117.4
# SMA Entropy: 1.2846803823113442
# SMA Clip %: 0.14787109375
# SMA Loss: 0.035218024840578434
# SMA PG Loss: -0.01761152777587995
# SMA V Loss: 0.06567635622806847
# Max reward: 220.0
# ---------- 3540 / 4882 ----------
# Num Games: 5927
# Num Frames: 3623936
# FPS: 90
# ETA: 4:13:25
# SMA Length: 614.44
# SMA Reward: 118.65
# SMA Entropy: 1.2748357987403869
# SMA Clip %: 0.147578125
# SMA Loss: 0.0358784662373364
# SMA PG Loss: -0.01746826571878046
# SMA V Loss: 0.06609508980996907
# Max reward: 220.0
# ---------- 3555 / 4882 ----------
# Num Games: 5949
# Num Frames: 3639296
# FPS: 90
# ETA: 4:09:47
# SMA Length: 619.02
# SMA Reward: 122.1
# SMA Entropy: 1.2666722372174264
# SMA Clip %: 0.1484765625
# SMA Loss: 0.03617652038577944
# SMA PG Loss: -0.01759710304904729
# SMA V Loss: 0.06644034571014344
# Max reward: 220.0
# ---------- 3570 / 4882 ----------
# Num Games: 5971
# Num Frames: 3654656
# FPS: 91
# ETA: 4:06:09
# SMA Length: 625.28
# SMA Reward: 123.5
# SMA Entropy: 1.252816279232502
# SMA Clip %: 0.14701171875
# SMA Loss: 0.03683488436974585
# SMA PG Loss: -0.017294984362088144
# SMA V Loss: 0.06665803144685924
# Max reward: 220.0
# ---------- 3585 / 4882 ----------
# Num Games: 5995
# Num Frames: 3670016
# FPS: 91
# ETA: 4:02:34
# SMA Length: 628.5
# SMA Reward: 123.65
# SMA Entropy: 1.2478409892320632
# SMA Clip %: 0.14666015625
# SMA Loss: 0.037239097263664006
# SMA PG Loss: -0.01707013278733939
# SMA V Loss: 0.06678763982839882
# Max reward: 220.0
# ---------- 3600 / 4882 ----------
# Num Games: 6021
# Num Frames: 3685376
# FPS: 91
# ETA: 3:58:59
# SMA Length: 629.425
# SMA Reward: 124.7
# SMA Entropy: 1.2423642018437386
# SMA Clip %: 0.14904296875
# SMA Loss: 0.037394891171716155
# SMA PG Loss: -0.01722453414928168
# SMA V Loss: 0.0670430672634393
# Max reward: 220.0
# ---------- 3615 / 4882 ----------
# Num Games: 6047
# Num Frames: 3700736
# FPS: 91
# ETA: 3:55:24
# SMA Length: 631.325
# SMA Reward: 127.85
# SMA Entropy: 1.2298819145560265
# SMA Clip %: 0.14830078125
# SMA Loss: 0.038173136059194805
# SMA PG Loss: -0.017046956187114118
# SMA V Loss: 0.06751891133375466
# Max reward: 220.0
# ---------- 3630 / 4882 ----------
# Num Games: 6073
# Num Frames: 3716096
# FPS: 92
# ETA: 3:51:51
# SMA Length: 633.215
# SMA Reward: 129.25
# SMA Entropy: 1.2085872754454612
# SMA Clip %: 0.14767578125
# SMA Loss: 0.040200820099562405
# SMA PG Loss: -0.01702614457346499
# SMA V Loss: 0.06931283735670149
# Max reward: 220.0
# ---------- 3645 / 4882 ----------
# Num Games: 6096
# Num Frames: 3731456
# FPS: 92
# ETA: 3:48:20
# SMA Length: 638.185
# SMA Reward: 130.85
# SMA Entropy: 1.2013233771920204
# SMA Clip %: 0.146484375
# SMA Loss: 0.04130989805329591
# SMA PG Loss: -0.016863383846357466
# SMA V Loss: 0.07018651562742889
# Max reward: 220.0
# ---------- 3660 / 4882 ----------
# Num Games: 6120
# Num Frames: 3746816
# FPS: 92
# ETA: 3:44:50
# SMA Length: 641.96
# SMA Reward: 132.4
# SMA Entropy: 1.194146076142788
# SMA Clip %: 0.14447265625
# SMA Loss: 0.04247187870088965
# SMA PG Loss: -0.016647695121355353
# SMA V Loss: 0.0710610345005989
# Max reward: 220.0
# ---------- 3675 / 4882 ----------
# Num Games: 6144
# Num Frames: 3762176
# FPS: 93
# ETA: 3:41:23
# SMA Length: 641.045
# SMA Reward: 132.35
# SMA Entropy: 1.174795050919056
# SMA Clip %: 0.14259765625
# SMA Loss: 0.0429759361455217
# SMA PG Loss: -0.01652457001619041
# SMA V Loss: 0.07124845661222935
# Max reward: 220.0
# ---------- 3690 / 4882 ----------
# Num Games: 6169
# Num Frames: 3777536
# FPS: 93
# ETA: 3:37:58
# SMA Length: 636.97
# SMA Reward: 132.05
# SMA Entropy: 1.1648122638463974
# SMA Clip %: 0.1417578125
# SMA Loss: 0.04452805297914893
# SMA PG Loss: -0.016539377830922602
# SMA V Loss: 0.07271555341780185
# Max reward: 220.0
# ---------- 3705 / 4882 ----------
# Num Games: 6193
# Num Frames: 3792896
# FPS: 93
# ETA: 3:34:34
# SMA Length: 633.065
# SMA Reward: 132.95
# SMA Entropy: 1.1506965035200118
# SMA Clip %: 0.13951171875
# SMA Loss: 0.045235895006917416
# SMA PG Loss: -0.01644411116372794
# SMA V Loss: 0.07318697115406395
# Max reward: 220.0
# ---------- 3720 / 4882 ----------
# Num Games: 6219
# Num Frames: 3808256
# FPS: 94
# ETA: 3:31:11
# SMA Length: 633.015
# SMA Reward: 132.1
# SMA Entropy: 1.1476470586657523
# SMA Clip %: 0.1396484375
# SMA Loss: 0.04587436724919826
# SMA PG Loss: -0.016357854986563326
# SMA V Loss: 0.07370869280770422
# Max reward: 220.0
# ---------- 3735 / 4882 ----------
# Num Games: 6244
# Num Frames: 3823616
# FPS: 94
# ETA: 3:27:50
# SMA Length: 636.26
# SMA Reward: 129.8
# SMA Entropy: 1.1396219474077225
# SMA Clip %: 0.13728515625
# SMA Loss: 0.04589476051274687
# SMA PG Loss: -0.016293822643347083
# SMA V Loss: 0.07358480252325535
# Max reward: 220.0
# ---------- 3750 / 4882 ----------
# Num Games: 6269
# Num Frames: 3838976
# FPS: 94
# ETA: 3:24:30
# SMA Length: 634.7
# SMA Reward: 128.45
# SMA Entropy: 1.1373554077744483
# SMA Clip %: 0.13552734375
# SMA Loss: 0.046021510814316574
# SMA PG Loss: -0.016122205327264966
# SMA V Loss: 0.07351727016270161
# Max reward: 220.0
# ---------- 3765 / 4882 ----------
# Num Games: 6293
# Num Frames: 3854336
# FPS: 94
# ETA: 3:21:11
# SMA Length: 631.59
# SMA Reward: 126.9
# SMA Entropy: 1.121804805099964
# SMA Clip %: 0.13326171875
# SMA Loss: 0.046879984899424014
# SMA PG Loss: -0.016009070510044694
# SMA V Loss: 0.07410710338503122
# Max reward: 220.0
# ---------- 3780 / 4882 ----------
# Num Games: 6319
# Num Frames: 3869696
# FPS: 95
# ETA: 3:17:54
# SMA Length: 628.765
# SMA Reward: 126.2
# SMA Entropy: 1.1041495189070702
# SMA Clip %: 0.13080078125
# SMA Loss: 0.04844338948372751
# SMA PG Loss: -0.015702256755903362
# SMA V Loss: 0.07518714139238
# Max reward: 220.0
# ---------- 3795 / 4882 ----------
# Num Games: 6343
# Num Frames: 3885056
# FPS: 95
# ETA: 3:14:38
# SMA Length: 624.82
# SMA Reward: 122.95
# SMA Entropy: 1.1019616931676866
# SMA Clip %: 0.1254296875
# SMA Loss: 0.0490059644728899
# SMA PG Loss: -0.015327683556824923
# SMA V Loss: 0.07535326497629286
# Max reward: 220.0
# ---------- 3810 / 4882 ----------
# Num Games: 6370
# Num Frames: 3900416
# FPS: 95
# ETA: 3:11:22
# SMA Length: 622.45
# SMA Reward: 123.05
# SMA Entropy: 1.111409876346588
# SMA Clip %: 0.1228125
# SMA Loss: 0.048795234998688104
# SMA PG Loss: -0.015095045263879002
# SMA V Loss: 0.07500437896698714
# Max reward: 220.0
# ---------- 3825 / 4882 ----------
# Num Games: 6395
# Num Frames: 3915776
# FPS: 96
# ETA: 3:08:09
# SMA Length: 619.29
# SMA Reward: 120.85
# SMA Entropy: 1.117527185380459
# SMA Clip %: 0.11927734375
# SMA Loss: 0.04846612391993403
# SMA PG Loss: -0.014976309267804027
# SMA V Loss: 0.07461770497262478
# Max reward: 220.0
# ---------- 3840 / 4882 ----------
# Num Games: 6420
# Num Frames: 3931136
# FPS: 96
# ETA: 3:04:56
# SMA Length: 618.395
# SMA Reward: 121.75
# SMA Entropy: 1.1189617559313774
# SMA Clip %: 0.11728515625
# SMA Loss: 0.047941976012662056
# SMA PG Loss: -0.01466826967196539
# SMA V Loss: 0.07379986310377717
# Max reward: 220.0
# ---------- 3855 / 4882 ----------
# Num Games: 6447
# Num Frames: 3946496
# FPS: 96
# ETA: 3:01:45
# SMA Length: 618.575
# SMA Reward: 124.1
# SMA Entropy: 1.1144735956192016
# SMA Clip %: 0.11611328125
# SMA Loss: 0.04851215375587344
# SMA PG Loss: -0.014297454894986003
# SMA V Loss: 0.07395434448495507
# Max reward: 220.0
# ---------- 3870 / 4882 ----------
# Num Games: 6470
# Num Frames: 3961856
# FPS: 96
# ETA: 2:58:34
# SMA Length: 621.595
# SMA Reward: 125.35
# SMA Entropy: 1.1023064562678337
# SMA Clip %: 0.1154296875
# SMA Loss: 0.048113880045711994
# SMA PG Loss: -0.014063164119143039
# SMA V Loss: 0.07320010866969824
# Max reward: 230.0
# ---------- 3885 / 4882 ----------
# Num Games: 6495
# Num Frames: 3977216
# FPS: 97
# ETA: 2:55:25
# SMA Length: 623.37
# SMA Reward: 126.75
# SMA Entropy: 1.0946951892971992
# SMA Clip %: 0.11451171875
# SMA Loss: 0.048054080959409474
# SMA PG Loss: -0.013918000392150133
# SMA V Loss: 0.07291903324425221
# Max reward: 230.0
# ---------- 3900 / 4882 ----------
# Num Games: 6521
# Num Frames: 3992576
# FPS: 97
# ETA: 2:52:17
# SMA Length: 621.2
# SMA Reward: 127.0
# SMA Entropy: 1.0993210011720658
# SMA Clip %: 0.1126953125
# SMA Loss: 0.047959184562787416
# SMA PG Loss: -0.013958288568537681
# SMA V Loss: 0.07291068309918046
# Max reward: 230.0
# ---------- 3915 / 4882 ----------
# Num Games: 6546
# Num Frames: 4007936
# FPS: 97
# ETA: 2:49:10
# SMA Length: 621.925
# SMA Reward: 128.45
# SMA Entropy: 1.0954966232180596
# SMA Clip %: 0.1103125
# SMA Loss: 0.047839117059484126
# SMA PG Loss: -0.013837575560901315
# SMA V Loss: 0.0726316587999463
# Max reward: 230.0
# ---------- 3930 / 4882 ----------
# Num Games: 6571
# Num Frames: 4023296
# FPS: 98
# ETA: 2:46:04
# SMA Length: 620.955
# SMA Reward: 127.4
# SMA Entropy: 1.1056236127018928
# SMA Clip %: 0.10693359375
# SMA Loss: 0.0483582225535065
# SMA PG Loss: -0.013667573246639222
# SMA V Loss: 0.07308203196153044
# Max reward: 230.0
# ---------- 3945 / 4882 ----------
# Num Games: 6595
# Num Frames: 4038656
# FPS: 98
# ETA: 2:42:58
# SMA Length: 626.78
# SMA Reward: 130.3
# SMA Entropy: 1.1041890808939934
# SMA Clip %: 0.1053125
# SMA Loss: 0.04865520872175694
# SMA PG Loss: -0.013648861751426012
# SMA V Loss: 0.07334596125409007
# Max reward: 230.0
# ---------- 3960 / 4882 ----------
# Num Games: 6621
# Num Frames: 4054016
# FPS: 98
# ETA: 2:39:54
# SMA Length: 628.03
# SMA Reward: 131.1
# SMA Entropy: 1.103122641146183
# SMA Clip %: 0.10357421875
# SMA Loss: 0.0487872926145792
# SMA PG Loss: -0.013529950033407658
# SMA V Loss: 0.07334846897050738
# Max reward: 230.0
# ---------- 3975 / 4882 ----------
# Num Games: 6645
# Num Frames: 4069376
# FPS: 98
# ETA: 2:36:52
# SMA Length: 628.105
# SMA Reward: 131.55
# SMA Entropy: 1.1064167359471322
# SMA Clip %: 0.10150390625
# SMA Loss: 0.048896298799663784
# SMA PG Loss: -0.013428915005642921
# SMA V Loss: 0.07338938105851411
# Max reward: 230.0
# ---------- 3990 / 4882 ----------
# Num Games: 6670
# Num Frames: 4084736
# FPS: 99
# ETA: 2:33:50
# SMA Length: 625.88
# SMA Reward: 132.4
# SMA Entropy: 1.1042705643177033
# SMA Clip %: 0.1022265625
# SMA Loss: 0.04907989410683513
# SMA PG Loss: -0.013706818337086589
# SMA V Loss: 0.07382941791787744
# Max reward: 230.0
# ---------- 4005 / 4882 ----------
# Num Games: 6696
# Num Frames: 4100096
# FPS: 99
# ETA: 2:30:50
# SMA Length: 622.105
# SMA Reward: 130.95
# SMA Entropy: 1.097702813744545
# SMA Clip %: 0.10404296875
# SMA Loss: 0.04879282170906663
# SMA PG Loss: -0.013801367485430092
# SMA V Loss: 0.07357121709734202
# Max reward: 230.0
# ---------- 4020 / 4882 ----------
# Num Games: 6719
# Num Frames: 4115456
# FPS: 99
# ETA: 2:27:51
# SMA Length: 623.26
# SMA Reward: 130.0
# SMA Entropy: 1.0953565227985382
# SMA Clip %: 0.10310546875
# SMA Loss: 0.04897458205930889
# SMA PG Loss: -0.013502188536804169
# SMA V Loss: 0.07343033559620381
# Max reward: 230.0
# ---------- 4035 / 4882 ----------
# Num Games: 6746
# Num Frames: 4130816
# FPS: 99
# ETA: 2:24:53
# SMA Length: 622.79
# SMA Reward: 130.0
# SMA Entropy: 1.0981889599561692
# SMA Clip %: 0.10064453125
# SMA Loss: 0.049328873669728636
# SMA PG Loss: -0.013372195416595787
# SMA V Loss: 0.07368295842781664
# Max reward: 230.0
# ---------- 4050 / 4882 ----------
# Num Games: 6772
# Num Frames: 4146176
# FPS: 100
# ETA: 2:21:56
# SMA Length: 623.15
# SMA Reward: 130.45
# SMA Entropy: 1.1081793370842934
# SMA Clip %: 0.0987890625
# SMA Loss: 0.04934949242509901
# SMA PG Loss: -0.013249695380218328
# SMA V Loss: 0.07368098095059394
# Max reward: 230.0
# ---------- 4065 / 4882 ----------
# Num Games: 6799
# Num Frames: 4161536
# FPS: 100
# ETA: 2:19:00
# SMA Length: 616.21
# SMA Reward: 129.75
# SMA Entropy: 1.1103771817684174
# SMA Clip %: 0.09603515625
# SMA Loss: 0.050318614160642025
# SMA PG Loss: -0.013233035674784333
# SMA V Loss: 0.07465542145073414
# Max reward: 230.0
# ---------- 4080 / 4882 ----------
# Num Games: 6823
# Num Frames: 4176896
# FPS: 100
# ETA: 2:16:05
# SMA Length: 615.585
# SMA Reward: 128.1
# SMA Entropy: 1.1113145077228546
# SMA Clip %: 0.094609375
# SMA Loss: 0.050245503624901176
# SMA PG Loss: -0.013195592092815787
# SMA V Loss: 0.07455424048006534
# Max reward: 230.0
# ---------- 4095 / 4882 ----------
# Num Games: 6848
# Num Frames: 4192256
# FPS: 101
# ETA: 2:13:11
# SMA Length: 614.5
# SMA Reward: 127.95
# SMA Entropy: 1.0954717960953713
# SMA Clip %: 0.092734375
# SMA Loss: 0.050803597895428536
# SMA PG Loss: -0.012802775020245462
# SMA V Loss: 0.07456109063699841
# Max reward: 230.0
# ---------- 4110 / 4882 ----------
# Num Games: 6876
# Num Frames: 4207616
# FPS: 101
# ETA: 2:10:18
# SMA Length: 612.69
# SMA Reward: 127.4
# SMA Entropy: 1.087377719283104
# SMA Clip %: 0.092578125
# SMA Loss: 0.05198169715702534
# SMA PG Loss: -0.01263132679508999
# SMA V Loss: 0.07548680085688829
# Max reward: 230.0
# ---------- 4125 / 4882 ----------
# Num Games: 6901
# Num Frames: 4222976
# FPS: 101
# ETA: 2:07:26
# SMA Length: 614.43
# SMA Reward: 128.6
# SMA Entropy: 1.0745294666290284
# SMA Clip %: 0.09166015625
# SMA Loss: 0.052956988457590344
# SMA PG Loss: -0.012668532023672014
# SMA V Loss: 0.07637081481516361
# Max reward: 230.0
# ---------- 4140 / 4882 ----------
# Num Games: 6924
# Num Frames: 4238336
# FPS: 101
# ETA: 2:04:34
# SMA Length: 614.73
# SMA Reward: 130.0
# SMA Entropy: 1.0759355917572975
# SMA Clip %: 0.08953125
# SMA Loss: 0.05275024206377566
# SMA PG Loss: -0.012409038066398353
# SMA V Loss: 0.07591863565146922
# Max reward: 230.0
# ---------- 4155 / 4882 ----------
# Num Games: 6948
# Num Frames: 4253696
# FPS: 102
# ETA: 2:01:44
# SMA Length: 617.39
# SMA Reward: 131.7
# SMA Entropy: 1.075252620279789
# SMA Clip %: 0.0870703125
# SMA Loss: 0.05335551192052662
# SMA PG Loss: -0.012177125045564025
# SMA V Loss: 0.07628516290336847
# Max reward: 230.0
# ---------- 4170 / 4882 ----------
# Num Games: 6974
# Num Frames: 4269056
# FPS: 102
# ETA: 1:58:55
# SMA Length: 620.695
# SMA Reward: 131.45
# SMA Entropy: 1.081530494093895
# SMA Clip %: 0.08419921875
# SMA Loss: 0.052907102182507514
# SMA PG Loss: -0.012135565259959548
# SMA V Loss: 0.0758579720556736
# Max reward: 230.0
# ---------- 4185 / 4882 ----------
# Num Games: 6999
# Num Frames: 4284416
# FPS: 102
# ETA: 1:56:06
# SMA Length: 621.01
# SMA Reward: 130.5
# SMA Entropy: 1.0950698053836823
# SMA Clip %: 0.0803125
# SMA Loss: 0.05290991246700287
# SMA PG Loss: -0.011842985565308481
# SMA V Loss: 0.07570359576493502
# Max reward: 230.0
# ---------- 4200 / 4882 ----------
# Num Games: 7026
# Num Frames: 4299776
# FPS: 102
# ETA: 1:53:19
# SMA Length: 616.915
# SMA Reward: 131.55
# SMA Entropy: 1.1039619413018227
# SMA Clip %: 0.07451171875
# SMA Loss: 0.05346499690786004
# SMA PG Loss: -0.011444028436671942
# SMA V Loss: 0.07594864441081882
# Max reward: 230.0
# ---------- 4215 / 4882 ----------
# Num Games: 7053
# Num Frames: 4315136
# FPS: 103
# ETA: 1:50:32
# SMA Length: 613.05
# SMA Reward: 130.65
# SMA Entropy: 1.105979319512844
# SMA Clip %: 0.071015625
# SMA Loss: 0.054121997272595763
# SMA PG Loss: -0.011377331169787794
# SMA V Loss: 0.0765591213479638
# Max reward: 230.0
# ---------- 4230 / 4882 ----------
# Num Games: 7079
# Num Frames: 4330496
# FPS: 103
# ETA: 1:47:46
# SMA Length: 610.22
# SMA Reward: 129.65
# SMA Entropy: 1.1126844468712807
# SMA Clip %: 0.06994140625
# SMA Loss: 0.05464047062210739
# SMA PG Loss: -0.011238356037065387
# SMA V Loss: 0.0770056708343327
# Max reward: 230.0
# ---------- 4245 / 4882 ----------
# Num Games: 7107
# Num Frames: 4345856
# FPS: 103
# ETA: 1:45:01
# SMA Length: 609.105
# SMA Reward: 129.5
# SMA Entropy: 1.1161185613274573
# SMA Clip %: 0.06787109375
# SMA Loss: 0.05460994394496083
# SMA PG Loss: -0.011128114233724774
# SMA V Loss: 0.07689924350008369
# Max reward: 230.0
# ---------- 4260 / 4882 ----------
# Num Games: 7133
# Num Frames: 4361216
# FPS: 104
# ETA: 1:42:17
# SMA Length: 602.455
# SMA Reward: 127.5
# SMA Entropy: 1.134528430402279
# SMA Clip %: 0.0658203125
# SMA Loss: 0.05451952402479947
# SMA PG Loss: -0.01104214102262631
# SMA V Loss: 0.07690694900229574
# Max reward: 230.0
# ---------- 4275 / 4882 ----------
# Num Games: 7159
# Num Frames: 4376576
# FPS: 104
# ETA: 1:39:34
# SMA Length: 595.95
# SMA Reward: 127.5
# SMA Entropy: 1.1454040291905403
# SMA Clip %: 0.063046875
# SMA Loss: 0.05542997620999813
# SMA PG Loss: -0.010839548937510698
# SMA V Loss: 0.07772356500849127
# Max reward: 230.0
# ---------- 4290 / 4882 ----------
# Num Games: 7184
# Num Frames: 4391936
# FPS: 104
# ETA: 1:36:52
# SMA Length: 595.175
# SMA Reward: 128.75
# SMA Entropy: 1.1548392155766487
# SMA Clip %: 0.060625
# SMA Loss: 0.05577669229358435
# SMA PG Loss: -0.010556907441932708
# SMA V Loss: 0.07788199150934816
# Max reward: 230.0
# ---------- 4305 / 4882 ----------
# Num Games: 7208
# Num Frames: 4407296
# FPS: 104
# ETA: 1:34:10
# SMA Length: 602.815
# SMA Reward: 130.05
# SMA Entropy: 1.1708945420384407
# SMA Clip %: 0.0564453125
# SMA Loss: 0.05512674728408456
# SMA PG Loss: -0.010340818522963672
# SMA V Loss: 0.07717651078477501
# Max reward: 230.0
# ---------- 4320 / 4882 ----------
# Num Games: 7233
# Num Frames: 4422656
# FPS: 105
# ETA: 1:31:30
# SMA Length: 602.62
# SMA Reward: 130.25
# SMA Entropy: 1.1939299896359443
# SMA Clip %: 0.0525390625
# SMA Loss: 0.054590575443580744
# SMA PG Loss: -0.009966981953475625
# SMA V Loss: 0.07649685690179467
# Max reward: 230.0
# ---------- 4335 / 4882 ----------
# Num Games: 7258
# Num Frames: 4438016
# FPS: 105
# ETA: 1:28:50
# SMA Length: 606.06
# SMA Reward: 130.35
# SMA Entropy: 1.2098528665304185
# SMA Clip %: 0.0493359375
# SMA Loss: 0.0550105329696089
# SMA PG Loss: -0.009654216209892184
# SMA V Loss: 0.0767632775194943
# Max reward: 230.0
# ---------- 4350 / 4882 ----------
# Num Games: 7284
# Num Frames: 4453376
# FPS: 105
# ETA: 1:26:12
# SMA Length: 608.335
# SMA Reward: 129.1
# SMA Entropy: 1.2254671534895898
# SMA Clip %: 0.04763671875
# SMA Loss: 0.05426722470670939
# SMA PG Loss: -0.009399226906243712
# SMA V Loss: 0.07592112265527248
# Max reward: 230.0
# ---------- 4365 / 4882 ----------
# Num Games: 7313
# Num Frames: 4468736
# FPS: 105
# ETA: 1:23:34
# SMA Length: 605.36
# SMA Reward: 128.5
# SMA Entropy: 1.245820486843586
# SMA Clip %: 0.0451171875
# SMA Loss: 0.05467091857455671
# SMA PG Loss: -0.00925892072962597
# SMA V Loss: 0.0763880436308682
# Max reward: 230.0
# ---------- 4380 / 4882 ----------
# Num Games: 7338
# Num Frames: 4484096
# FPS: 106
# ETA: 1:20:57
# SMA Length: 609.805
# SMA Reward: 126.2
# SMA Entropy: 1.2465160113573075
# SMA Clip %: 0.04322265625
# SMA Loss: 0.054116916144266725
# SMA PG Loss: -0.008958963092882187
# SMA V Loss: 0.07554103882983326
# Max reward: 230.0
# ---------- 4395 / 4882 ----------
# Num Games: 7363
# Num Frames: 4499456
# FPS: 106
# ETA: 1:18:21
# SMA Length: 612.41
# SMA Reward: 125.15
# SMA Entropy: 1.2528464674949646
# SMA Clip %: 0.0414453125
# SMA Loss: 0.05382680146954954
# SMA PG Loss: -0.008723974234890193
# SMA V Loss: 0.07507923986762761
# Max reward: 230.0
# ---------- 4410 / 4882 ----------
# Num Games: 7388
# Num Frames: 4514816
# FPS: 106
# ETA: 1:15:45
# SMA Length: 614.12
# SMA Reward: 125.45
# SMA Entropy: 1.2465897765755654
# SMA Clip %: 0.040234375
# SMA Loss: 0.05378414386883378
# SMA PG Loss: -0.00844363511307165
# SMA V Loss: 0.07469367621466518
# Max reward: 230.0
# ---------- 4425 / 4882 ----------
# Num Games: 7412
# Num Frames: 4530176
# FPS: 106
# ETA: 1:13:10
# SMA Length: 612.37
# SMA Reward: 125.5
# SMA Entropy: 1.244183192551136
# SMA Clip %: 0.03990234375
# SMA Loss: 0.05362396444194019
# SMA PG Loss: -0.008338254196569323
# SMA V Loss: 0.07440405005589128
# Max reward: 230.0
# ---------- 4440 / 4882 ----------
# Num Games: 7437
# Num Frames: 4545536
# FPS: 107
# ETA: 1:10:37
# SMA Length: 611.595
# SMA Reward: 124.35
# SMA Entropy: 1.2397546735405922
# SMA Clip %: 0.0376953125
# SMA Loss: 0.05431657399982214
# SMA PG Loss: -0.008105030776932835
# SMA V Loss: 0.07481915099546313
# Max reward: 230.0
# ---------- 4455 / 4882 ----------
# Num Games: 7461
# Num Frames: 4560896
# FPS: 107
# ETA: 1:08:03
# SMA Length: 612.08
# SMA Reward: 120.7
# SMA Entropy: 1.2329409182071687
# SMA Clip %: 0.0364453125
# SMA Loss: 0.0530959015712142
# SMA PG Loss: -0.007918904218822718
# SMA V Loss: 0.07334421455860138
# Max reward: 230.0
# ---------- 4470 / 4882 ----------
# Num Games: 7488
# Num Frames: 4576256
# FPS: 107
# ETA: 1:05:31
# SMA Length: 618.015
# SMA Reward: 119.55
# SMA Entropy: 1.2299925893545152
# SMA Clip %: 0.03564453125
# SMA Loss: 0.05302855945192277
# SMA PG Loss: -0.007765179690904915
# SMA V Loss: 0.07309366459026932
# Max reward: 230.0
# ---------- 4485 / 4882 ----------
# Num Games: 7511
# Num Frames: 4591616
# FPS: 108
# ETA: 1:02:59
# SMA Length: 627.675
# SMA Reward: 116.85
# SMA Entropy: 1.2343605697154998
# SMA Clip %: 0.03513671875
# SMA Loss: 0.051276857694610954
# SMA PG Loss: -0.0077043581055477265
# SMA V Loss: 0.07132482102140784
# Max reward: 230.0
# ---------- 4500 / 4882 ----------
# Num Games: 7537
# Num Frames: 4606976
# FPS: 108
# ETA: 1:00:28
# SMA Length: 626.245
# SMA Reward: 114.85
# SMA Entropy: 1.2497584310173988
# SMA Clip %: 0.0335546875
# SMA Loss: 0.05030999790877104
# SMA PG Loss: -0.007628168507944792
# SMA V Loss: 0.07043575037270784
# Max reward: 230.0
# ---------- 4515 / 4882 ----------
# Num Games: 7562
# Num Frames: 4622336
# FPS: 108
# ETA: 0:57:58
# SMA Length: 630.245
# SMA Reward: 114.65
# SMA Entropy: 1.2466325920820236
# SMA Clip %: 0.03306640625
# SMA Loss: 0.05017086303792894
# SMA PG Loss: -0.007670291606336832
# SMA V Loss: 0.07030748013406991
# Max reward: 230.0
# ---------- 4530 / 4882 ----------
# Num Games: 7586
# Num Frames: 4637696
# FPS: 108
# ETA: 0:55:28
# SMA Length: 628.135
# SMA Reward: 113.05
# SMA Entropy: 1.2404204833507537
# SMA Clip %: 0.03380859375
# SMA Loss: 0.04955669675953686
# SMA PG Loss: -0.007867475217208266
# SMA V Loss: 0.06982837632298469
# Max reward: 230.0
# ---------- 4545 / 4882 ----------
# Num Games: 7612
# Num Frames: 4653056
# FPS: 109
# ETA: 0:52:59
# SMA Length: 626.325
# SMA Reward: 112.7
# SMA Entropy: 1.2351543736457824
# SMA Clip %: 0.03314453125
# SMA Loss: 0.05002871003001928
# SMA PG Loss: -0.007892460920847952
# SMA V Loss: 0.0702727142162621
# Max reward: 230.0
# ---------- 4560 / 4882 ----------
# Num Games: 7637
# Num Frames: 4668416
# FPS: 109
# ETA: 0:50:31
# SMA Length: 629.205
# SMA Reward: 114.55
# SMA Entropy: 1.231111975312233
# SMA Clip %: 0.0329296875
# SMA Loss: 0.05016752154566348
# SMA PG Loss: -0.00782318194862455
# SMA V Loss: 0.07030182287096977
# Max reward: 230.0
# ---------- 4575 / 4882 ----------
# Num Games: 7663
# Num Frames: 4683776
# FPS: 109
# ETA: 0:48:04
# SMA Length: 628.215
# SMA Reward: 117.35
# SMA Entropy: 1.2334874665737152
# SMA Clip %: 0.03283203125
# SMA Loss: 0.05073902799747884
# SMA PG Loss: -0.007687950513791293
# SMA V Loss: 0.07076185282319784
# Max reward: 230.0
# ---------- 4590 / 4882 ----------
# Num Games: 7687
# Num Frames: 4699136
# FPS: 109
# ETA: 0:45:38
# SMA Length: 625.205
# SMA Reward: 119.35
# SMA Entropy: 1.237815721333027
# SMA Clip %: 0.0330078125
# SMA Loss: 0.05156628438271582
# SMA PG Loss: -0.007763814234640449
# SMA V Loss: 0.07170825548470021
# Max reward: 230.0
# ---------- 4605 / 4882 ----------
# Num Games: 7711
# Num Frames: 4714496
# FPS: 110
# ETA: 0:43:12
# SMA Length: 622.16
# SMA Reward: 123.7
# SMA Entropy: 1.2515351775288581
# SMA Clip %: 0.03330078125
# SMA Loss: 0.05153399556875229
# SMA PG Loss: -0.007764988571871072
# SMA V Loss: 0.0718143356218934
# Max reward: 230.0
# ---------- 4620 / 4882 ----------
# Num Games: 7737
# Num Frames: 4729856
# FPS: 110
# ETA: 0:40:47
# SMA Length: 625.155
# SMA Reward: 126.95
# SMA Entropy: 1.2600886273384093
# SMA Clip %: 0.03333984375
# SMA Loss: 0.05090965135022998
# SMA PG Loss: -0.007752777009736747
# SMA V Loss: 0.07126331429928541
# Max reward: 230.0
# ---------- 4635 / 4882 ----------
# Num Games: 7763
# Num Frames: 4745216
# FPS: 110
# ETA: 0:38:22
# SMA Length: 622.22
# SMA Reward: 128.25
# SMA Entropy: 1.2733152374625205
# SMA Clip %: 0.03328125
# SMA Loss: 0.0505351697653532
# SMA PG Loss: -0.007799817363265901
# SMA V Loss: 0.07106813920661807
# Max reward: 230.0
# ---------- 4650 / 4882 ----------
# Num Games: 7788
# Num Frames: 4760576
# FPS: 110
# ETA: 0:35:58
# SMA Length: 623.075
# SMA Reward: 128.85
# SMA Entropy: 1.28390539675951
# SMA Clip %: 0.033203125
# SMA Loss: 0.05082386139780283
# SMA PG Loss: -0.007871855075936764
# SMA V Loss: 0.07153477007523179
# Max reward: 230.0
# ---------- 4665 / 4882 ----------
# Num Games: 7813
# Num Frames: 4775936
# FPS: 111
# ETA: 0:33:35
# SMA Length: 623.83
# SMA Reward: 130.15
# SMA Entropy: 1.2949715873599053
# SMA Clip %: 0.03220703125
# SMA Loss: 0.05145017208531499
# SMA PG Loss: -0.007897195809055119
# SMA V Loss: 0.07229708340018988
# Max reward: 230.0
# ---------- 4680 / 4882 ----------
# Num Games: 7839
# Num Frames: 4791296
# FPS: 111
# ETA: 0:31:13
# SMA Length: 623.315
# SMA Reward: 130.3
# SMA Entropy: 1.3025947013497352
# SMA Clip %: 0.031875
# SMA Loss: 0.0523584567848593
# SMA PG Loss: -0.008012751541100442
# SMA V Loss: 0.07339715493842959
# Max reward: 230.0
# ---------- 4695 / 4882 ----------
# Num Games: 7864
# Num Frames: 4806656
# FPS: 111
# ETA: 0:28:51
# SMA Length: 626.66
# SMA Reward: 131.75
# SMA Entropy: 1.296758760213852
# SMA Clip %: 0.03275390625
# SMA Loss: 0.0534521634504199
# SMA PG Loss: -0.008017822103574872
# SMA V Loss: 0.07443757275119424
# Max reward: 230.0
# ---------- 4710 / 4882 ----------
# Num Games: 7886
# Num Frames: 4822016
# FPS: 111
# ETA: 0:26:30
# SMA Length: 626.28
# SMA Reward: 131.15
# SMA Entropy: 1.291660751104355
# SMA Clip %: 0.03330078125
# SMA Loss: 0.05323963179253042
# SMA PG Loss: -0.007982877418398857
# SMA V Loss: 0.07413911633193493
# Max reward: 230.0
# ---------- 4725 / 4882 ----------
# Num Games: 7911
# Num Frames: 4837376
# FPS: 112
# ETA: 0:24:09
# SMA Length: 625.87
# SMA Reward: 130.55
# SMA Entropy: 1.2928980940580368
# SMA Clip %: 0.03322265625
# SMA Loss: 0.05374562966637313
# SMA PG Loss: -0.007774460176005959
# SMA V Loss: 0.07444907039403915
# Max reward: 230.0
# ---------- 4740 / 4882 ----------
# Num Games: 7938
# Num Frames: 4852736
# FPS: 112
# ETA: 0:21:49
# SMA Length: 624.195
# SMA Reward: 131.95
# SMA Entropy: 1.295633996129036
# SMA Clip %: 0.03322265625
# SMA Loss: 0.05371595540083945
# SMA PG Loss: -0.007785267550498247
# SMA V Loss: 0.07445756252855062
# Max reward: 230.0
# ---------- 4755 / 4882 ----------
# Num Games: 7965
# Num Frames: 4868096
# FPS: 112
# ETA: 0:19:30
# SMA Length: 624.51
# SMA Reward: 131.75
# SMA Entropy: 1.2956959041953087
# SMA Clip %: 0.03296875
# SMA Loss: 0.05332000539638102
# SMA PG Loss: -0.007744995863176883
# SMA V Loss: 0.07402195993810892
# Max reward: 230.0
# ---------- 4770 / 4882 ----------
# Num Games: 7988
# Num Frames: 4883456
# FPS: 112
# ETA: 0:17:11
# SMA Length: 623.625
# SMA Reward: 132.6
# SMA Entropy: 1.289099345803261
# SMA Clip %: 0.03474609375
# SMA Loss: 0.05291866906918585
# SMA PG Loss: -0.007932476524729282
# SMA V Loss: 0.07374213861301541
# Max reward: 230.0
# ---------- 4785 / 4882 ----------
# Num Games: 8014
# Num Frames: 4898816
# FPS: 113
# ETA: 0:14:53
# SMA Length: 620.315
# SMA Reward: 131.9
# SMA Entropy: 1.2872049474716187
# SMA Clip %: 0.0342578125
# SMA Loss: 0.05287951403297484
# SMA PG Loss: -0.007993148565292358
# SMA V Loss: 0.07374471163377166
# Max reward: 230.0
# ---------- 4800 / 4882 ----------
# Num Games: 8039
# Num Frames: 4914176
# FPS: 113
# ETA: 0:12:36
# SMA Length: 621.145
# SMA Reward: 131.85
# SMA Entropy: 1.2853182005882262
# SMA Clip %: 0.0344140625
# SMA Loss: 0.05290901773609221
# SMA PG Loss: -0.008217306872829795
# SMA V Loss: 0.07397950613871217
# Max reward: 230.0
# ---------- 4815 / 4882 ----------
# Num Games: 8064
# Num Frames: 4929536
# FPS: 113
# ETA: 0:10:19
# SMA Length: 620.13
# SMA Reward: 131.35
# SMA Entropy: 1.2860411900281905
# SMA Clip %: 0.03365234375
# SMA Loss: 0.05309447462670505
# SMA PG Loss: -0.008197694087866693
# SMA V Loss: 0.07415258012712002
# Max reward: 230.0
# ---------- 4830 / 4882 ----------
# Num Games: 8090
# Num Frames: 4944896
# FPS: 113
# ETA: 0:08:03
# SMA Length: 616.52
# SMA Reward: 132.85
# SMA Entropy: 1.2769582962989807
# SMA Clip %: 0.03423828125
# SMA Loss: 0.05371059361845255
# SMA PG Loss: -0.008320595750119538
# SMA V Loss: 0.07480077194049954
# Max reward: 230.0
# ---------- 4845 / 4882 ----------
# Num Games: 8114
# Num Frames: 4960256
# FPS: 114
# ETA: 0:05:47
# SMA Length: 617.9
# SMA Reward: 133.75
# SMA Entropy: 1.2761485895514488
# SMA Clip %: 0.03423828125
# SMA Loss: 0.05359395182691515
# SMA PG Loss: -0.008146933789830654
# SMA V Loss: 0.0745023711770773
# Max reward: 230.0
# ---------- 4860 / 4882 ----------
# Num Games: 8142
# Num Frames: 4975616
# FPS: 114
# ETA: 0:03:33
# SMA Length: 616.55
# SMA Reward: 134.2
# SMA Entropy: 1.2767549809813499
# SMA Clip %: 0.0340234375
# SMA Loss: 0.05327421211637556
# SMA PG Loss: -0.008186316695064305
# SMA V Loss: 0.07422807835042476
# Max reward: 230.0
# ---------- 4875 / 4882 ----------
# Num Games: 8166
# Num Frames: 4990976
# FPS: 114
# ETA: 0:01:18
# SMA Length: 614.985
# SMA Reward: 134.05
# SMA Entropy: 1.277769457399845
# SMA Clip %: 0.0349609375
# SMA Loss: 0.0529524124506861
# SMA PG Loss: -0.008082216354086996
# SMA V Loss: 0.0738123232126236
# Max reward: 230.0

# %% [markdown]
# # Save final model and log

# %%
save_checkpoint('FINAL')
T.save(logger.log, SAVE_PATH+'FINAL.'+ENV_NAME+'.log')
T.save(ac, SAVE_PATH+'FINAL.'+ENV_NAME+'.MODEL')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:360: UserWarning: Couldn't retrieve source code for container of type AC. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %% [markdown]
# # Plot results

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set()

# %%
def plot_log(log, ylabel):
    # compute rolling avg and std
    df = pd.DataFrame(log, columns =['Frames', 'Iters', ylabel])
    sma_y = df[ylabel].rolling(500).mean()
    std_y = df[ylabel].rolling(500).std()
    
    # plot with seaborn
    fig, ax = plt.subplots(figsize=(5,5))
    ax.set_xlabel('Frames')
    ax.set_ylabel(ylabel)
    clrs = sns.color_palette("husl", 8)

    # fill standard deviation
    ax.plot(df['Frames'], sma_y, label=ylabel, c=clrs[0])
    ax.fill_between(df['Frames'], sma_y-std_y,  sma_y+std_y, 
                    alpha=0.3, facecolor=clrs[0]) 
    ax.legend(loc='upper left')
    plt.savefig(SAVE_PATH+ENV_NAME+'.'+ylabel+'.plt.png', 
                dpi=300, pad_inches=0)
    plt.show()

plot_log(logger.log['ep_r'], 'Reward')
plot_log(logger.log['ep_l'], 'Length')
plot_log(logger.log['loss'], 'Loss')
plot_log(logger.log['ent'], 'Entropy')

# %%
fig_all, ax_all = plt.subplots(2,2, figsize=(8,8))

## REWARD 
df = pd.DataFrame(logger.log['ep_r'], columns =['Frames', 'Iters', 'rwd'])
sma_y = df['rwd'].rolling(500).mean()
std_y = df['rwd'].rolling(500).std()

ax_all[0][0].set_ylabel('Reward')
clrs = sns.color_palette("husl", 8)

# fill standard deviation
ax_all[0][0].plot(df['Frames'], sma_y, label='Episode Reward', c=clrs[0])
ax_all[0][0].fill_between(df['Frames'], sma_y-std_y,  sma_y+std_y, 
                alpha=0.3, facecolor=clrs[0])

# make x axis nice
ax_all[0][0].set_xticklabels('')


## LENGTH 
df = pd.DataFrame(logger.log['ep_l'], columns =['Frames', 'Iters', 'Len'])
sma_y = df['Len'].rolling(500).mean()
std_y = df['Len'].rolling(500).std()

ax_all[0][1].set_ylabel('Length')
ax_all[0][1].yaxis.tick_right()
clrs = sns.color_palette("husl", 8)

# fill standard deviation
ax_all[0][1].plot(df['Frames'], sma_y, label='Episode Length', c=clrs[0])
ax_all[0][1].fill_between(df['Frames'], sma_y-std_y,  sma_y+std_y, 
                alpha=0.3, facecolor=clrs[0])

# make x axis nice
ax_all[0][1].set_xticklabels('')


## ENTROPY 
df = pd.DataFrame(logger.log['ent'], columns =['Frames', 'Iters', 'ent'])
sma_y = df['ent'].rolling(500).mean()
std_y = df['ent'].rolling(500).std()

ax_all[1][0].set_xlabel('Frames')
ax_all[1][0].set_ylabel('Entropy')
clrs = sns.color_palette("husl", 8)

# fill standard deviation
ax_all[1][0].plot(df['Frames'], sma_y, label='Entropy', c=clrs[0])
ax_all[1][0].fill_between(df['Frames'], sma_y-std_y,  sma_y+std_y, 
                alpha=0.3, facecolor=clrs[0])

# make x axis nice
xlabels = [f'{int(x)}M' for x in ax_all[1][0].get_xticks()/1e6]
ax_all[1][0].set_xticklabels(xlabels)


## LOSS 
df = pd.DataFrame(logger.log['loss'], columns =['Frames', 'Iters', 'Loss'])
sma_y = df['Loss'].rolling(500).mean()
std_y = df['Loss'].rolling(500).std()

ax_all[1][1].set_xlabel('Frames')
ax_all[1][1].set_ylabel('Loss')
ax_all[1][1].yaxis.tick_right()
clrs = sns.color_palette("husl", 8)

# fill standard deviation
ax_all[1][1].plot(df['Frames'], sma_y, label='Loss', c=clrs[0])
ax_all[1][1].fill_between(df['Frames'], sma_y-std_y,  sma_y+std_y, 
                alpha=0.3, facecolor=clrs[0])

# make x axis nice
xlabels = [f'{int(x)}M' for x in ax_all[1][1].get_xticks()/1e6]
ax_all[1][1].set_xticklabels(xlabels)

plt.savefig(SAVE_PATH+ENV_NAME+'_plot_thesis.png', 
            dpi=300, pad_inches=0, bbox_inches = 'tight')

plt.show()
