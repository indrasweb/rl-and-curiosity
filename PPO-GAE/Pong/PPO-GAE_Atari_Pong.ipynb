# %%
# !pip install stable-baselines==2.9.0

# %%
import datetime
from time import time
from collections import deque

import numpy as np

import torch as T
from torch.autograd import Variable
import torch.nn as nn
from torch.distributions import Categorical
from torch.optim import Adam
from torch.optim.lr_scheduler import LambdaLR

from stable_baselines.common.misc_util import set_global_seeds
from stable_baselines.common.cmd_util import make_atari_env
from stable_baselines.common.vec_env import VecFrameStack, VecNormalize

from tqdm import trange
from google.colab import drive
from itertools import count

# %%
drive.mount('/content/gdrive')

# %%
ENV_NAME = 'PongNoFrameskip-v4'
SAVE_PATH = '/content/gdrive/My Drive/PPO-GAE/'

TOTAL_FRAMES = 5e6    # 5 million frames
ROLLOUT_LENGTH = 128  # transitions in each rollout
NENV = 8              # parallel environments; increase to decorrolate batches
GAMMA = 0.99          # reward discounting coefficient
LAMBDA = 0.95         # GAE discounting coefficient
SEED = 420            # blaze it
MB_SPLIT = 4          # split minibatch into quarters for surrogate calculation
MB_EPOCHS = 4         # epochs per minibatch (4 weight updates on policy per mb)
CLIP = 0.2            # clip the surrogate objective so updates are not too big

STEPS_PER_ROLLOUT = ROLLOUT_LENGTH*NENV
TOTAL_UPDATES = int(TOTAL_FRAMES // STEPS_PER_ROLLOUT)
SPLIT_LEN = int(STEPS_PER_ROLLOUT//MB_SPLIT)
DEVICE = T.device('cuda' if T.cuda.is_available() else 'cpu')

set_global_seeds(SEED)

# %% [markdown]
# # Neural Net Definitions

# %%
def conv_size(net, in_shape):
    """ util for calculating flat output shape of a given net """
    x = Variable(T.rand(1, *in_shape))
    o = net(x)
    b = (-1, o.size(1), o.size(2), o.size(3))
    return b, o.data.view(1, -1).size(1)

# %%
class AC(nn.Module):
  
    def __init__(self, input_shape, num_actions):
        super().__init__()
        h, w, c = input_shape

        self.conv = nn.Sequential(
            nn.Conv2d(c, 32, 8, 4),
            nn.ReLU(True),
            nn.Conv2d(32, 64, 4, 2),
            nn.ReLU(True),
            nn.Conv2d(64, 64, 3, 1),
            nn.ReLU(True),
        )
        
        _, f = conv_size(self.conv, (c,h,w))
        self.backbone = nn.Sequential(self.conv, nn.Flatten())
        self.actor = nn.Linear(f, num_actions)
        self.critic = nn.Linear(f, 1)

    def forward(self, x):
        latent = self.backbone(x)
        return self.actor(latent), self.critic(latent)

# %% [markdown]
# # Logging utils

# %%
class Logger:

    def __init__(self, print_rate):
        self.log = {'ep_r':[], 'ep_l':[], 'loss':[], 'pgloss':[], 
                    'vloss':[], 'ent':[], 'cf':[]}
        self.n_ep = 0              # total games/episodes
        self.n_update = 1          # total weight updates
        self.n_frames = 0          # env steps (total from checkpoint)
        self.run_frames = 0        # env steps (for this run)
        self.max_rwd = -np.inf     # max rwd out of all games played
        self.start_time = time()   # time we started *this* run
        self.last_checkpoint = 0   # total_frames at last checkpoint
        self.print_rate = print_rate

    def eta(self):  # get hh:mm:ss left to train
        elapsed_time = time() - self.start_time
        frames_left = TOTAL_FRAMES - self.n_frames
        sec_per_frame = elapsed_time / self.n_frames
        sec_left = int(frames_left * sec_per_frame)
        eta_str = str(datetime.timedelta(seconds=sec_left))
        return eta_str

    def fps(self):  # get frames per second
        elapsed_time = time() - self.start_time
        fps = int(self.run_frames / elapsed_time)
        return fps

    def sma(self, x):  # simple moving average
        if len(x) == 0: return 'NaN'
        div = 200 if len(x) > 200 else len(x)
        return sum(list(zip(*x[-div:]))[-1])/div

    def print_log(self):
        fps = self.fps()
        eta = self.eta()
        print('-'*10, self.n_update, '/', TOTAL_UPDATES, '-'*10)
        print('Num Games:', self.n_ep)
        print('Num Frames:', self.n_frames)
        print('FPS:', fps)
        print('ETA:', eta)
        print('SMA Length:', self.sma(self.log['ep_l']))
        print('SMA Reward:', self.sma(self.log['ep_r']))
        print('SMA Entropy:', self.sma(self.log['ent']))
        print('SMA Clip %:', self.sma(self.log['cf']))
        print('SMA Loss:', self.sma(self.log['loss']))
        print('SMA PG Loss:', self.sma(self.log['pgloss']))
        print('SMA V Loss:', self.sma(self.log['vloss']))
        print('Max reward:', self.max_rwd)

    def record(self, ep, loss, pgloss, vloss, ent, cf):
        
        self.n_update += 1
        self.n_frames += STEPS_PER_ROLLOUT
        self.run_frames += STEPS_PER_ROLLOUT
        fr = (self.n_frames, self.n_update)

        # stats about finished episodes/games
        for l, r in zip(ep['l'], ep['r']):
            self.log['ep_l'].append(fr+(l,))
            self.log['ep_r'].append(fr+(r,))
            if r > self.max_rwd: self.max_rwd = r
            self.n_ep += 1
             
        # nn training statistics
        self.log['loss'].append(fr+(loss,))
        self.log['pgloss'].append(fr+(pgloss,))
        self.log['vloss'].append(fr+(vloss,))
        self.log['ent'].append(fr+(ent,))
        self.log['cf'].append(fr+(cf,))
        
        # print log
        if self.n_update % self.print_rate == 0:
            self.print_log()

# %% [markdown]
# # Rollout handling

# %%
def ob_to_torch(x):
    x = np.moveaxis(x, -1, 1)
    x = T.from_numpy(x).float()
    x = x.to(DEVICE)
    return x

# %%
def GAE(rwds, vals, next_val, dones=None):
    """ GAE lambda. vals is full batch, next_val is singular """
    returns = T.empty_like(rwds).to(DEVICE)
    if dones is None: dones = T.ones_like(rwds, dtype=T.bool)
    g = 0
    for i in reversed(range(ROLLOUT_LENGTH)):
        d = rwds[i] + (GAMMA * next_val * ~dones[i]) - vals[i]
        g = d + (GAMMA * LAMBDA * ~dones[i] * g)
        returns[i] = g + vals[i]
        next_val = vals[i]
    adv = returns - vals
    return returns, adv

# %%
def rollout_generator(env, policy):

    ob = ob_to_torch(env.reset())
    mb = {'obs':[], 'act':[], 'logp':[], 'rwd':[], 'done':[], 'val':[]}
    ep = {'l':[], 'r':[]}  # len & total reward of done eps 
    
    for step in count(1):

        # we compute gradients in the train loop
        with T.no_grad():
            logits, val = policy(ob)
            dist = Categorical(logits=logits)
            action = dist.sample()
            logp = dist.log_prob(action)
        
        new_ob, rwd, done, info = env.step(action)
        
        # store transition
        mb['obs'].append(ob)
        mb['act'].append(action)
        mb['logp'].append(logp)
        mb['rwd'].append(T.from_numpy(rwd))
        mb['val'].append(val.view(-1))
        mb['done'].append(T.from_numpy(done))
        for t in info:
            if t.get('episode'):
                ep['l'].append(t['episode']['l'])
                ep['r'].append(t['episode']['r'])

        ob = ob_to_torch(new_ob)

        if step % ROLLOUT_LENGTH != 0:
            continue

        ########################################################
        ###   Flatten rollout & assign credit w/ GAE         ###
        ########################################################

        for k in mb.keys():
            mb[k] = T.stack(mb[k]).to(DEVICE)

        # bootstap generalized advantages
        with T.no_grad():
            next_val = policy(ob)[1].view(-1) * ~mb['done'][-1]
            mb['rtn'], mb['gae'] = GAE(mb['rwd'], mb['val'], next_val, mb['done'])

        # flatten to (NENV*ROLLOUT_LENGTH, ...)
        for k in mb.keys():
            s = mb[k].size()
            mb[k] = mb[k].view(STEPS_PER_ROLLOUT, *s[2:])
        
        yield mb, ep
        mb = {'obs':[], 'act':[], 'logp':[], 'rwd':[], 'done':[], 'val':[]}
        ep = {'l':[], 'r':[]}

# %% [markdown]
# # Checkpoint loading and saving

# %%
def new_run():
    """ setup parallelised gym environments (MaxAndSkip=4 by default) """
    env = make_atari_env(ENV_NAME, num_env=NENV, seed=SEED)
    env._max_episode_steps = 4500*4
    env = VecFrameStack(env, n_stack=4)
    in_dim = env.observation_space.shape
    policy_dim = env.action_space.n

    # get actor + critic || learning rate is SO important (see README)
    ac = AC(in_dim, policy_dim).to(DEVICE)
    ac_optimizer = Adam(ac.parameters(), 1e-4, eps=1e-5)
    logger = Logger(15)

    return env, ac, ac_optimizer, logger

# %%
def save_checkpoint(checkpoint_id):
    checkpoint = {
        'ac': ac.state_dict(),
        'ac_opt': ac_optimizer.state_dict(),
        'logger': logger
    }
    X = str(checkpoint_id)
    T.save(checkpoint, SAVE_PATH+X+'.'+ENV_NAME+'.checkpoint')

# %%
def load_checkpoint(file_name):
    checkpoint = T.load(file_name, map_location=DEVICE)

    env = make_atari_env(ENV_NAME, num_env=NENV, seed=SEED)
    env = VecFrameStack(env, n_stack=4)
    in_dim = env.observation_space.shape
    policy_dim = env.action_space.n
    
    ac = AC(in_dim, policy_dim).to(DEVICE)
    ac.load_state_dict(checkpoint['ac'])
    ac_optimizer = Adam(ac.parameters())
    ac_optimizer.load_state_dict(checkpoint['ac_opt'])
    logger = checkpoint['logger']

    return env, ac, ac_optimizer, logger

# %% [markdown]
# # Load checkpoint or begin new run

# %%
# env, ac, ac_optimizer, logger = new_run()
env, ac, ac_optimizer, logger = load_checkpoint(SAVE_PATH+'4001792.PongNoFrameskip-v4.checkpoint')

rollouts = rollout_generator(env, ac)
lr_scheduler = LambdaLR(ac_optimizer, lambda i: max(0.1, 1 - i/TOTAL_UPDATES))

# %% [markdown]
# # Train!

# %%
for i_update in range(logger.n_update, TOTAL_UPDATES):

    mb, ep = next(rollouts)
    
    # randomly split mb for surrogate calculation
    ixs = np.arange(STEPS_PER_ROLLOUT)
    
    # multiple updates using each minibatch
    for epoch in range(MB_EPOCHS):
        
        np.random.shuffle(ixs)
        
        for s in range(MB_SPLIT):

            # split minibatch into chunks
            ix = ixs[s*SPLIT_LEN:s*SPLIT_LEN+SPLIT_LEN]
            s_obs = mb['obs'][ix]        # observations (states)
            s_logp_old = mb['logp'][ix]  # log probs
            s_act = mb['act'][ix]        # actions
            s_rtn = mb['rtn'][ix]        # returns (not baselined)
            s_adv = mb['gae'][ix]        # generalized advantages

            # normalized split advantange
            s_adv = (s_adv - s_adv.mean()) / (s_adv.std() + 1e-8)

            # policy gradient + entropy
            logits, val = ac(s_obs)
            dist = Categorical(logits=logits)
            s_ent = dist.entropy().mean()
            s_logp_new = dist.log_prob(s_act)

            # surrogate loss (ratio == 1 on first iter, ln cancels)
            ratio = (s_logp_new - s_logp_old).exp() # e^x / e^x == e^(x-y)
            L_CPI = -s_adv * ratio
            L_CLAMP = -s_adv * ratio.clamp(1-CLIP, 1+CLIP)
            L_CLIP = T.max(L_CPI, L_CLAMP).mean()
            
            # fraction of clipped samples; ensure this is < ~0.2
            # whilst training, else your policy will collapse
            r = ratio.detach()
            clip_frac = ((r < 1-CLIP) | (r > 1+CLIP)).float().mean()
            
            # value loss
            V_L = 0.5 * (val - s_rtn).pow(2).mean()

            # step
            loss = L_CLIP + V_L - 0.01*s_ent
            ac_optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(ac.parameters(), 0.5)
            ac_optimizer.step()

    # decay lr and log training stats
    lr_scheduler.step(i_update)
    logger.record(ep, loss.item(), L_CLIP.item(), V_L.item(),
                  s_ent.item(), clip_frac.item())
    
    # make a checkpoint every 1m frames
    if logger.n_frames - logger.last_checkpoint >= 1e6:
        save_checkpoint(logger.n_frames)
        logger.last_checkpoint = logger.n_frames
# Out:
# ---------- 3915 / 4882 ----------
# Num Games: 2370
# Num Frames: 4007936
# FPS: 104
# ETA: 2:38:41
# SMA Length: 1852.875
# SMA Reward: 17.105
# SMA Entropy: 1.0491088980436325
# SMA Clip %: 0.05935546875
# SMA Loss: 0.027953604753129184
# SMA PG Loss: -0.006047323958482593
# SMA V Loss: 0.04449201742187142
# Max reward: 21.0
# ---------- 3930 / 4882 ----------
# Num Games: 2378
# Num Frames: 4023296
# FPS: 104
# ETA: 2:35:44
# SMA Length: 1860.995
# SMA Reward: 16.885
# SMA Entropy: 1.0475496315956117
# SMA Clip %: 0.05890625
# SMA Loss: 0.0280019408185035
# SMA PG Loss: -0.0058967233006842435
# SMA V Loss: 0.04437416016124189
# Max reward: 21.0
# ---------- 3945 / 4882 ----------
# Num Games: 2386
# Num Frames: 4038656
# FPS: 104
# ETA: 2:32:49
# SMA Length: 1858.95
# SMA Reward: 16.95
# SMA Entropy: 1.0490149825811386
# SMA Clip %: 0.05609375
# SMA Loss: 0.027791334772482513
# SMA PG Loss: -0.005659424953628331
# SMA V Loss: 0.0439409093093127
# Max reward: 21.0
# ---------- 3960 / 4882 ----------
# Num Games: 2394
# Num Frames: 4054016
# FPS: 105
# ETA: 2:29:55
# SMA Length: 1865.17
# SMA Reward: 16.88
# SMA Entropy: 1.0517986169457436
# SMA Clip %: 0.05673828125
# SMA Loss: 0.027733598137274384
# SMA PG Loss: -0.005633683314081281
# SMA V Loss: 0.043885267367586495
# Max reward: 21.0
# ---------- 3975 / 4882 ----------
# Num Games: 2402
# Num Frames: 4069376
# FPS: 105
# ETA: 2:27:02
# SMA Length: 1868.19
# SMA Reward: 16.87
# SMA Entropy: 1.045934970676899
# SMA Clip %: 0.0588671875
# SMA Loss: 0.027867304771207274
# SMA PG Loss: -0.0054574021464213725
# SMA V Loss: 0.04378405638039112
# Max reward: 21.0
# ---------- 3990 / 4882 ----------
# Num Games: 2409
# Num Frames: 4084736
# FPS: 105
# ETA: 2:24:10
# SMA Length: 1872.715
# SMA Reward: 16.82
# SMA Entropy: 1.0402313169836999
# SMA Clip %: 0.05478515625
# SMA Loss: 0.026943314336240292
# SMA PG Loss: -0.005205926515627652
# SMA V Loss: 0.04255155384540558
# Max reward: 21.0
# ---------- 4005 / 4882 ----------
# Num Games: 2417
# Num Frames: 4100096
# FPS: 106
# ETA: 2:21:20
# SMA Length: 1883.245
# SMA Reward: 16.425
# SMA Entropy: 1.044489503800869
# SMA Clip %: 0.05515625
# SMA Loss: 0.027241109348833562
# SMA PG Loss: -0.005217911642976105
# SMA V Loss: 0.04290391586720944
# Max reward: 21.0
# ---------- 4020 / 4882 ----------
# Num Games: 2425
# Num Frames: 4115456
# FPS: 106
# ETA: 2:18:30
# SMA Length: 1888.05
# SMA Reward: 16.35
# SMA Entropy: 1.0498473858833313
# SMA Clip %: 0.051875
# SMA Loss: 0.027143423580564558
# SMA PG Loss: -0.005035783138591796
# SMA V Loss: 0.04267768042162061
# Max reward: 21.0
# ---------- 4035 / 4882 ----------
# Num Games: 2433
# Num Frames: 4130816
# FPS: 106
# ETA: 2:15:41
# SMA Length: 1892.055
# SMA Reward: 16.29
# SMA Entropy: 1.0570012810826301
# SMA Clip %: 0.05216796875
# SMA Loss: 0.027284524808637797
# SMA PG Loss: -0.005104614174924791
# SMA V Loss: 0.042959151603281495
# Max reward: 21.0
# ---------- 4050 / 4882 ----------
# Num Games: 2441
# Num Frames: 4146176
# FPS: 107
# ETA: 2:12:54
# SMA Length: 1895.835
# SMA Reward: 16.185
# SMA Entropy: 1.0621487185359002
# SMA Clip %: 0.05310546875
# SMA Loss: 0.027540727849118412
# SMA PG Loss: -0.005070587098598481
# SMA V Loss: 0.0432328019849956
# Max reward: 21.0
# ---------- 4065 / 4882 ----------
# Num Games: 2449
# Num Frames: 4161536
# FPS: 107
# ETA: 2:10:07
# SMA Length: 1898.145
# SMA Reward: 16.115
# SMA Entropy: 1.0706090703606606
# SMA Clip %: 0.0560546875
# SMA Loss: 0.027940755542367697
# SMA PG Loss: -0.005225223135203123
# SMA V Loss: 0.043872069166973234
# Max reward: 21.0
# ---------- 4080 / 4882 ----------
# Num Games: 2457
# Num Frames: 4176896
# FPS: 107
# ETA: 2:07:21
# SMA Length: 1897.045
# SMA Reward: 16.105
# SMA Entropy: 1.0782099094986917
# SMA Clip %: 0.0551953125
# SMA Loss: 0.02830221344716847
# SMA PG Loss: -0.005166152287274599
# SMA V Loss: 0.04425046457909047
# Max reward: 21.0
# ---------- 4095 / 4882 ----------
# Num Games: 2467
# Num Frames: 4192256
# FPS: 108
# ETA: 2:04:37
# SMA Length: 1886.43
# SMA Reward: 16.055
# SMA Entropy: 1.0893936550617218
# SMA Clip %: 0.0596875
# SMA Loss: 0.028781673600897194
# SMA PG Loss: -0.005300769950263202
# SMA V Loss: 0.04497637984342873
# Max reward: 21.0
# ---------- 4110 / 4882 ----------
# Num Games: 2475
# Num Frames: 4207616
# FPS: 108
# ETA: 2:01:53
# SMA Length: 1881.66
# SMA Reward: 16.185
# SMA Entropy: 1.0912946206331253
# SMA Clip %: 0.059921875
# SMA Loss: 0.02851405114866793
# SMA PG Loss: -0.005381659613922238
# SMA V Loss: 0.04480865673162043
# Max reward: 21.0
# ---------- 4125 / 4882 ----------
# Num Games: 2483
# Num Frames: 4222976
# FPS: 108
# ETA: 1:59:11
# SMA Length: 1873.94
# SMA Reward: 16.335
# SMA Entropy: 1.076797707080841
# SMA Clip %: 0.0634375
# SMA Loss: 0.027868063785135747
# SMA PG Loss: -0.005533193866722286
# SMA V Loss: 0.04416923446580768
# Max reward: 21.0
# ---------- 4140 / 4882 ----------
# Num Games: 2492
# Num Frames: 4238336
# FPS: 108
# ETA: 1:56:29
# SMA Length: 1866.685
# SMA Reward: 16.385
# SMA Entropy: 1.0752082860469818
# SMA Clip %: 0.06265625
# SMA Loss: 0.02797634106595069
# SMA PG Loss: -0.005602015531621873
# SMA V Loss: 0.044330439176410434
# Max reward: 21.0
# ---------- 4155 / 4882 ----------
# Num Games: 2500
# Num Frames: 4253696
# FPS: 109
# ETA: 1:53:48
# SMA Length: 1863.82
# SMA Reward: 16.44
# SMA Entropy: 1.0742461666464806
# SMA Clip %: 0.06421875
# SMA Loss: 0.027801940781064332
# SMA PG Loss: -0.0055834311991930004
# SMA V Loss: 0.04412783334963024
# Max reward: 21.0
# ---------- 4170 / 4882 ----------
# Num Games: 2509
# Num Frames: 4269056
# FPS: 109
# ETA: 1:51:09
# SMA Length: 1854.255
# SMA Reward: 16.72
# SMA Entropy: 1.086325678229332
# SMA Clip %: 0.06166015625
# SMA Loss: 0.028237226977944375
# SMA PG Loss: -0.005442032665014267
# SMA V Loss: 0.044542516116052866
# Max reward: 21.0
# ---------- 4185 / 4882 ----------
# Num Games: 2516
# Num Frames: 4284416
# FPS: 109
# ETA: 1:48:30
# SMA Length: 1855.13
# SMA Reward: 16.77
# SMA Entropy: 1.0959811747074126
# SMA Clip %: 0.0582421875
# SMA Loss: 0.028929281518794595
# SMA PG Loss: -0.005464637437835335
# SMA V Loss: 0.04535373043268919
# Max reward: 21.0
# ---------- 4200 / 4882 ----------
# Num Games: 2525
# Num Frames: 4299776
# FPS: 110
# ETA: 1:45:52
# SMA Length: 1853.855
# SMA Reward: 16.815
# SMA Entropy: 1.0912126663327217
# SMA Clip %: 0.052421875
# SMA Loss: 0.027748599029146136
# SMA PG Loss: -0.005321860609110445
# SMA V Loss: 0.04398258604109287
# Max reward: 21.0
# ---------- 4215 / 4882 ----------
# Num Games: 2535
# Num Frames: 4315136
# FPS: 110
# ETA: 1:43:15
# SMA Length: 1855.705
# SMA Reward: 16.76
# SMA Entropy: 1.090909615457058
# SMA Clip %: 0.05109375
# SMA Loss: 0.02738916364032775
# SMA PG Loss: -0.005399956461042165
# SMA V Loss: 0.043698215996846555
# Max reward: 21.0
# ---------- 4230 / 4882 ----------
# Num Games: 2542
# Num Frames: 4330496
# FPS: 110
# ETA: 1:40:39
# SMA Length: 1856.325
# SMA Reward: 16.77
# SMA Entropy: 1.0819014546275139
# SMA Clip %: 0.05072265625
# SMA Loss: 0.027354250843636692
# SMA PG Loss: -0.0053025417169556026
# SMA V Loss: 0.04347580680623651
# Max reward: 21.0
# ---------- 4245 / 4882 ----------
# Num Games: 2552
# Num Frames: 4345856
# FPS: 111
# ETA: 1:38:04
# SMA Length: 1856.78
# SMA Reward: 16.765
# SMA Entropy: 1.0819084197282791
# SMA Clip %: 0.04755859375
# SMA Loss: 0.026718677105382085
# SMA PG Loss: -0.0052632360369898375
# SMA V Loss: 0.04280099704861641
# Max reward: 21.0
# ---------- 4260 / 4882 ----------
# Num Games: 2560
# Num Frames: 4361216
# FPS: 111
# ETA: 1:35:30
# SMA Length: 1860.425
# SMA Reward: 16.73
# SMA Entropy: 1.0828192341327667
# SMA Clip %: 0.04017578125
# SMA Loss: 0.02669035301543772
# SMA PG Loss: -0.005053556051570922
# SMA V Loss: 0.04257210117764771
# Max reward: 21.0
# ---------- 4275 / 4882 ----------
# Num Games: 2568
# Num Frames: 4376576
# FPS: 111
# ETA: 1:32:56
# SMA Length: 1863.695
# SMA Reward: 16.69
# SMA Entropy: 1.0813974192738534
# SMA Clip %: 0.0351953125
# SMA Loss: 0.026389685291796923
# SMA PG Loss: -0.004745154718402773
# SMA V Loss: 0.04194881402887404
# Max reward: 21.0
# ---------- 4290 / 4882 ----------
# Num Games: 2576
# Num Frames: 4391936
# FPS: 112
# ETA: 1:30:24
# SMA Length: 1855.335
# SMA Reward: 16.95
# SMA Entropy: 1.079502911567688
# SMA Clip %: 0.0300390625
# SMA Loss: 0.026478544510900974
# SMA PG Loss: -0.004549775945488364
# SMA V Loss: 0.04182334940880537
# Max reward: 21.0
# ---------- 4305 / 4882 ----------
# Num Games: 2585
# Num Frames: 4407296
# FPS: 112
# ETA: 1:27:52
# SMA Length: 1856.045
# SMA Reward: 16.98
# SMA Entropy: 1.0783903107047081
# SMA Clip %: 0.024140625
# SMA Loss: 0.02622512839268893
# SMA PG Loss: -0.004370803218334913
# SMA V Loss: 0.041379834543913606
# Max reward: 21.0
# ---------- 4320 / 4882 ----------
# Num Games: 2594
# Num Frames: 4422656
# FPS: 112
# ETA: 1:25:21
# SMA Length: 1846.23
# SMA Reward: 17.155
# SMA Entropy: 1.0794659411907197
# SMA Clip %: 0.0215234375
# SMA Loss: 0.02581077519338578
# SMA PG Loss: -0.00417373328935355
# SMA V Loss: 0.0407791677583009
# Max reward: 21.0
# ---------- 4335 / 4882 ----------
# Num Games: 2602
# Num Frames: 4438016
# FPS: 113
# ETA: 1:22:51
# SMA Length: 1843.695
# SMA Reward: 17.185
# SMA Entropy: 1.0699706262350082
# SMA Clip %: 0.0241015625
# SMA Loss: 0.02588233527727425
# SMA PG Loss: -0.00410398083506152
# SMA V Loss: 0.04068602230399847
# Max reward: 21.0
# ---------- 4350 / 4882 ----------
# Num Games: 2611
# Num Frames: 4453376
# FPS: 113
# ETA: 1:20:22
# SMA Length: 1834.315
# SMA Reward: 17.46
# SMA Entropy: 1.0638209003210068
# SMA Clip %: 0.02431640625
# SMA Loss: 0.026001226003281773
# SMA PG Loss: -0.004011977242771536
# SMA V Loss: 0.04065141215920448
# Max reward: 21.0
# ---------- 4365 / 4882 ----------
# Num Games: 2619
# Num Frames: 4468736
# FPS: 113
# ETA: 1:17:54
# SMA Length: 1819.73
# SMA Reward: 17.51
# SMA Entropy: 1.0520313701033592
# SMA Clip %: 0.02935546875
# SMA Loss: 0.02632882621139288
# SMA PG Loss: -0.003977878224104643
# SMA V Loss: 0.040827018013224005
# Max reward: 21.0
# ---------- 4380 / 4882 ----------
# Num Games: 2628
# Num Frames: 4484096
# FPS: 113
# ETA: 1:15:27
# SMA Length: 1812.0
# SMA Reward: 17.615
# SMA Entropy: 1.042902479469776
# SMA Clip %: 0.0286328125
# SMA Loss: 0.02555806964170188
# SMA PG Loss: -0.003912350321188569
# SMA V Loss: 0.0398994446080178
# Max reward: 21.0
# ---------- 4395 / 4882 ----------
# Num Games: 2636
# Num Frames: 4499456
# FPS: 114
# ETA: 1:13:00
# SMA Length: 1808.755
# SMA Reward: 17.685
# SMA Entropy: 1.0454514801502228
# SMA Clip %: 0.02716796875
# SMA Loss: 0.025879247440025212
# SMA PG Loss: -0.003764609578065574
# SMA V Loss: 0.04009837160818279
# Max reward: 21.0
# ---------- 4410 / 4882 ----------
# Num Games: 2647
# Num Frames: 4514816
# FPS: 114
# ETA: 1:10:34
# SMA Length: 1805.84
# SMA Reward: 17.785
# SMA Entropy: 1.0425490301847458
# SMA Clip %: 0.02751953125
# SMA Loss: 0.025987497023306785
# SMA PG Loss: -0.003667618194594979
# SMA V Loss: 0.04008060527965426
# Max reward: 21.0
# ---------- 4425 / 4882 ----------
# Num Games: 2655
# Num Frames: 4530176
# FPS: 114
# ETA: 1:08:09
# SMA Length: 1802.965
# SMA Reward: 17.85
# SMA Entropy: 1.0412327817082405
# SMA Clip %: 0.0332421875
# SMA Loss: 0.02619793191552162
# SMA PG Loss: -0.0035087189637124537
# SMA V Loss: 0.04011897845193744
# Max reward: 21.0
# ---------- 4440 / 4882 ----------
# Num Games: 2663
# Num Frames: 4545536
# FPS: 115
# ETA: 1:05:45
# SMA Length: 1805.195
# SMA Reward: 17.795
# SMA Entropy: 1.0447654154896737
# SMA Clip %: 0.03068359375
# SMA Loss: 0.02684544079005718
# SMA PG Loss: -0.003345697552431375
# SMA V Loss: 0.040638792254030706
# Max reward: 21.0
# ---------- 4455 / 4882 ----------
# Num Games: 2672
# Num Frames: 4560896
# FPS: 115
# ETA: 1:03:21
# SMA Length: 1809.68
# SMA Reward: 17.955
# SMA Entropy: 1.0452896809577943
# SMA Clip %: 0.031484375
# SMA Loss: 0.02704609549138695
# SMA PG Loss: -0.0033012956683523952
# SMA V Loss: 0.04080028772354126
# Max reward: 21.0
# ---------- 4470 / 4882 ----------
# Num Games: 2679
# Num Frames: 4576256
# FPS: 115
# ETA: 1:00:59
# SMA Length: 1807.74
# SMA Reward: 17.99
# SMA Entropy: 1.042727427482605
# SMA Clip %: 0.03140625
# SMA Loss: 0.027114520007744433
# SMA PG Loss: -0.00335738975321874
# SMA V Loss: 0.04089918374083936
# Max reward: 21.0
# ---------- 4485 / 4882 ----------
# Num Games: 2688
# Num Frames: 4591616
# FPS: 116
# ETA: 0:58:37
# SMA Length: 1809.05
# SMA Reward: 17.97
# SMA Entropy: 1.0458505854010582
# SMA Clip %: 0.03064453125
# SMA Loss: 0.02716916676145047
# SMA PG Loss: -0.0033506654552184047
# SMA V Loss: 0.04097833775915206
# Max reward: 21.0
# ---------- 4500 / 4882 ----------
# Num Games: 2696
# Num Frames: 4606976
# FPS: 116
# ETA: 0:56:16
# SMA Length: 1813.96
# SMA Reward: 17.94
# SMA Entropy: 1.046305426955223
# SMA Clip %: 0.0301953125
# SMA Loss: 0.027463037227280437
# SMA PG Loss: -0.0032758534396998586
# SMA V Loss: 0.04120194460265338
# Max reward: 21.0
# ---------- 4515 / 4882 ----------
# Num Games: 2704
# Num Frames: 4622336
# FPS: 116
# ETA: 0:53:55
# SMA Length: 1813.34
# SMA Reward: 17.94
# SMA Entropy: 1.0540066847205163
# SMA Clip %: 0.02873046875
# SMA Loss: 0.027721070419065654
# SMA PG Loss: -0.0032165650860406458
# SMA V Loss: 0.041477701971307394
# Max reward: 21.0
# ---------- 4530 / 4882 ----------
# Num Games: 2713
# Num Frames: 4637696
# FPS: 117
# ETA: 0:51:36
# SMA Length: 1806.42
# SMA Reward: 18.065
# SMA Entropy: 1.0621722039580346
# SMA Clip %: 0.02486328125
# SMA Loss: 0.02778899190016091
# SMA PG Loss: -0.0031850924901664257
# SMA V Loss: 0.041595806032419205
# Max reward: 21.0
# ---------- 4545 / 4882 ----------
# Num Games: 2722
# Num Frames: 4653056
# FPS: 117
# ETA: 0:49:17
# SMA Length: 1792.57
# SMA Reward: 18.305
# SMA Entropy: 1.0683046883344651
# SMA Clip %: 0.02150390625
# SMA Loss: 0.02774054419249296
# SMA PG Loss: -0.0031489542499184607
# SMA V Loss: 0.04157254491001368
# Max reward: 21.0
# ---------- 4560 / 4882 ----------
# Num Games: 2730
# Num Frames: 4668416
# FPS: 117
# ETA: 0:46:59
# SMA Length: 1789.78
# SMA Reward: 18.35
# SMA Entropy: 1.0742570355534553
# SMA Clip %: 0.0168359375
# SMA Loss: 0.026890966473147274
# SMA PG Loss: -0.0030786385224200784
# SMA V Loss: 0.040712174912914637
# Max reward: 21.0
# ---------- 4575 / 4882 ----------
# Num Games: 2738
# Num Frames: 4683776
# FPS: 117
# ETA: 0:44:41
# SMA Length: 1790.995
# SMA Reward: 18.35
# SMA Entropy: 1.0773975887894631
# SMA Clip %: 0.01560546875
# SMA Loss: 0.026870821481570602
# SMA PG Loss: -0.003169322246685624
# SMA V Loss: 0.040814119214192035
# Max reward: 21.0
# ---------- 4590 / 4882 ----------
# Num Games: 2746
# Num Frames: 4699136
# FPS: 118
# ETA: 0:42:24
# SMA Length: 1791.87
# SMA Reward: 18.32
# SMA Entropy: 1.0799891331791878
# SMA Clip %: 0.01544921875
# SMA Loss: 0.027288165865465997
# SMA PG Loss: -0.0031360414228402077
# SMA V Loss: 0.04122409823350608
# Max reward: 21.0
# ---------- 4605 / 4882 ----------
# Num Games: 2755
# Num Frames: 4714496
# FPS: 118
# ETA: 0:40:08
# SMA Length: 1796.77
# SMA Reward: 18.25
# SMA Entropy: 1.0810550144314766
# SMA Clip %: 0.01515625
# SMA Loss: 0.027339683836326
# SMA PG Loss: -0.003181516614276916
# SMA V Loss: 0.0413317502848804
# Max reward: 21.0
# ---------- 4620 / 4882 ----------
# Num Games: 2763
# Num Frames: 4729856
# FPS: 118
# ETA: 0:37:53
# SMA Length: 1803.485
# SMA Reward: 18.16
# SMA Entropy: 1.0809594404697418
# SMA Clip %: 0.009765625
# SMA Loss: 0.02768083050381392
# SMA PG Loss: -0.003030893381219357
# SMA V Loss: 0.04152131796814501
# Max reward: 21.0
# ---------- 4635 / 4882 ----------
# Num Games: 2772
# Num Frames: 4745216
# FPS: 119
# ETA: 0:35:38
# SMA Length: 1803.015
# SMA Reward: 18.17
# SMA Entropy: 1.0720789137482643
# SMA Clip %: 0.011640625
# SMA Loss: 0.027440316299907862
# SMA PG Loss: -0.003121809472795576
# SMA V Loss: 0.04128291457891464
# Max reward: 21.0
# ---------- 4650 / 4882 ----------
# Num Games: 2780
# Num Frames: 4760576
# FPS: 119
# ETA: 0:33:24
# SMA Length: 1801.25
# SMA Reward: 18.175
# SMA Entropy: 1.061833257675171
# SMA Clip %: 0.01431640625
# SMA Loss: 0.027349682771600783
# SMA PG Loss: -0.002956884561572224
# SMA V Loss: 0.04092489957809448
# Max reward: 21.0
# ---------- 4665 / 4882 ----------
# Num Games: 2790
# Num Frames: 4775936
# FPS: 119
# ETA: 0:31:11
# SMA Length: 1793.99
# SMA Reward: 18.27
# SMA Entropy: 1.0598569947481156
# SMA Clip %: 0.015234375
# SMA Loss: 0.026678968276828526
# SMA PG Loss: -0.002936394226271659
# SMA V Loss: 0.040213932124897836
# Max reward: 21.0
# ---------- 4680 / 4882 ----------
# Num Games: 2799
# Num Frames: 4791296
# FPS: 120
# ETA: 0:28:58
# SMA Length: 1799.235
# SMA Reward: 18.205
# SMA Entropy: 1.067938404083252
# SMA Clip %: 0.01529296875
# SMA Loss: 0.027067001699469982
# SMA PG Loss: -0.002992088438477367
# SMA V Loss: 0.040738473841920496
# Max reward: 21.0
# ---------- 4695 / 4882 ----------
# Num Games: 2806
# Num Frames: 4806656
# FPS: 120
# ETA: 0:26:46
# SMA Length: 1806.125
# SMA Reward: 18.075
# SMA Entropy: 1.0711172235012054
# SMA Clip %: 0.0162109375
# SMA Loss: 0.027442399957217277
# SMA PG Loss: -0.0030515985772944986
# SMA V Loss: 0.04120517047122121
# Max reward: 21.0
# ---------- 4710 / 4882 ----------
# Num Games: 2816
# Num Frames: 4822016
# FPS: 120
# ETA: 0:24:35
# SMA Length: 1814.705
# SMA Reward: 18.235
# SMA Entropy: 1.0666390135884285
# SMA Clip %: 0.021875
# SMA Loss: 0.027077095550484955
# SMA PG Loss: -0.0031209268257953227
# SMA V Loss: 0.0408644122350961
# Max reward: 21.0
# ---------- 4725 / 4882 ----------
# Num Games: 2825
# Num Frames: 4837376
# FPS: 120
# ETA: 0:22:24
# SMA Length: 1819.555
# SMA Reward: 18.19
# SMA Entropy: 1.067567946910858
# SMA Clip %: 0.02232421875
# SMA Loss: 0.026977307279594243
# SMA PG Loss: -0.0031826305901631715
# SMA V Loss: 0.04083561708219349
# Max reward: 21.0
# ---------- 4740 / 4882 ----------
# Num Games: 2833
# Num Frames: 4852736
# FPS: 121
# ETA: 0:20:14
# SMA Length: 1821.675
# SMA Reward: 18.15
# SMA Entropy: 1.0731814748048782
# SMA Clip %: 0.02185546875
# SMA Loss: 0.027307377657853068
# SMA PG Loss: -0.0032088280748575927
# SMA V Loss: 0.041248020278289915
# Max reward: 21.0
# ---------- 4755 / 4882 ----------
# Num Games: 2841
# Num Frames: 4868096
# FPS: 121
# ETA: 0:18:05
# SMA Length: 1820.455
# SMA Reward: 18.17
# SMA Entropy: 1.0734905096888543
# SMA Clip %: 0.02287109375
# SMA Loss: 0.027542396765202284
# SMA PG Loss: -0.0032259107194840906
# SMA V Loss: 0.041503212423995135
# Max reward: 21.0
# ---------- 4770 / 4882 ----------
# Num Games: 2849
# Num Frames: 4883456
# FPS: 121
# ETA: 0:15:56
# SMA Length: 1821.07
# SMA Reward: 18.155
# SMA Entropy: 1.062538594007492
# SMA Clip %: 0.0237109375
# SMA Loss: 0.027261980925686657
# SMA PG Loss: -0.003264856031164527
# SMA V Loss: 0.04115222278051078
# Max reward: 21.0
# ---------- 4785 / 4882 ----------
# Num Games: 2858
# Num Frames: 4898816
# FPS: 122
# ETA: 0:13:48
# SMA Length: 1817.22
# SMA Reward: 18.185
# SMA Entropy: 1.0503789740800857
# SMA Clip %: 0.0254296875
# SMA Loss: 0.027178237563930452
# SMA PG Loss: -0.0032868772512301804
# SMA V Loss: 0.04096890444867313
# Max reward: 21.0
# ---------- 4800 / 4882 ----------
# Num Games: 2866
# Num Frames: 4914176
# FPS: 122
# ETA: 0:11:41
# SMA Length: 1817.045
# SMA Reward: 18.2
# SMA Entropy: 1.0450751531124114
# SMA Clip %: 0.02638671875
# SMA Loss: 0.026820739824324848
# SMA PG Loss: -0.003414938726928085
# SMA V Loss: 0.04068642994388938
# Max reward: 21.0
# ---------- 4815 / 4882 ----------
# Num Games: 2874
# Num Frames: 4929536
# FPS: 122
# ETA: 0:09:34
# SMA Length: 1813.97
# SMA Reward: 18.265
# SMA Entropy: 1.043123254776001
# SMA Clip %: 0.0263671875
# SMA Loss: 0.026331248101778327
# SMA PG Loss: -0.0033807823969982565
# SMA V Loss: 0.04014326282776892
# Max reward: 21.0
# ---------- 4830 / 4882 ----------
# Num Games: 2883
# Num Frames: 4944896
# FPS: 123
# ETA: 0:07:27
# SMA Length: 1812.405
# SMA Reward: 18.285
# SMA Entropy: 1.0567842423915863
# SMA Clip %: 0.0235546875
# SMA Loss: 0.026245393985882402
# SMA PG Loss: -0.003449100002180785
# SMA V Loss: 0.040262336200103166
# Max reward: 21.0
# ---------- 4845 / 4882 ----------
# Num Games: 2891
# Num Frames: 4960256
# FPS: 123
# ETA: 0:05:22
# SMA Length: 1814.64
# SMA Reward: 18.235
# SMA Entropy: 1.0673119711875916
# SMA Clip %: 0.01951171875
# SMA Loss: 0.026354167773388327
# SMA PG Loss: -0.0035457632062025368
# SMA V Loss: 0.04057305050082505
# Max reward: 21.0
# ---------- 4860 / 4882 ----------
# Num Games: 2900
# Num Frames: 4975616
# FPS: 123
# ETA: 0:03:17
# SMA Length: 1813.44
# SMA Reward: 18.24
# SMA Entropy: 1.0738511729240416
# SMA Clip %: 0.0176953125
# SMA Loss: 0.026762843704782425
# SMA PG Loss: -0.0036108422582037747
# SMA V Loss: 0.04111219746991992
# Max reward: 21.0
# ---------- 4875 / 4882 ----------
# Num Games: 2908
# Num Frames: 4990976
# FPS: 123
# ETA: 0:01:12
# SMA Length: 1812.98
# SMA Reward: 18.26
# SMA Entropy: 1.0679876670241355
# SMA Clip %: 0.01794921875
# SMA Loss: 0.026425868263468145
# SMA PG Loss: -0.0036860011867247524
# SMA V Loss: 0.040791745912283656
# Max reward: 21.0

# %% [markdown]
# # Save final model and log

# %%
save_checkpoint('FINAL')
T.save(logger.log, SAVE_PATH+'FINAL.'+ENV_NAME+'.log')
T.save(ac, SAVE_PATH+'FINAL.'+ENV_NAME+'.MODEL')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:360: UserWarning: Couldn't retrieve source code for container of type AC. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %% [markdown]
# # Plot results

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set()

# %%
def plot_log(log, ylabel):
    # compute rolling avg and std
    df = pd.DataFrame(log, columns =['Frames', 'Iters', ylabel])
    sma_y = df[ylabel].rolling(500).mean()
    std_y = df[ylabel].rolling(500).std()
    
    # plot with seaborn
    fig, ax = plt.subplots(figsize=(5,5))
    ax.set_xlabel('Frames')
    ax.set_ylabel(ylabel)
    clrs = sns.color_palette("husl", 8)

    # fill standard deviation
    ax.plot(df['Frames'], sma_y, label=ylabel, c=clrs[0])
    ax.fill_between(df['Frames'], sma_y-std_y,  sma_y+std_y, 
                    alpha=0.3, facecolor=clrs[0]) 
    ax.legend(loc='upper left')
    plt.savefig(SAVE_PATH+ENV_NAME+'.'+ylabel+'.plt.png', 
                dpi=300, pad_inches=0)
    plt.show()

plot_log(logger.log['ep_r'], 'Reward')
plot_log(logger.log['ep_l'], 'Length')
plot_log(logger.log['loss'], 'Loss')
plot_log(logger.log['ent'], 'Entropy')

# %%
fig_all, ax_all = plt.subplots(2,2, figsize=(8,8))

## REWARD 
df = pd.DataFrame(logger.log['ep_r'], columns =['Frames', 'Iters', 'rwd'])
sma_y = df['rwd'].rolling(500).mean()
std_y = df['rwd'].rolling(500).std()

ax_all[0][0].set_ylabel('Reward')
clrs = sns.color_palette("husl", 8)

# fill standard deviation
ax_all[0][0].plot(df['Frames'], sma_y, label='Episode Reward', c=clrs[0])
ax_all[0][0].fill_between(df['Frames'], sma_y-std_y,  sma_y+std_y, 
                alpha=0.3, facecolor=clrs[0])

# make x axis nice
ax_all[0][0].set_xticklabels('')


## LENGTH 
df = pd.DataFrame(logger.log['ep_l'], columns =['Frames', 'Iters', 'Len'])
sma_y = df['Len'].rolling(500).mean()
std_y = df['Len'].rolling(500).std()

ax_all[0][1].set_ylabel('Length')
ax_all[0][1].yaxis.tick_right()
clrs = sns.color_palette("husl", 8)

# fill standard deviation
ax_all[0][1].plot(df['Frames'], sma_y, label='Episode Length', c=clrs[0])
ax_all[0][1].fill_between(df['Frames'], sma_y-std_y,  sma_y+std_y, 
                alpha=0.3, facecolor=clrs[0])

# make x axis nice
ax_all[0][1].set_xticklabels('')


## ENTROPY 
df = pd.DataFrame(logger.log['ent'], columns =['Frames', 'Iters', 'ent'])
sma_y = df['ent'].rolling(500).mean()
std_y = df['ent'].rolling(500).std()

ax_all[1][0].set_xlabel('Frames')
ax_all[1][0].set_ylabel('Entropy')
clrs = sns.color_palette("husl", 8)

# fill standard deviation
ax_all[1][0].plot(df['Frames'], sma_y, label='Entropy', c=clrs[0])
ax_all[1][0].fill_between(df['Frames'], sma_y-std_y,  sma_y+std_y, 
                alpha=0.3, facecolor=clrs[0])

# make x axis nice
xlabels = [f'{int(x)}M' for x in ax_all[1][0].get_xticks()/1e6]
ax_all[1][0].set_xticklabels(xlabels)


## LOSS 
df = pd.DataFrame(logger.log['loss'], columns =['Frames', 'Iters', 'Loss'])
sma_y = df['Loss'].rolling(500).mean()
std_y = df['Loss'].rolling(500).std()

ax_all[1][1].set_xlabel('Frames')
ax_all[1][1].set_ylabel('Loss')
ax_all[1][1].yaxis.tick_right()
clrs = sns.color_palette("husl", 8)

# fill standard deviation
ax_all[1][1].plot(df['Frames'], sma_y, label='Loss', c=clrs[0])
ax_all[1][1].fill_between(df['Frames'], sma_y-std_y,  sma_y+std_y, 
                alpha=0.3, facecolor=clrs[0])

# make x axis nice
xlabels = [f'{int(x)}M' for x in ax_all[1][1].get_xticks()/1e6]
ax_all[1][1].set_xticklabels(xlabels)

plt.savefig(SAVE_PATH+ENV_NAME+'_plot_thesis.png', 
            dpi=300, pad_inches=0, bbox_inches = 'tight')

plt.show()
