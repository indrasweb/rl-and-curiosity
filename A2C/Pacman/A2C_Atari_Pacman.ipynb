# %%
# !pip install stable-baselines==2.9.0

# %%
import datetime
from time import time

import numpy as np

import torch as T
from torch.autograd import Variable
import torch.nn as nn
from torch.distributions import Categorical
from torch.optim import Adam
from torch.optim.lr_scheduler import LambdaLR

from stable_baselines.common.misc_util import set_global_seeds
from stable_baselines.common.cmd_util import make_atari_env
from stable_baselines.common.vec_env import VecFrameStack, VecNormalize
from stable_baselines.common.running_mean_std import RunningMeanStd

from google.colab import drive
from itertools import count

# %%
ENV_NAME = 'MsPacmanNoFrameskip-v4'
SAVE_PATH = '/content/gdrive/My Drive/Colab Notebooks/A2C/'

TOTAL_FRAMES = 5e6  # 5 million frames
ROLLOUT_LENGTH = 5  # transitions in each rollout
NENV = 8            # parallel environments, increase to decorrolate batches
GAMMA = 0.99        # reward discounting coefficient
SEED = 420          # blaze it
STEPS_PER_ROLLOUT = ROLLOUT_LENGTH*NENV
TOTAL_UPDATES = int(TOTAL_FRAMES // STEPS_PER_ROLLOUT)
DEVICE = T.device('cuda' if T.cuda.is_available() else 'cpu')

set_global_seeds(SEED)

# %%
drive.mount('/content/gdrive')

# %%
class Logger:

    def __init__(self, print_rate=250):
        self.log = {'ep_r':[], 'ep_l':[], 'loss':[], 'pgloss':[], 
                    'vloss':[], 'ent':[]}
        self.n_ep = 0              # total games/episodes
        self.n_update = 1          # total weight updates
        self.n_frames = 0          # env steps (total from checkpoint)
        self.run_frames = 0        # env steps (for this run)
        self.max_rwd = -np.inf     # max rwd out of all games played
        self.start_time = time()   # time we started *this* run
        self.last_checkpoint = 0   # total_frames at last checkpoint
        self.print_rate = print_rate

    def eta(self):  # get hh:mm:ss left to train
        elapsed_time = time() - self.start_time
        frames_left = TOTAL_FRAMES - self.n_frames
        sec_per_frame = elapsed_time / self.n_frames
        sec_left = int(frames_left * sec_per_frame)
        eta_str = str(datetime.timedelta(seconds=sec_left))
        return eta_str

    def fps(self):  # get frames per second
        elapsed_time = time() - self.start_time
        fps = int(self.run_frames / elapsed_time)
        return fps

    def sma(self, x):  # simple moving average
        div = 200 if len(x) > 200 else len(x)
        return sum(list(zip(*x[-div:]))[-1])/div

    def print_log(self):
        fps = self.fps()
        eta = self.eta()
        print('-'*10, self.n_update, '/', TOTAL_UPDATES, '-'*10)
        print('Num Games:', self.n_ep)
        print('Num Frames:', self.n_frames)
        print('FPS:', fps)
        print('ETA:', eta)
        print('SMA Length:', self.sma(self.log['ep_l']))
        print('SMA Reward:', self.sma(self.log['ep_r']))
        print('SMA Entropy:', self.sma(self.log['ent']))
        print('SMA Loss:', self.sma(self.log['loss']))
        print('SMA PG Loss:', self.sma(self.log['pgloss']))
        print('SMA V Loss:', self.sma(self.log['vloss']))
        print('Max reward:', self.max_rwd)

    def record(self, ep, loss, pgloss, vloss, ent):
        
        self.n_update += 1
        self.n_frames += STEPS_PER_ROLLOUT
        self.run_frames += STEPS_PER_ROLLOUT
        fr = (self.n_frames, self.n_update)

        # stats about finished episodes/games
        for l, r in zip(ep['l'], ep['r']):
            self.log['ep_l'].append(fr+(l,))
            self.log['ep_r'].append(fr+(r,))
            if r > self.max_rwd: self.max_rwd = r
            self.n_ep += 1
             
        # nn training statistics
        self.log['loss'].append(fr+(loss,))
        self.log['pgloss'].append(fr+(pgloss,))
        self.log['vloss'].append(fr+(vloss,))
        self.log['ent'].append(fr+(ent,))
        
        # print log
        if self.n_update % self.print_rate == 0:
            self.print_log()

# %%
class AC(nn.Module):
  
    def __init__(self, input_shape, num_actions):
        super().__init__()
        h, w, c = input_shape

        self.conv = nn.Sequential(
            nn.Conv2d(c, 32, 8, 4),
            nn.ReLU(True),
            nn.Conv2d(32, 64, 4, 2),
            nn.ReLU(True),
            nn.Conv2d(64, 64, 3, 1),
            nn.ReLU(True),
        )
        
        f = self.conv_size(self.conv, (c,h,w))

        self.flat = nn.Sequential(
            nn.Flatten(),
            nn.Linear(f, 512),
            nn.ReLU(True)
        )

        self.backbone = nn.Sequential(self.conv, self.flat)
        self.actor = nn.Linear(512, num_actions)
        self.critic = nn.Linear(512, 1)

    def conv_size(self, net, in_shape):
        x = Variable(T.rand(1, *in_shape))
        o = net(x)
        b = (-1, o.size(1), o.size(2), o.size(3))
        return o.data.view(1, -1).size(1)

    def forward(self, x):
        latent = self.backbone(x)
        return self.actor(latent), self.critic(latent)

# %%
def ob_to_torch(x):
    x = np.moveaxis(x, -1, 1)
    x = T.from_numpy(x).float()
    x = x.to(DEVICE)
    return x

def rollout_generator(env, policy):

    ob = ob_to_torch(env.reset())
    mb = {'obs':[], 'act':[], 'rwd':[], 'done':[], 'val':[]}
    ep = {'l':[], 'r':[]}  # len & total reward of done eps 
    
    for step in count(1):

        # we compute gradients in the train loop
        with T.no_grad():
            logits, val = policy(ob)
            dist = Categorical(logits=logits)
            action = dist.sample()
        
        new_ob, rwd, done, info = env.step(action)
        
        # store transition
        mb['obs'].append(ob)
        mb['act'].append(action)
        mb['rwd'].append(T.from_numpy(rwd))
        mb['val'].append(val.view(-1))
        mb['done'].append(T.from_numpy(done))
        for t in info:
            if t.get('episode'):
                ep['l'].append(t['episode']['l'])
                ep['r'].append(t['episode']['r'])

        ob = ob_to_torch(new_ob)

        if step % ROLLOUT_LENGTH != 0:
            continue

        ########################################################
        ###         Flatten rollout & assign credit          ###
        ########################################################
        ### Credit is bootstrapped from our critic (value    ###
        ### function) if the episode is not terminal. This   ###
        ### bootstrapped credit comes from the estimated     ###
        ### value of the *next* state, making it TD(0).      ###
        ########################################################

        for k in mb.keys():
            mb[k] = T.stack(mb[k]).to(DEVICE)

        # bootstrap from value function - TD(0)
        with T.no_grad():
            last_val = policy(ob)[1].view(-1) * ~mb['done'][-1]
            mb['rwd'][-1] += GAMMA * last_val

        # discount (bootstrapped) rewards
        for i in reversed(range(ROLLOUT_LENGTH-1)):
            mb['rwd'][i] += GAMMA * mb['rwd'][i+1] * ~mb['done'][i]

        # flatten to (NENV*ROLLOUT_LENGTH, ...)
        for k in mb.keys():
            s = mb[k].size()
            mb[k] = mb[k].view(STEPS_PER_ROLLOUT, *s[2:])
        
        yield mb, ep
        mb = {'obs':[], 'act':[], 'rwd':[], 'done':[], 'val':[]}
        ep = {'l':[], 'r':[]}

# %%
def save_checkpoint(checkpoint_id):
    checkpoint = {
        'env': env,
        'ac': ac.state_dict(),
        'ac_opt': ac_optimizer.state_dict(),
        'logger': logger
    }
    X = str(checkpoint_id)
    T.save(checkpoint, SAVE_PATH+X+'.'+ENV_NAME+'.checkpoint')

# %%
def load_checkpoint(file_name):
    checkpoint = T.load(file_name)
    
    venv = make_atari_env(ENV_NAME, num_env=NENV, seed=SEED)
    venv = VecFrameStack(venv, n_stack=4)
    env = checkpoint['env']
    env.set_venv(venv)
    in_dim = env.observation_space.shape
    policy_dim = env.action_space.n

    ac = AC(in_dim, policy_dim).to(DEVICE)
    ac.load_state_dict(checkpoint['ac'])
    ac_optimizer = Adam(ac.parameters(), 7e-4, eps=1e-5)
    ac_optimizer.load_state_dict(checkpoint['ac_opt'])

    logger = checkpoint['logger']

    return env, ac, ac_optimizer, logger

# %%
def new_run():

    # setup parallelised gym environments (MaxAndSkip=4 by default)
    env = make_atari_env(ENV_NAME, num_env=NENV, seed=SEED)
    env._max_episode_steps = 4500*4
    env = VecFrameStack(env, n_stack=4)
    env = VecNormalize(env, norm_reward=False, clip_reward=1e5, gamma=1.0)
    in_dim = env.observation_space.shape
    policy_dim = env.action_space.n

    # get actor + critic
    ac = AC(in_dim, policy_dim).to(DEVICE)
    ac_optimizer = Adam(ac.parameters(), 7e-4, eps=1e-5)

    logger = Logger()

    return env, ac, ac_optimizer, logger

# %%
env, ac, ac_optimizer, logger = new_run()
# env, ac, ac_optimizer, logger = load_checkpoint(SAVE_PATH+'FINAL.MsPacmanNoFrameskip-v4.checkpoint')

# %%
rollouts = rollout_generator(env, ac)
scheduler = LambdaLR(ac_optimizer, lambda i: 1 - i / TOTAL_UPDATES)

for i_update in range(logger.n_update, TOTAL_UPDATES):

    mb, ep = next(rollouts)

    # calculate advantange
    logits, val = ac(mb['obs'])
    dist = Categorical(logits=logits)
    ent = dist.entropy().mean()
    logp = dist.log_prob(mb['act'])
    adv = mb['rwd'] - mb['val']
    
    # calculate losses (soft ac with entropy)
    vloss = (val.view(-1) - mb['rwd']).pow(2).mean()
    pgloss = -(adv * logp).mean()
    loss = pgloss + 0.5*vloss - 0.01*ent
    
    # update policy
    ac_optimizer.zero_grad()
    loss.backward()
    nn.utils.clip_grad_norm_(ac.parameters(), 0.5)
    ac_optimizer.step()
    scheduler.step(i_update)

    logger.record(ep, loss.item(), pgloss.item(), vloss.item(), ent.item())
    
    # make a checkpoint every 1m frames
    if logger.n_frames - logger.last_checkpoint > 1e6:
        save_checkpoint(logger.n_frames)
        logger.last_checkpoint = logger.n_frames

save_checkpoint('FINAL')
# Out:
# Streaming output truncated to the last 5000 lines.
# SMA Length: 613.395
# SMA Reward: 901.25
# SMA Entropy: 0.9041864797472954
# SMA Loss: 1.0691433157259598
# SMA PG Loss: 0.020331684488919564
# SMA V Loss: 2.115707000270486
# Max reward: 3940.0
# ---------- 21250 / 125000 ----------
# Num Games: 1373
# Num Frames: 849960
# FPS: 348
# ETA: 3:18:25
# SMA Length: 611.37
# SMA Reward: 904.7
# SMA Entropy: 0.7884233023226261
# SMA Loss: 1.0721035373257473
# SMA PG Loss: 0.011505595784401522
# SMA V Loss: 2.136964345537126
# Max reward: 3940.0
# ---------- 21500 / 125000 ----------
# Num Games: 1389
# Num Frames: 859960
# FPS: 348
# ETA: 3:17:53
# SMA Length: 620.795
# SMA Reward: 922.75
# SMA Entropy: 0.9210428084433079
# SMA Loss: 0.9052701878314838
# SMA PG Loss: 0.03591794114705408
# SMA V Loss: 1.7571253467723726
# Max reward: 3940.0
# ---------- 21750 / 125000 ----------
# Num Games: 1403
# Num Frames: 869960
# FPS: 348
# ETA: 3:17:22
# SMA Length: 626.595
# SMA Reward: 939.25
# SMA Entropy: 0.9077097782492638
# SMA Loss: 0.8796952747157775
# SMA PG Loss: 0.015082844411954283
# SMA V Loss: 1.747379054352641
# Max reward: 3940.0
# ---------- 22000 / 125000 ----------
# Num Games: 1419
# Num Frames: 879960
# FPS: 348
# ETA: 3:16:51
# SMA Length: 623.495
# SMA Reward: 926.45
# SMA Entropy: 1.0006908157467842
# SMA Loss: 0.7714289338607341
# SMA PG Loss: 0.08191998060894548
# SMA V Loss: 1.399031735509634
# Max reward: 3940.0
# ---------- 22250 / 125000 ----------
# Num Games: 1434
# Num Frames: 889960
# FPS: 348
# ETA: 3:16:21
# SMA Length: 624.09
# SMA Reward: 914.8
# SMA Entropy: 1.0357067877054214
# SMA Loss: 0.9618666201783345
# SMA PG Loss: 0.0949473016517004
# SMA V Loss: 1.7545527608320117
# Max reward: 3940.0
# ---------- 22500 / 125000 ----------
# Num Games: 1453
# Num Frames: 899960
# FPS: 348
# ETA: 3:15:52
# SMA Length: 624.525
# SMA Reward: 908.6
# SMA Entropy: 0.9200491397082806
# SMA Loss: 0.8447470546420663
# SMA PG Loss: 0.012716414248279762
# SMA V Loss: 1.6824622716754676
# Max reward: 3940.0
# ---------- 22750 / 125000 ----------
# Num Games: 1470
# Num Frames: 909960
# FPS: 348
# ETA: 3:15:22
# SMA Length: 623.28
# SMA Reward: 903.75
# SMA Entropy: 0.8460356986522675
# SMA Loss: 0.8936480342783034
# SMA PG Loss: 0.033827329863561316
# SMA V Loss: 1.7365621315315365
# Max reward: 3940.0
# ---------- 23000 / 125000 ----------
# Num Games: 1484
# Num Frames: 919960
# FPS: 348
# ETA: 3:14:52
# SMA Length: 635.39
# SMA Reward: 916.1
# SMA Entropy: 0.8239992946386338
# SMA Loss: 0.940782426071819
# SMA PG Loss: 0.005687412932747975
# SMA V Loss: 1.88667002171278
# Max reward: 3940.0
# ---------- 23250 / 125000 ----------
# Num Games: 1499
# Num Frames: 929960
# FPS: 348
# ETA: 3:14:22
# SMA Length: 642.405
# SMA Reward: 916.7
# SMA Entropy: 0.8441303811967373
# SMA Loss: 1.0404626057017594
# SMA PG Loss: 0.02872344189020623
# SMA V Loss: 2.04036095418036
# Max reward: 3940.0
# ---------- 23500 / 125000 ----------
# Num Games: 1515
# Num Frames: 939960
# FPS: 348
# ETA: 3:13:53
# SMA Length: 634.705
# SMA Reward: 886.4
# SMA Entropy: 0.9726146693527699
# SMA Loss: 1.1336322436947375
# SMA PG Loss: 0.08022609433508478
# SMA V Loss: 2.126264609731734
# Max reward: 3940.0
# ---------- 23750 / 125000 ----------
# Num Games: 1527
# Num Frames: 949960
# FPS: 349
# ETA: 3:13:22
# SMA Length: 643.735
# SMA Reward: 900.25
# SMA Entropy: 0.9825074169039726
# SMA Loss: 1.0408120464300736
# SMA PG Loss: 0.09340399465057998
# SMA V Loss: 1.9144662749767303
# Max reward: 3940.0
# ---------- 24000 / 125000 ----------
# Num Games: 1543
# Num Frames: 959960
# FPS: 349
# ETA: 3:12:53
# SMA Length: 643.985
# SMA Reward: 897.0
# SMA Entropy: 0.7733339540660381
# SMA Loss: 0.897290278042201
# SMA PG Loss: 0.04304011610998714
# SMA V Loss: 1.7239670025557279
# Max reward: 3940.0
# ---------- 24250 / 125000 ----------
# Num Games: 1558
# Num Frames: 969960
# FPS: 349
# ETA: 3:12:22
# SMA Length: 650.95
# SMA Reward: 910.45
# SMA Entropy: 0.9393437775969505
# SMA Loss: 0.6904316593334079
# SMA PG Loss: 0.013584601859620307
# SMA V Loss: 1.3724809921160341
# Max reward: 3940.0
# ---------- 24500 / 125000 ----------
# Num Games: 1575
# Num Frames: 979960
# FPS: 349
# ETA: 3:11:51
# SMA Length: 649.455
# SMA Reward: 906.95
# SMA Entropy: 0.9324164895713329
# SMA Loss: 0.9094152434496209
# SMA PG Loss: 0.030912294696099706
# SMA V Loss: 1.7756542387604712
# Max reward: 3940.0
# ---------- 24750 / 125000 ----------
# Num Games: 1593
# Num Frames: 989960
# FPS: 349
# ETA: 3:11:21
# SMA Length: 642.695
# SMA Reward: 902.9
# SMA Entropy: 0.7817459993064404
# SMA Loss: 1.1635818321444094
# SMA PG Loss: 0.02218757938084309
# SMA V Loss: 2.2984234428405763
# Max reward: 3940.0
# ---------- 25000 / 125000 ----------
# Num Games: 1609
# Num Frames: 999960
# FPS: 349
# ETA: 3:10:49
# SMA Length: 632.315
# SMA Reward: 893.7
# SMA Entropy: 0.7850612387061119
# SMA Loss: 0.8138674989854917
# SMA PG Loss: 0.006934271443606121
# SMA V Loss: 1.6295676808804274
# Max reward: 3940.0
# ---------- 25250 / 125000 ----------
# Num Games: 1626
# Num Frames: 1009960
# FPS: 349
# ETA: 3:10:22
# SMA Length: 630.455
# SMA Reward: 894.2
# SMA Entropy: 0.8658630041778088
# SMA Loss: 0.9358654846437275
# SMA PG Loss: 0.0270040591689758
# SMA V Loss: 1.8350401151925326
# Max reward: 3940.0
# ---------- 25500 / 125000 ----------
# Num Games: 1641
# Num Frames: 1019960
# FPS: 349
# ETA: 3:09:52
# SMA Length: 636.25
# SMA Reward: 901.15
# SMA Entropy: 0.8747732995450497
# SMA Loss: 0.9485699583520182
# SMA PG Loss: 0.051720259809517305
# SMA V Loss: 1.811194867566228
# Max reward: 3940.0
# ---------- 25750 / 125000 ----------
# Num Games: 1656
# Num Frames: 1029960
# FPS: 349
# ETA: 3:09:22
# SMA Length: 643.375
# SMA Reward: 906.2
# SMA Entropy: 0.8736892054975033
# SMA Loss: 0.967047253982164
# SMA PG Loss: 0.027604201533831654
# SMA V Loss: 1.89635989010334
# Max reward: 3940.0
# ---------- 26000 / 125000 ----------
# Num Games: 1667
# Num Frames: 1039960
# FPS: 349
# ETA: 3:08:52
# SMA Length: 654.71
# SMA Reward: 929.7
# SMA Entropy: 0.8255072481930256
# SMA Loss: 0.7403627587435767
# SMA PG Loss: -0.03417232631054503
# SMA V Loss: 1.565580326616764
# Max reward: 3940.0
# ---------- 26250 / 125000 ----------
# Num Games: 1682
# Num Frames: 1049960
# FPS: 349
# ETA: 3:08:23
# SMA Length: 651.425
# SMA Reward: 936.65
# SMA Entropy: 0.6012369603663683
# SMA Loss: 0.8403587466001045
# SMA PG Loss: -0.022192785263323456
# SMA V Loss: 1.737127783149481
# Max reward: 3940.0
# ---------- 26500 / 125000 ----------
# Num Games: 1697
# Num Frames: 1059960
# FPS: 349
# ETA: 3:07:54
# SMA Length: 650.32
# SMA Reward: 940.3
# SMA Entropy: 0.6015208781510591
# SMA Loss: 0.9054703737841919
# SMA PG Loss: -0.012273490577936173
# SMA V Loss: 1.8475181580334903
# Max reward: 3940.0
# ---------- 26750 / 125000 ----------
# Num Games: 1713
# Num Frames: 1069960
# FPS: 349
# ETA: 3:07:24
# SMA Length: 658.945
# SMA Reward: 964.3
# SMA Entropy: 0.6520839244127273
# SMA Loss: 0.9612443543528206
# SMA PG Loss: 0.026824651221277238
# SMA V Loss: 1.881881069727242
# Max reward: 3940.0
# ---------- 27000 / 125000 ----------
# Num Games: 1726
# Num Frames: 1079960
# FPS: 349
# ETA: 3:06:55
# SMA Length: 656.1
# SMA Reward: 965.75
# SMA Entropy: 0.7289097122102975
# SMA Loss: 0.935458600348793
# SMA PG Loss: -0.0012411852362856734
# SMA V Loss: 1.8879777754843234
# Max reward: 3940.0
# ---------- 27250 / 125000 ----------
# Num Games: 1740
# Num Frames: 1089960
# FPS: 349
# ETA: 3:06:25
# SMA Length: 657.145
# SMA Reward: 968.55
# SMA Entropy: 0.6208912543207407
# SMA Loss: 1.1828445339738392
# SMA PG Loss: 0.022314659008407033
# SMA V Loss: 2.3334775876998903
# Max reward: 3940.0
# ---------- 27500 / 125000 ----------
# Num Games: 1755
# Num Frames: 1099960
# FPS: 349
# ETA: 3:05:56
# SMA Length: 661.71
# SMA Reward: 969.2
# SMA Entropy: 0.6709888885915279
# SMA Loss: 1.1427141235698945
# SMA PG Loss: 0.011924527529627084
# SMA V Loss: 2.2749989831447603
# Max reward: 3940.0
# ---------- 27750 / 125000 ----------
# Num Games: 1769
# Num Frames: 1109960
# FPS: 349
# ETA: 3:05:26
# SMA Length: 667.935
# SMA Reward: 973.55
# SMA Entropy: 0.7655794855952263
# SMA Loss: 0.9264736791932955
# SMA PG Loss: -0.0004003091614868026
# SMA V Loss: 1.8690595662966372
# Max reward: 3940.0
# ---------- 28000 / 125000 ----------
# Num Games: 1782
# Num Frames: 1119960
# FPS: 349
# ETA: 3:04:56
# SMA Length: 673.46
# SMA Reward: 974.0
# SMA Entropy: 0.6902007154375315
# SMA Loss: 1.0004104001889937
# SMA PG Loss: 0.009429642139002681
# SMA V Loss: 1.995765542127192
# Max reward: 3940.0
# ---------- 28250 / 125000 ----------
# Num Games: 1794
# Num Frames: 1129960
# FPS: 349
# ETA: 3:04:26
# SMA Length: 687.35
# SMA Reward: 1005.8
# SMA Entropy: 0.7621704718470573
# SMA Loss: 0.8295799208851531
# SMA PG Loss: -0.0059398181273718365
# SMA V Loss: 1.6862828913331032
# Max reward: 3940.0
# ---------- 28500 / 125000 ----------
# Num Games: 1809
# Num Frames: 1139960
# FPS: 349
# ETA: 3:03:55
# SMA Length: 702.315
# SMA Reward: 1026.35
# SMA Entropy: 0.7749469976127148
# SMA Loss: 1.1148561372701078
# SMA PG Loss: 0.014186077415943146
# SMA V Loss: 2.216839032992721
# Max reward: 3940.0
# ---------- 28750 / 125000 ----------
# Num Games: 1820
# Num Frames: 1149960
# FPS: 349
# ETA: 3:03:24
# SMA Length: 713.375
# SMA Reward: 1052.25
# SMA Entropy: 0.7874745491892099
# SMA Loss: 0.9388860579347238
# SMA PG Loss: 0.034149155072664146
# SMA V Loss: 1.8252232962846755
# Max reward: 3940.0
# ---------- 29000 / 125000 ----------
# Num Games: 1834
# Num Frames: 1159960
# FPS: 349
# ETA: 3:02:54
# SMA Length: 720.39
# SMA Reward: 1063.15
# SMA Entropy: 0.7853134056925773
# SMA Loss: 0.9503358904295601
# SMA PG Loss: 0.024275074423821933
# SMA V Loss: 1.867827896773815
# Max reward: 3940.0
# ---------- 29250 / 125000 ----------
# Num Games: 1847
# Num Frames: 1169960
# FPS: 349
# ETA: 3:02:24
# SMA Length: 729.45
# SMA Reward: 1086.9
# SMA Entropy: 0.8051368652284145
# SMA Loss: 0.7710056736459956
# SMA PG Loss: -0.013861933876760303
# SMA V Loss: 1.5858379649370908
# Max reward: 3940.0
# ---------- 29500 / 125000 ----------
# Num Games: 1861
# Num Frames: 1179960
# FPS: 349
# ETA: 3:01:54
# SMA Length: 729.515
# SMA Reward: 1086.8
# SMA Entropy: 0.6721663963794708
# SMA Loss: 0.8862855881080032
# SMA PG Loss: 0.03507699349691393
# SMA V Loss: 1.7158605185709894
# Max reward: 3940.0
# ---------- 29750 / 125000 ----------
# Num Games: 1877
# Num Frames: 1189960
# FPS: 350
# ETA: 3:01:24
# SMA Length: 726.28
# SMA Reward: 1074.3
# SMA Entropy: 0.5327254015952348
# SMA Loss: 0.739857101936359
# SMA PG Loss: -0.02516469983067509
# SMA V Loss: 1.5406981159746647
# Max reward: 3940.0
# ---------- 30000 / 125000 ----------
# Num Games: 1892
# Num Frames: 1199960
# FPS: 350
# ETA: 3:00:55
# SMA Length: 718.76
# SMA Reward: 1066.6
# SMA Entropy: 0.5682479196414352
# SMA Loss: 0.7320603631145787
# SMA PG Loss: 0.027500024798428058
# SMA V Loss: 1.4204856400564312
# Max reward: 3940.0
# ---------- 30250 / 125000 ----------
# Num Games: 1909
# Num Frames: 1209960
# FPS: 350
# ETA: 3:00:26
# SMA Length: 711.195
# SMA Reward: 1047.6
# SMA Entropy: 0.3381911396421492
# SMA Loss: 0.7104509690077976
# SMA PG Loss: 0.031164155131264124
# SMA V Loss: 1.365337442085147
# Max reward: 3940.0
# ---------- 30500 / 125000 ----------
# Num Games: 1925
# Num Frames: 1219960
# FPS: 350
# ETA: 2:59:56
# SMA Length: 703.9
# SMA Reward: 1014.35
# SMA Entropy: 1.0837492707371712
# SMA Loss: 0.8428357960470021
# SMA PG Loss: 0.1044737355899997
# SMA V Loss: 1.498399129509926
# Max reward: 3940.0
# ---------- 30750 / 125000 ----------
# Num Games: 1940
# Num Frames: 1229960
# FPS: 350
# ETA: 2:59:27
# SMA Length: 705.695
# SMA Reward: 1028.05
# SMA Entropy: 0.8582349608838559
# SMA Loss: 0.9329114944394677
# SMA PG Loss: 0.047181341219693425
# SMA V Loss: 1.7886250130832195
# Max reward: 3940.0
# ---------- 31000 / 125000 ----------
# Num Games: 1953
# Num Frames: 1239960
# FPS: 350
# ETA: 2:58:58
# SMA Length: 707.415
# SMA Reward: 1028.0
# SMA Entropy: 0.8313814170658589
# SMA Loss: 0.7695130037423223
# SMA PG Loss: 0.019483633051859215
# SMA V Loss: 1.5166863847523928
# Max reward: 3940.0
# ---------- 31250 / 125000 ----------
# Num Games: 1969
# Num Frames: 1249960
# FPS: 350
# ETA: 2:58:28
# SMA Length: 707.125
# SMA Reward: 1034.6
# SMA Entropy: 0.7395610676705837
# SMA Loss: 1.1108174088504166
# SMA PG Loss: 0.008734054422820919
# SMA V Loss: 2.21895790591836
# Max reward: 3940.0
# ---------- 31500 / 125000 ----------
# Num Games: 1980
# Num Frames: 1259960
# FPS: 350
# ETA: 2:57:58
# SMA Length: 709.225
# SMA Reward: 1053.5
# SMA Entropy: 0.7856923827528953
# SMA Loss: 0.9710541828721762
# SMA PG Loss: 0.03459699913364602
# SMA V Loss: 1.8886282189004122
# Max reward: 3940.0
# ---------- 31750 / 125000 ----------
# Num Games: 1996
# Num Frames: 1269960
# FPS: 350
# ETA: 2:57:29
# SMA Length: 702.46
# SMA Reward: 1039.55
# SMA Entropy: 0.8699567049741745
# SMA Loss: 0.8374777255486697
# SMA PG Loss: -0.0006575252069160342
# SMA V Loss: 1.6936696374043823
# Max reward: 3940.0
# ---------- 32000 / 125000 ----------
# Num Games: 2011
# Num Frames: 1279960
# FPS: 350
# ETA: 2:57:00
# SMA Length: 692.005
# SMA Reward: 1014.15
# SMA Entropy: 0.9454818193614483
# SMA Loss: 0.8505510713742115
# SMA PG Loss: 0.038769032328855244
# SMA V Loss: 1.6424737125635147
# Max reward: 3940.0
# ---------- 32250 / 125000 ----------
# Num Games: 2024
# Num Frames: 1289960
# FPS: 350
# ETA: 2:56:29
# SMA Length: 691.685
# SMA Reward: 1012.8
# SMA Entropy: 0.7395801020413637
# SMA Loss: 0.9843177341064439
# SMA PG Loss: 0.023840864733792842
# SMA V Loss: 1.935745315849781
# Max reward: 3940.0
# ---------- 32500 / 125000 ----------
# Num Games: 2038
# Num Frames: 1299960
# FPS: 350
# ETA: 2:55:59
# SMA Length: 691.15
# SMA Reward: 1022.05
# SMA Entropy: 0.8494149834662675
# SMA Loss: 0.975417182892561
# SMA PG Loss: 0.010411370611691381
# SMA V Loss: 1.9469999001547693
# Max reward: 3940.0
# ---------- 32750 / 125000 ----------
# Num Games: 2052
# Num Frames: 1309960
# FPS: 350
# ETA: 2:55:28
# SMA Length: 682.585
# SMA Reward: 1002.2
# SMA Entropy: 0.838168378174305
# SMA Loss: 1.0781011087703518
# SMA PG Loss: 0.025055051228846423
# SMA V Loss: 2.1228554953448473
# Max reward: 3940.0
# ---------- 33000 / 125000 ----------
# Num Games: 2062
# Num Frames: 1319960
# FPS: 350
# ETA: 2:54:58
# SMA Length: 694.185
# SMA Reward: 1021.95
# SMA Entropy: 1.0471824318170548
# SMA Loss: 0.8508459812169895
# SMA PG Loss: 0.0555556039964722
# SMA V Loss: 1.6115244057774545
# Max reward: 3940.0
# ---------- 33250 / 125000 ----------
# Num Games: 2073
# Num Frames: 1329960
# FPS: 350
# ETA: 2:54:26
# SMA Length: 697.935
# SMA Reward: 1036.6
# SMA Entropy: 0.9409335424005986
# SMA Loss: 0.9409214860084467
# SMA PG Loss: 0.07066083133104258
# SMA V Loss: 1.759339956343174
# Max reward: 3940.0
# ---------- 33500 / 125000 ----------
# Num Games: 2086
# Num Frames: 1339960
# FPS: 350
# ETA: 2:53:56
# SMA Length: 711.7
# SMA Reward: 1058.95
# SMA Entropy: 0.8891898664832115
# SMA Loss: 1.1322481100261212
# SMA PG Loss: 0.05165370364731643
# SMA V Loss: 2.178972584605217
# Max reward: 3940.0
# ---------- 33750 / 125000 ----------
# Num Games: 2100
# Num Frames: 1349960
# FPS: 350
# ETA: 2:53:25
# SMA Length: 727.38
# SMA Reward: 1087.9
# SMA Entropy: 0.6727882215380668
# SMA Loss: 0.8263278603553772
# SMA PG Loss: 0.017748969125677833
# SMA V Loss: 1.6306135465018452
# Max reward: 3940.0
# ---------- 34000 / 125000 ----------
# Num Games: 2110
# Num Frames: 1359960
# FPS: 350
# ETA: 2:52:55
# SMA Length: 743.455
# SMA Reward: 1132.65
# SMA Entropy: 0.7560557250678539
# SMA Loss: 1.1488152738194912
# SMA PG Loss: 0.018497811958950477
# SMA V Loss: 2.2757560205459595
# Max reward: 3940.0
# ---------- 34250 / 125000 ----------
# Num Games: 2122
# Num Frames: 1369960
# FPS: 350
# ETA: 2:52:25
# SMA Length: 759.365
# SMA Reward: 1186.2
# SMA Entropy: 0.8218444189988077
# SMA Loss: 0.945056026969105
# SMA PG Loss: 0.00721605091181118
# SMA V Loss: 1.8921168255060912
# Max reward: 3940.0
# ---------- 34500 / 125000 ----------
# Num Games: 2134
# Num Frames: 1379960
# FPS: 350
# ETA: 2:51:55
# SMA Length: 771.81
# SMA Reward: 1218.65
# SMA Entropy: 0.7338583785295486
# SMA Loss: 0.7996295223617926
# SMA PG Loss: 0.017939891831192652
# SMA V Loss: 1.578056451752782
# Max reward: 3940.0
# ---------- 34750 / 125000 ----------
# Num Games: 2148
# Num Frames: 1389960
# FPS: 350
# ETA: 2:51:25
# SMA Length: 775.39
# SMA Reward: 1224.3
# SMA Entropy: 0.8213511525094509
# SMA Loss: 0.8073176086251624
# SMA PG Loss: -0.009127288323652465
# SMA V Loss: 1.6493168181180955
# Max reward: 3940.0
# ---------- 35000 / 125000 ----------
# Num Games: 2159
# Num Frames: 1399960
# FPS: 351
# ETA: 2:50:55
# SMA Length: 776.33
# SMA Reward: 1235.55
# SMA Entropy: 0.8377711279690265
# SMA Loss: 0.8933066220162437
# SMA PG Loss: 0.001343572020996362
# SMA V Loss: 1.8006815021857618
# Max reward: 3940.0
# ---------- 35250 / 125000 ----------
# Num Games: 2173
# Num Frames: 1409960
# FPS: 351
# ETA: 2:50:25
# SMA Length: 783.495
# SMA Reward: 1257.05
# SMA Entropy: 0.8272120895981788
# SMA Loss: 1.0487445666687563
# SMA PG Loss: 0.042071216600888875
# SMA V Loss: 2.0298909359425306
# Max reward: 3940.0
# ---------- 35500 / 125000 ----------
# Num Games: 2187
# Num Frames: 1419960
# FPS: 351
# ETA: 2:49:55
# SMA Length: 784.655
# SMA Reward: 1250.8
# SMA Entropy: 0.8540973009169102
# SMA Loss: 1.212774529256858
# SMA PG Loss: 0.05041219086317142
# SMA V Loss: 2.3418066251184793
# Max reward: 3940.0
# ---------- 35750 / 125000 ----------
# Num Games: 2201
# Num Frames: 1429960
# FPS: 351
# ETA: 2:49:25
# SMA Length: 787.51
# SMA Reward: 1276.2
# SMA Entropy: 0.7212924942374229
# SMA Loss: 1.509474776298739
# SMA PG Loss: 0.014288258528104052
# SMA V Loss: 3.004798840433359
# Max reward: 3940.0
# ---------- 36000 / 125000 ----------
# Num Games: 2213
# Num Frames: 1439960
# FPS: 351
# ETA: 2:48:56
# SMA Length: 790.13
# SMA Reward: 1306.35
# SMA Entropy: 0.7947485968470573
# SMA Loss: 0.9852319431048818
# SMA PG Loss: 0.010591598105093
# SMA V Loss: 1.9651756621152163
# Max reward: 3940.0
# ---------- 36250 / 125000 ----------
# Num Games: 2227
# Num Frames: 1449960
# FPS: 351
# ETA: 2:48:26
# SMA Length: 786.49
# SMA Reward: 1294.55
# SMA Entropy: 0.6166078788042069
# SMA Loss: 1.2486440652282909
# SMA PG Loss: 0.0016645065110060385
# SMA V Loss: 2.506291260011494
# Max reward: 3940.0
# ---------- 36500 / 125000 ----------
# Num Games: 2242
# Num Frames: 1459960
# FPS: 351
# ETA: 2:47:56
# SMA Length: 787.6
# SMA Reward: 1298.35
# SMA Entropy: 0.7420524209737778
# SMA Loss: 1.1817617378709837
# SMA PG Loss: 0.0477515731920721
# SMA V Loss: 2.282861424796283
# Max reward: 3940.0
# ---------- 36750 / 125000 ----------
# Num Games: 2255
# Num Frames: 1469960
# FPS: 351
# ETA: 2:47:26
# SMA Length: 793.0
# SMA Reward: 1318.5
# SMA Entropy: 0.8617086884379387
# SMA Loss: 0.8946529852272943
# SMA PG Loss: 0.018820213582075668
# SMA V Loss: 1.7688997116684915
# Max reward: 3940.0
# ---------- 37000 / 125000 ----------
# Num Games: 2266
# Num Frames: 1479960
# FPS: 351
# ETA: 2:46:56
# SMA Length: 783.715
# SMA Reward: 1296.3
# SMA Entropy: 0.7552508790791035
# SMA Loss: 1.3337998005002738
# SMA PG Loss: 0.003440953427925706
# SMA V Loss: 2.6758227077126504
# Max reward: 3940.0
# ---------- 37250 / 125000 ----------
# Num Games: 2277
# Num Frames: 1489960
# FPS: 351
# ETA: 2:46:27
# SMA Length: 784.065
# SMA Reward: 1311.05
# SMA Entropy: 0.7106325280666351
# SMA Loss: 0.6126382656255737
# SMA PG Loss: -0.003105992269702256
# SMA V Loss: 1.2457011786848307
# Max reward: 3940.0
# ---------- 37500 / 125000 ----------
# Num Games: 2290
# Num Frames: 1499960
# FPS: 351
# ETA: 2:45:57
# SMA Length: 791.46
# SMA Reward: 1329.75
# SMA Entropy: 0.8855957044661045
# SMA Loss: 0.6462984275212511
# SMA PG Loss: 0.0007678455446148291
# SMA V Loss: 1.3087730738520622
# Max reward: 3940.0
# ---------- 37750 / 125000 ----------
# Num Games: 2301
# Num Frames: 1509960
# FPS: 351
# ETA: 2:45:28
# SMA Length: 796.35
# SMA Reward: 1353.5
# SMA Entropy: 0.7950755449384451
# SMA Loss: 0.9784704869473353
# SMA PG Loss: -0.037299581401748584
# SMA V Loss: 2.0474416523054244
# Max reward: 3940.0
# ---------- 38000 / 125000 ----------
# Num Games: 2314
# Num Frames: 1519960
# FPS: 351
# ETA: 2:44:58
# SMA Length: 784.405
# SMA Reward: 1328.45
# SMA Entropy: 0.6736114336550236
# SMA Loss: 0.9224593328940682
# SMA PG Loss: -0.0291534795233747
# SMA V Loss: 1.916697883605957
# Max reward: 3940.0
# ---------- 38250 / 125000 ----------
# Num Games: 2328
# Num Frames: 1529960
# FPS: 351
# ETA: 2:44:27
# SMA Length: 776.29
# SMA Reward: 1307.5
# SMA Entropy: 0.7423683272302151
# SMA Loss: 1.088462624917738
# SMA PG Loss: 0.0036827337778231593
# SMA V Loss: 2.1844071217626335
# Max reward: 3940.0
# ---------- 38500 / 125000 ----------
# Num Games: 2343
# Num Frames: 1539960
# FPS: 351
# ETA: 2:43:56
# SMA Length: 775.0
# SMA Reward: 1304.45
# SMA Entropy: 0.7517718855291605
# SMA Loss: 1.1725045700185002
# SMA PG Loss: -0.003924711500876583
# SMA V Loss: 2.367893993332982
# Max reward: 3940.0
# ---------- 38750 / 125000 ----------
# Num Games: 2358
# Num Frames: 1549960
# FPS: 351
# ETA: 2:43:25
# SMA Length: 760.05
# SMA Reward: 1267.4
# SMA Entropy: 0.611329086124897
# SMA Loss: 1.0996761660045014
# SMA PG Loss: 0.04563823283853708
# SMA V Loss: 2.1203024594485758
# Max reward: 3940.0
# ---------- 39000 / 125000 ----------
# Num Games: 2373
# Num Frames: 1559960
# FPS: 351
# ETA: 2:42:54
# SMA Length: 756.06
# SMA Reward: 1250.95
# SMA Entropy: 0.7405114625394345
# SMA Loss: 1.1614355788729154
# SMA PG Loss: -0.016712267344119028
# SMA V Loss: 2.371105935703963
# Max reward: 3940.0
# ---------- 39250 / 125000 ----------
# Num Games: 2384
# Num Frames: 1569960
# FPS: 352
# ETA: 2:42:24
# SMA Length: 757.28
# SMA Reward: 1248.95
# SMA Entropy: 0.9708989517390728
# SMA Loss: 1.1495086561632342
# SMA PG Loss: 0.09897560145689567
# SMA V Loss: 2.120484092272818
# Max reward: 3940.0
# ---------- 39500 / 125000 ----------
# Num Games: 2397
# Num Frames: 1579960
# FPS: 352
# ETA: 2:41:53
# SMA Length: 760.88
# SMA Reward: 1243.95
# SMA Entropy: 0.8759151639044285
# SMA Loss: 1.049552448450122
# SMA PG Loss: 0.07903294469811954
# SMA V Loss: 1.9585573654994368
# Max reward: 3940.0
# ---------- 39750 / 125000 ----------
# Num Games: 2410
# Num Frames: 1589960
# FPS: 352
# ETA: 2:41:22
# SMA Length: 767.06
# SMA Reward: 1234.9
# SMA Entropy: 0.8280901904404163
# SMA Loss: 1.201601637469139
# SMA PG Loss: -0.0007797720469534397
# SMA V Loss: 2.421324620693922
# Max reward: 3940.0
# ---------- 40000 / 125000 ----------
# Num Games: 2420
# Num Frames: 1599960
# FPS: 352
# ETA: 2:40:51
# SMA Length: 767.28
# SMA Reward: 1236.8
# SMA Entropy: 0.9516135135293007
# SMA Loss: 1.1664148789062165
# SMA PG Loss: 0.06787766874826047
# SMA V Loss: 2.2161067052558066
# Max reward: 3940.0
# ---------- 40250 / 125000 ----------
# Num Games: 2435
# Num Frames: 1609960
# FPS: 352
# ETA: 2:40:20
# SMA Length: 775.77
# SMA Reward: 1262.65
# SMA Entropy: 0.7053577069938183
# SMA Loss: 1.1796804091939703
# SMA PG Loss: 0.004419796390866395
# SMA V Loss: 2.3646283882856367
# Max reward: 3940.0
# ---------- 40500 / 125000 ----------
# Num Games: 2447
# Num Frames: 1619960
# FPS: 352
# ETA: 2:39:49
# SMA Length: 781.125
# SMA Reward: 1267.0
# SMA Entropy: 0.944590053781867
# SMA Loss: 0.9478463124553673
# SMA PG Loss: 0.012602790727396496
# SMA V Loss: 1.8893788314983249
# Max reward: 3940.0
# ---------- 40750 / 125000 ----------
# Num Games: 2462
# Num Frames: 1629960
# FPS: 352
# ETA: 2:39:19
# SMA Length: 775.88
# SMA Reward: 1272.75
# SMA Entropy: 0.7219858579337597
# SMA Loss: 1.055558614404872
# SMA PG Loss: -0.008681925699711428
# SMA V Loss: 2.142920815050602
# Max reward: 3940.0
# ---------- 41000 / 125000 ----------
# Num Games: 2475
# Num Frames: 1639960
# FPS: 352
# ETA: 2:38:49
# SMA Length: 765.52
# SMA Reward: 1257.3
# SMA Entropy: 0.7392597284913063
# SMA Loss: 1.0866159086301923
# SMA PG Loss: 0.02419188490472152
# SMA V Loss: 2.139633259214461
# Max reward: 3940.0
# ---------- 41250 / 125000 ----------
# Num Games: 2488
# Num Frames: 1649960
# FPS: 352
# ETA: 2:38:19
# SMA Length: 758.95
# SMA Reward: 1254.7
# SMA Entropy: 0.6637325561791658
# SMA Loss: 1.0130770940217189
# SMA PG Loss: -0.003879983831429854
# SMA V Loss: 2.0471887985244392
# Max reward: 3940.0
# ---------- 41500 / 125000 ----------
# Num Games: 2502
# Num Frames: 1659960
# FPS: 352
# ETA: 2:37:51
# SMA Length: 747.055
# SMA Reward: 1231.2
# SMA Entropy: 0.7047462217509747
# SMA Loss: 1.0733626987156457
# SMA PG Loss: -0.03482354963431135
# SMA V Loss: 2.2304674446210266
# Max reward: 3940.0
# ---------- 41750 / 125000 ----------
# Num Games: 2518
# Num Frames: 1669960
# FPS: 352
# ETA: 2:37:21
# SMA Length: 746.205
# SMA Reward: 1232.45
# SMA Entropy: 0.6770903831720352
# SMA Loss: 1.3638696553814225
# SMA PG Loss: -0.02145316149224527
# SMA V Loss: 2.78418750487268
# Max reward: 3940.0
# ---------- 42000 / 125000 ----------
# Num Games: 2527
# Num Frames: 1679960
# FPS: 352
# ETA: 2:36:52
# SMA Length: 753.005
# SMA Reward: 1255.8
# SMA Entropy: 0.8738628271222114
# SMA Loss: 1.1649422034434975
# SMA PG Loss: 0.025901683616248193
# SMA V Loss: 2.2955583349987863
# Max reward: 4390.0
# ---------- 42250 / 125000 ----------
# Num Games: 2541
# Num Frames: 1689960
# FPS: 352
# ETA: 2:36:23
# SMA Length: 754.31
# SMA Reward: 1266.45
# SMA Entropy: 0.741902349293232
# SMA Loss: 1.2372093283059076
# SMA PG Loss: -0.008514730870665517
# SMA V Loss: 2.5062861718982457
# Max reward: 4390.0
# ---------- 42500 / 125000 ----------
# Num Games: 2553
# Num Frames: 1699960
# FPS: 352
# ETA: 2:35:53
# SMA Length: 768.23
# SMA Reward: 1288.55
# SMA Entropy: 0.764706259444356
# SMA Loss: 0.9133805306325666
# SMA PG Loss: -0.006250887515197974
# SMA V Loss: 1.854556927923113
# Max reward: 4390.0
# ---------- 42750 / 125000 ----------
# Num Games: 2566
# Num Frames: 1709960
# FPS: 352
# ETA: 2:35:23
# SMA Length: 771.47
# SMA Reward: 1286.9
# SMA Entropy: 0.7575508752465248
# SMA Loss: 1.2970599269727245
# SMA PG Loss: 0.025302123884321192
# SMA V Loss: 2.5586666481196882
# Max reward: 4390.0
# ---------- 43000 / 125000 ----------
# Num Games: 2578
# Num Frames: 1719960
# FPS: 352
# ETA: 2:34:54
# SMA Length: 771.24
# SMA Reward: 1285.35
# SMA Entropy: 0.6269512270390988
# SMA Loss: 0.8466406353702769
# SMA PG Loss: -0.0006344519287085859
# SMA V Loss: 1.7070891942828894
# Max reward: 4390.0
# ---------- 43250 / 125000 ----------
# Num Games: 2591
# Num Frames: 1729960
# FPS: 352
# ETA: 2:34:25
# SMA Length: 777.33
# SMA Reward: 1302.5
# SMA Entropy: 0.6494533764570951
# SMA Loss: 1.3462500427942723
# SMA PG Loss: 0.0572749502264196
# SMA V Loss: 2.5909392217174174
# Max reward: 4390.0
# ---------- 43500 / 125000 ----------
# Num Games: 2604
# Num Frames: 1739960
# FPS: 352
# ETA: 2:33:56
# SMA Length: 774.015
# SMA Reward: 1297.35
# SMA Entropy: 0.7045995151251554
# SMA Loss: 1.1200928309978917
# SMA PG Loss: 0.007102639437071048
# SMA V Loss: 2.2400723749026654
# Max reward: 4390.0
# ---------- 43750 / 125000 ----------
# Num Games: 2617
# Num Frames: 1749960
# FPS: 352
# ETA: 2:33:28
# SMA Length: 772.925
# SMA Reward: 1316.85
# SMA Entropy: 0.658167771846056
# SMA Loss: 1.473873954846058
# SMA PG Loss: 0.025753610411775298
# SMA V Loss: 2.9094040400162338
# Max reward: 4390.0
# ---------- 44000 / 125000 ----------
# Num Games: 2629
# Num Frames: 1759960
# FPS: 352
# ETA: 2:33:01
# SMA Length: 772.815
# SMA Reward: 1310.3
# SMA Entropy: 0.6876315238326788
# SMA Loss: 0.9944562990544363
# SMA PG Loss: 0.013549576814257306
# SMA V Loss: 1.9755660687759518
# Max reward: 4390.0
# ---------- 44250 / 125000 ----------
# Num Games: 2640
# Num Frames: 1769960
# FPS: 352
# ETA: 2:32:32
# SMA Length: 778.715
# SMA Reward: 1324.2
# SMA Entropy: 0.6799195576459169
# SMA Loss: 1.0452225119015202
# SMA PG Loss: -0.035680691869929435
# SMA V Loss: 2.175404791906476
# Max reward: 4390.0
# ---------- 44500 / 125000 ----------
# Num Games: 2657
# Num Frames: 1779960
# FPS: 352
# ETA: 2:32:04
# SMA Length: 772.035
# SMA Reward: 1309.4
# SMA Entropy: 0.507977703474462
# SMA Loss: 1.3440250693820417
# SMA PG Loss: 0.0015547906495339704
# SMA V Loss: 2.6951001511141657
# Max reward: 4390.0
# ---------- 44750 / 125000 ----------
# Num Games: 2674
# Num Frames: 1789960
# FPS: 352
# ETA: 2:31:36
# SMA Length: 761.245
# SMA Reward: 1278.0
# SMA Entropy: 0.4206968216598034
# SMA Loss: 1.2440852287481539
# SMA PG Loss: -0.009636644957354293
# SMA V Loss: 2.515857698246837
# Max reward: 4390.0
# ---------- 45000 / 125000 ----------
# Num Games: 2686
# Num Frames: 1799960
# FPS: 352
# ETA: 2:31:08
# SMA Length: 759.185
# SMA Reward: 1261.5
# SMA Entropy: 0.5910381575673819
# SMA Loss: 0.8641258235881105
# SMA PG Loss: -0.02399198779836297
# SMA V Loss: 1.788056390285492
# Max reward: 4390.0
# ---------- 45250 / 125000 ----------
# Num Games: 2701
# Num Frames: 1809960
# FPS: 352
# ETA: 2:30:39
# SMA Length: 762.13
# SMA Reward: 1261.25
# SMA Entropy: 0.5082440848648548
# SMA Loss: 0.8728748640371486
# SMA PG Loss: -0.004718174792142236
# SMA V Loss: 1.7653509428352117
# Max reward: 4390.0
# ---------- 45500 / 125000 ----------
# Num Games: 2712
# Num Frames: 1819960
# FPS: 352
# ETA: 2:30:10
# SMA Length: 768.16
# SMA Reward: 1276.5
# SMA Entropy: 0.5031369218230247
# SMA Loss: 0.8197172588377726
# SMA PG Loss: -0.006600065903621726
# SMA V Loss: 1.6626973877847195
# Max reward: 4390.0
# ---------- 45750 / 125000 ----------
# Num Games: 2724
# Num Frames: 1829960
# FPS: 352
# ETA: 2:29:41
# SMA Length: 771.205
# SMA Reward: 1290.15
# SMA Entropy: 0.5055488079041243
# SMA Loss: 0.7808406467537862
# SMA PG Loss: -0.005492518694154569
# SMA V Loss: 1.5827772955968975
# Max reward: 4390.0
# ---------- 46000 / 125000 ----------
# Num Games: 2735
# Num Frames: 1839960
# FPS: 352
# ETA: 2:29:13
# SMA Length: 767.595
# SMA Reward: 1276.7
# SMA Entropy: 0.5243631888180971
# SMA Loss: 1.0223461471637711
# SMA PG Loss: 0.017046510130512615
# SMA V Loss: 2.021086547970772
# Max reward: 4390.0
# ---------- 46250 / 125000 ----------
# Num Games: 2747
# Num Frames: 1849960
# FPS: 352
# ETA: 2:28:44
# SMA Length: 773.17
# SMA Reward: 1286.55
# SMA Entropy: 0.5489696037769317
# SMA Loss: 0.8909219358908013
# SMA PG Loss: 0.008749961436769808
# SMA V Loss: 1.775323346182704
# Max reward: 4390.0
# ---------- 46500 / 125000 ----------
# Num Games: 2761
# Num Frames: 1859960
# FPS: 352
# ETA: 2:28:16
# SMA Length: 777.385
# SMA Reward: 1301.55
# SMA Entropy: 0.5341992884874344
# SMA Loss: 1.5116520782583394
# SMA PG Loss: -0.013674718802503776
# SMA V Loss: 3.0613376193866135
# Max reward: 4390.0
# ---------- 46750 / 125000 ----------
# Num Games: 2773
# Num Frames: 1869960
# FPS: 352
# ETA: 2:27:47
# SMA Length: 779.115
# SMA Reward: 1329.8
# SMA Entropy: 0.5934850930422545
# SMA Loss: 1.332966826125048
# SMA PG Loss: -0.007632935586480016
# SMA V Loss: 2.6930692141875623
# Max reward: 4390.0
# ---------- 47000 / 125000 ----------
# Num Games: 2785
# Num Frames: 1879960
# FPS: 353
# ETA: 2:27:18
# SMA Length: 772.89
# SMA Reward: 1326.9
# SMA Entropy: 0.6166096889227629
# SMA Loss: 0.8876325413328595
# SMA PG Loss: -0.013779473778886314
# SMA V Loss: 1.8151562244817614
# Max reward: 4390.0
# ---------- 47250 / 125000 ----------
# Num Games: 2797
# Num Frames: 1889960
# FPS: 353
# ETA: 2:26:49
# SMA Length: 773.855
# SMA Reward: 1324.85
# SMA Entropy: 0.5401092736423015
# SMA Loss: 0.8803206697595306
# SMA PG Loss: -0.019755548533285035
# SMA V Loss: 1.8109546151943505
# Max reward: 4390.0
# ---------- 47500 / 125000 ----------
# Num Games: 2811
# Num Frames: 1899960
# FPS: 353
# ETA: 2:26:20
# SMA Length: 778.17
# SMA Reward: 1311.05
# SMA Entropy: 0.5585349328070879
# SMA Loss: 1.0690485173021442
# SMA PG Loss: -0.014330086299451069
# SMA V Loss: 2.1779278821870687
# Max reward: 4390.0
# ---------- 47750 / 125000 ----------
# Num Games: 2822
# Num Frames: 1909960
# FPS: 353
# ETA: 2:25:51
# SMA Length: 780.09
# SMA Reward: 1312.55
# SMA Entropy: 0.6173787228018045
# SMA Loss: 0.9193266836449038
# SMA PG Loss: 0.01550166325585451
# SMA V Loss: 1.8199976040422916
# Max reward: 4390.0
# ---------- 48000 / 125000 ----------
# Num Games: 2832
# Num Frames: 1919960
# FPS: 353
# ETA: 2:25:22
# SMA Length: 783.13
# SMA Reward: 1327.2
# SMA Entropy: 0.6485212532430887
# SMA Loss: 0.9272981427423655
# SMA PG Loss: 0.008451367485104128
# SMA V Loss: 1.850663939677179
# Max reward: 4390.0
# ---------- 48250 / 125000 ----------
# Num Games: 2844
# Num Frames: 1929960
# FPS: 353
# ETA: 2:24:53
# SMA Length: 782.79
# SMA Reward: 1307.7
# SMA Entropy: 0.7424298587441445
# SMA Loss: 0.703895428837277
# SMA PG Loss: -0.012309822695096955
# SMA V Loss: 1.4472590970247985
# Max reward: 4390.0
# ---------- 48500 / 125000 ----------
# Num Games: 2854
# Num Frames: 1939960
# FPS: 353
# ETA: 2:24:24
# SMA Length: 799.44
# SMA Reward: 1321.25
# SMA Entropy: 0.6083377829194069
# SMA Loss: 0.974330883056391
# SMA PG Loss: -0.02790443120873533
# SMA V Loss: 2.0166373923420906
# Max reward: 4390.0
# ---------- 48750 / 125000 ----------
# Num Games: 2868
# Num Frames: 1949960
# FPS: 353
# ETA: 2:23:55
# SMA Length: 815.51
# SMA Reward: 1346.9
# SMA Entropy: 0.6225076539814473
# SMA Loss: 1.1270797775383108
# SMA PG Loss: -0.015601574167521903
# SMA V Loss: 2.2978128283843398
# Max reward: 4390.0
# ---------- 49000 / 125000 ----------
# Num Games: 2881
# Num Frames: 1959960
# FPS: 353
# ETA: 2:23:25
# SMA Length: 829.255
# SMA Reward: 1371.65
# SMA Entropy: 0.5753215790167451
# SMA Loss: 1.2415964702144264
# SMA PG Loss: -0.016193184015864972
# SMA V Loss: 2.5270857036672534
# Max reward: 4390.0
# ---------- 49250 / 125000 ----------
# Num Games: 2894
# Num Frames: 1969960
# FPS: 353
# ETA: 2:22:56
# SMA Length: 826.405
# SMA Reward: 1369.85
# SMA Entropy: 0.6028338073939085
# SMA Loss: 1.1517186657118146
# SMA PG Loss: -0.023967465651221573
# SMA V Loss: 2.3634288973920046
# Max reward: 4390.0
# ---------- 49500 / 125000 ----------
# Num Games: 2907
# Num Frames: 1979960
# FPS: 353
# ETA: 2:22:27
# SMA Length: 824.615
# SMA Reward: 1374.8
# SMA Entropy: 0.662904084995389
# SMA Loss: 1.426418163171038
# SMA PG Loss: 0.0024570397734350992
# SMA V Loss: 2.861180291995406
# Max reward: 4390.0
# ---------- 49750 / 125000 ----------
# Num Games: 2919
# Num Frames: 1989960
# FPS: 353
# ETA: 2:21:58
# SMA Length: 821.765
# SMA Reward: 1373.05
# SMA Entropy: 0.6348250317759812
# SMA Loss: 0.847616880335845
# SMA PG Loss: -0.006912874727277085
# SMA V Loss: 1.7217560083046555
# Max reward: 4390.0
# ---------- 50000 / 125000 ----------
# Num Games: 2932
# Num Frames: 1999960
# FPS: 353
# ETA: 2:21:29
# SMA Length: 822.955
# SMA Reward: 1357.0
# SMA Entropy: 0.6386744998022914
# SMA Loss: 1.1089749824418687
# SMA PG Loss: -0.01444692651508376
# SMA V Loss: 2.259617340527475
# Max reward: 4390.0
# ---------- 50250 / 125000 ----------
# Num Games: 2944
# Num Frames: 2009960
# FPS: 353
# ETA: 2:21:02
# SMA Length: 815.345
# SMA Reward: 1353.4
# SMA Entropy: 0.6392895869165659
# SMA Loss: 1.3651037725852802
# SMA PG Loss: 0.003650261708535254
# SMA V Loss: 2.7356928065232933
# Max reward: 4390.0
# ---------- 50500 / 125000 ----------
# Num Games: 2958
# Num Frames: 2019960
# FPS: 353
# ETA: 2:20:33
# SMA Length: 806.125
# SMA Reward: 1335.05
# SMA Entropy: 0.6941361682116985
# SMA Loss: 1.4376159766828642
# SMA PG Loss: -0.009129136316478253
# SMA V Loss: 2.9073729695379735
# Max reward: 4390.0
# ---------- 50750 / 125000 ----------
# Num Games: 2968
# Num Frames: 2029960
# FPS: 353
# ETA: 2:20:05
# SMA Length: 809.945
# SMA Reward: 1332.55
# SMA Entropy: 0.7234761702269316
# SMA Loss: 0.9294253263785504
# SMA PG Loss: 0.015089078248711302
# SMA V Loss: 1.8431420486792922
# Max reward: 4390.0
# ---------- 51000 / 125000 ----------
# Num Games: 2982
# Num Frames: 2039960
# FPS: 353
# ETA: 2:19:36
# SMA Length: 813.47
# SMA Reward: 1334.4
# SMA Entropy: 0.6089277847111225
# SMA Loss: 0.9130933209904469
# SMA PG Loss: -0.007922321168880444
# SMA V Loss: 1.8542098439484835
# Max reward: 4390.0
# ---------- 51250 / 125000 ----------
# Num Games: 2995
# Num Frames: 2049960
# FPS: 353
# ETA: 2:19:08
# SMA Length: 816.135
# SMA Reward: 1339.7
# SMA Entropy: 0.5393670423328877
# SMA Loss: 1.1954962073941715
# SMA PG Loss: -0.00311366600333713
# SMA V Loss: 2.4080070706270633
# Max reward: 4390.0
# ---------- 51500 / 125000 ----------
# Num Games: 3010
# Num Frames: 2059960
# FPS: 353
# ETA: 2:18:40
# SMA Length: 811.815
# SMA Reward: 1346.15
# SMA Entropy: 0.5829322667419911
# SMA Loss: 1.0206548726640177
# SMA PG Loss: 0.034007257178018335
# SMA V Loss: 1.984953857716173
# Max reward: 4390.0
# ---------- 51750 / 125000 ----------
# Num Games: 3022
# Num Frames: 2069960
# FPS: 353
# ETA: 2:18:11
# SMA Length: 803.42
# SMA Reward: 1322.75
# SMA Entropy: 0.5889536037482321
# SMA Loss: 1.1011779889732134
# SMA PG Loss: -0.02391650328929245
# SMA V Loss: 2.2619680336490275
# Max reward: 4390.0
# ---------- 52000 / 125000 ----------
# Num Games: 3037
# Num Frames: 2079960
# FPS: 353
# ETA: 2:17:42
# SMA Length: 787.08
# SMA Reward: 1291.3
# SMA Entropy: 0.45094684636220334
# SMA Loss: 1.1752405334962532
# SMA PG Loss: -0.02200570408225758
# SMA V Loss: 2.4035114410333334
# Max reward: 4390.0
# ---------- 52250 / 125000 ----------
# Num Games: 3050
# Num Frames: 2089960
# FPS: 353
# ETA: 2:17:13
# SMA Length: 777.13
# SMA Reward: 1293.5
# SMA Entropy: 0.5773850794136525
# SMA Loss: 1.6479535560170189
# SMA PG Loss: -0.006539667947799898
# SMA V Loss: 3.3205341244116426
# Max reward: 4390.0
# ---------- 52500 / 125000 ----------
# Num Games: 3063
# Num Frames: 2099960
# FPS: 353
# ETA: 2:16:45
# SMA Length: 767.33
# SMA Reward: 1281.25
# SMA Entropy: 0.5916092244163156
# SMA Loss: 1.12966594515834
# SMA PG Loss: -0.01940385728579713
# SMA V Loss: 2.3099717565812172
# Max reward: 4390.0
# ---------- 52750 / 125000 ----------
# Num Games: 3077
# Num Frames: 2109960
# FPS: 353
# ETA: 2:16:16
# SMA Length: 767.25
# SMA Reward: 1289.65
# SMA Entropy: 0.5259319234266877
# SMA Loss: 1.11791951949941
# SMA PG Loss: 0.0012015483307186514
# SMA V Loss: 2.2439546264894306
# Max reward: 4390.0
# ---------- 53000 / 125000 ----------
# Num Games: 3091
# Num Frames: 2119960
# FPS: 353
# ETA: 2:15:47
# SMA Length: 760.835
# SMA Reward: 1282.2
# SMA Entropy: 0.5697243214771152
# SMA Loss: 1.19209169030888
# SMA PG Loss: -0.005577962801326066
# SMA V Loss: 2.406733767800033
# Max reward: 4390.0
# ---------- 53250 / 125000 ----------
# Num Games: 3107
# Num Frames: 2129960
# FPS: 353
# ETA: 2:15:18
# SMA Length: 751.195
# SMA Reward: 1245.5
# SMA Entropy: 0.6345270881801843
# SMA Loss: 0.9353813739283942
# SMA PG Loss: -0.0036687767424155027
# SMA V Loss: 1.8907908594980836
# Max reward: 4390.0
# ---------- 53500 / 125000 ----------
# Num Games: 3124
# Num Frames: 2139960
# FPS: 353
# ETA: 2:14:50
# SMA Length: 729.62
# SMA Reward: 1200.5
# SMA Entropy: 0.4942779663577676
# SMA Loss: 0.9500035207974724
# SMA PG Loss: 0.046862679536279754
# SMA V Loss: 1.8161672309041024
# Max reward: 4390.0
# ---------- 53750 / 125000 ----------
# Num Games: 3139
# Num Frames: 2149960
# FPS: 353
# ETA: 2:14:21
# SMA Length: 722.635
# SMA Reward: 1190.1
# SMA Entropy: 0.505940452888608
# SMA Loss: 0.9558670312771573
# SMA PG Loss: 0.05973873931536218
# SMA V Loss: 1.802375412620604
# Max reward: 4390.0
# ---------- 54000 / 125000 ----------
# Num Games: 3155
# Num Frames: 2159960
# FPS: 353
# ETA: 2:13:53
# SMA Length: 721.835
# SMA Reward: 1180.25
# SMA Entropy: 0.6530434137582779
# SMA Loss: 1.2533945221127942
# SMA PG Loss: 0.011500149813946337
# SMA V Loss: 2.496849622540176
# Max reward: 4390.0
# ---------- 54250 / 125000 ----------
# Num Games: 3166
# Num Frames: 2169960
# FPS: 353
# ETA: 2:13:24
# SMA Length: 720.14
# SMA Reward: 1175.7
# SMA Entropy: 0.5487663986161351
# SMA Loss: 1.076806677915156
# SMA PG Loss: 0.010571870124840644
# SMA V Loss: 2.143444940149784
# Max reward: 4390.0
# ---------- 54500 / 125000 ----------
# Num Games: 3177
# Num Frames: 2179960
# FPS: 353
# ETA: 2:12:55
# SMA Length: 720.85
# SMA Reward: 1163.55
# SMA Entropy: 0.5044541548192502
# SMA Loss: 1.0691054481698665
# SMA PG Loss: 0.0015434783583623357
# SMA V Loss: 2.1452130753919483
# Max reward: 4390.0
# ---------- 54750 / 125000 ----------
# Num Games: 3189
# Num Frames: 2189960
# FPS: 353
# ETA: 2:12:26
# SMA Length: 723.225
# SMA Reward: 1159.65
# SMA Entropy: 0.5691429647803307
# SMA Loss: 1.263463477496989
# SMA PG Loss: 0.045286956752534024
# SMA V Loss: 2.4477359202504156
# Max reward: 4390.0
# ---------- 55000 / 125000 ----------
# Num Games: 3199
# Num Frames: 2199960
# FPS: 353
# ETA: 2:11:58
# SMA Length: 726.71
# SMA Reward: 1167.9
# SMA Entropy: 0.6029289833456278
# SMA Loss: 0.8703768478846178
# SMA PG Loss: 0.024953452329536958
# SMA V Loss: 1.7029053958132863
# Max reward: 4390.0
# ---------- 55250 / 125000 ----------
# Num Games: 3212
# Num Frames: 2209960
# FPS: 353
# ETA: 2:11:28
# SMA Length: 734.235
# SMA Reward: 1174.3
# SMA Entropy: 0.49291992507874965
# SMA Loss: 1.2924374007433652
# SMA PG Loss: 0.01564784692978719
# SMA V Loss: 2.5634375671111047
# Max reward: 4390.0
# ---------- 55500 / 125000 ----------
# Num Games: 3225
# Num Frames: 2219960
# FPS: 353
# ETA: 2:11:00
# SMA Length: 745.895
# SMA Reward: 1185.1
# SMA Entropy: 0.6117989268153906
# SMA Loss: 1.434979160381481
# SMA PG Loss: 0.05271731118904427
# SMA V Loss: 2.776759673226625
# Max reward: 4390.0
# ---------- 55750 / 125000 ----------
# Num Games: 3237
# Num Frames: 2229960
# FPS: 353
# ETA: 2:10:32
# SMA Length: 754.28
# SMA Reward: 1199.25
# SMA Entropy: 0.6626632823050023
# SMA Loss: 0.9885237387754023
# SMA PG Loss: 0.021962084754777608
# SMA V Loss: 1.9463765630126
# Max reward: 4390.0
# ---------- 56000 / 125000 ----------
# Num Games: 3248
# Num Frames: 2239960
# FPS: 353
# ETA: 2:10:03
# SMA Length: 753.65
# SMA Reward: 1196.4
# SMA Entropy: 0.6798468080163002
# SMA Loss: 1.1368581494805403
# SMA PG Loss: 0.02094604958037962
# SMA V Loss: 2.2454211410880087
# Max reward: 4390.0
# ---------- 56250 / 125000 ----------
# Num Games: 3261
# Num Frames: 2249960
# FPS: 353
# ETA: 2:09:35
# SMA Length: 759.76
# SMA Reward: 1225.25
# SMA Entropy: 0.6240527422726154
# SMA Loss: 1.0989922972163186
# SMA PG Loss: 0.024777616036735707
# SMA V Loss: 2.1609104055166246
# Max reward: 4390.0
# ---------- 56500 / 125000 ----------
# Num Games: 3274
# Num Frames: 2259960
# FPS: 353
# ETA: 2:09:08
# SMA Length: 762.875
# SMA Reward: 1230.25
# SMA Entropy: 0.5073905470967293
# SMA Loss: 1.1460885749279988
# SMA PG Loss: 0.015441362374695018
# SMA V Loss: 2.2714422799274328
# Max reward: 4390.0
# ---------- 56750 / 125000 ----------
# Num Games: 3287
# Num Frames: 2269960
# FPS: 353
# ETA: 2:08:40
# SMA Length: 764.67
# SMA Reward: 1231.15
# SMA Entropy: 0.5965805760025978
# SMA Loss: 1.317840429681819
# SMA PG Loss: 0.013402777801529738
# SMA V Loss: 2.6208069057017567
# Max reward: 4390.0
# ---------- 57000 / 125000 ----------
# Num Games: 3300
# Num Frames: 2279960
# FPS: 353
# ETA: 2:08:12
# SMA Length: 772.82
# SMA Reward: 1252.85
# SMA Entropy: 0.6493316236883402
# SMA Loss: 0.9665213071717881
# SMA PG Loss: 0.042673829020932315
# SMA V Loss: 1.8606815826892853
# Max reward: 4390.0
# ---------- 57250 / 125000 ----------
# Num Games: 3311
# Num Frames: 2289960
# FPS: 353
# ETA: 2:07:44
# SMA Length: 785.34
# SMA Reward: 1299.35
# SMA Entropy: 0.6228363485634327
# SMA Loss: 1.0464302458625752
# SMA PG Loss: 0.017721450612007174
# SMA V Loss: 2.0698743325099347
# Max reward: 4390.0
# ---------- 57500 / 125000 ----------
# Num Games: 3324
# Num Frames: 2299960
# FPS: 353
# ETA: 2:07:16
# SMA Length: 801.3
# SMA Reward: 1330.55
# SMA Entropy: 0.5946591877937317
# SMA Loss: 1.3480389157496393
# SMA PG Loss: 0.021078834279032888
# SMA V Loss: 2.6658133664540946
# Max reward: 4390.0
# ---------- 57750 / 125000 ----------
# Num Games: 3339
# Num Frames: 2309960
# FPS: 353
# ETA: 2:06:48
# SMA Length: 803.775
# SMA Reward: 1329.75
# SMA Entropy: 0.5598424269258976
# SMA Loss: 1.3287041796417907
# SMA PG Loss: 0.027303215650608764
# SMA V Loss: 2.6139987621456386
# Max reward: 4390.0
# ---------- 58000 / 125000 ----------
# Num Games: 3351
# Num Frames: 2319960
# FPS: 353
# ETA: 2:06:19
# SMA Length: 800.455
# SMA Reward: 1334.5
# SMA Entropy: 0.46842551793903114
# SMA Loss: 0.9974757847120054
# SMA PG Loss: 0.0054101175430696456
# SMA V Loss: 1.9934998581558465
# Max reward: 4390.0
# ---------- 58250 / 125000 ----------
# Num Games: 3366
# Num Frames: 2329960
# FPS: 353
# ETA: 2:05:51
# SMA Length: 801.74
# SMA Reward: 1332.6
# SMA Entropy: 0.521437825486064
# SMA Loss: 0.9198314098047559
# SMA PG Loss: -0.005805591773823835
# SMA V Loss: 1.861702765263617
# Max reward: 4390.0
# ---------- 58500 / 125000 ----------
# Num Games: 3377
# Num Frames: 2339960
# FPS: 353
# ETA: 2:05:23
# SMA Length: 803.235
# SMA Reward: 1344.6
# SMA Entropy: 0.7224669070541858
# SMA Loss: 0.9460985001665541
# SMA PG Loss: 0.024905969148530858
# SMA V Loss: 1.856834376193583
# Max reward: 4390.0
# ---------- 58750 / 125000 ----------
# Num Games: 3391
# Num Frames: 2349960
# FPS: 353
# ETA: 2:04:54
# SMA Length: 799.14
# SMA Reward: 1355.3
# SMA Entropy: 0.643638257086277
# SMA Loss: 1.3606053454848006
# SMA PG Loss: 0.04822418612726324
# SMA V Loss: 2.6376350986212493
# Max reward: 4390.0
# ---------- 59000 / 125000 ----------
# Num Games: 3403
# Num Frames: 2359960
# FPS: 353
# ETA: 2:04:26
# SMA Length: 788.55
# SMA Reward: 1337.45
# SMA Entropy: 0.5540270398557187
# SMA Loss: 1.466206428183941
# SMA PG Loss: 0.043732261826080504
# SMA V Loss: 2.8560288497433066
# Max reward: 4390.0
# ---------- 59250 / 125000 ----------
# Num Games: 3415
# Num Frames: 2369960
# FPS: 353
# ETA: 2:03:57
# SMA Length: 785.355
# SMA Reward: 1347.9
# SMA Entropy: 0.5450750912725926
# SMA Loss: 1.0893622260773554
# SMA PG Loss: 0.04808692984981462
# SMA V Loss: 2.093452069610357
# Max reward: 4390.0
# ---------- 59500 / 125000 ----------
# Num Games: 3429
# Num Frames: 2379960
# FPS: 353
# ETA: 2:03:29
# SMA Length: 777.11
# SMA Reward: 1346.2
# SMA Entropy: 0.5691572377085685
# SMA Loss: 1.1477649328648112
# SMA PG Loss: 0.058890318267513064
# SMA V Loss: 2.1891323728859424
# Max reward: 4390.0
# ---------- 59750 / 125000 ----------
# Num Games: 3442
# Num Frames: 2389960
# FPS: 353
# ETA: 2:03:00
# SMA Length: 777.71
# SMA Reward: 1347.4
# SMA Entropy: 0.5001743106544018
# SMA Loss: 1.0021094382018783
# SMA PG Loss: 0.020879044809407787
# SMA V Loss: 1.9724642523378133
# Max reward: 4390.0
# ---------- 60000 / 125000 ----------
# Num Games: 3453
# Num Frames: 2399960
# FPS: 353
# ETA: 2:02:32
# SMA Length: 779.13
# SMA Reward: 1337.95
# SMA Entropy: 0.4891707647591829
# SMA Loss: 0.9006643584161066
# SMA PG Loss: 0.007497632132726722
# SMA V Loss: 1.796116849537939
# Max reward: 4390.0
# ---------- 60250 / 125000 ----------
# Num Games: 3463
# Num Frames: 2409960
# FPS: 353
# ETA: 2:02:03
# SMA Length: 785.29
# SMA Reward: 1349.05
# SMA Entropy: 0.5803156372532249
# SMA Loss: 0.925202536325669
# SMA PG Loss: 0.03984441378379415
# SMA V Loss: 1.7823225417360664
# Max reward: 4390.0
# ---------- 60500 / 125000 ----------
# Num Games: 3475
# Num Frames: 2419960
# FPS: 353
# ETA: 2:01:34
# SMA Length: 794.23
# SMA Reward: 1352.75
# SMA Entropy: 0.5007501737773419
# SMA Loss: 0.867096551018767
# SMA PG Loss: -0.0215408954569466
# SMA V Loss: 1.7872898886352777
# Max reward: 4390.0
# ---------- 60750 / 125000 ----------
# Num Games: 3490
# Num Frames: 2429960
# FPS: 353
# ETA: 2:01:06
# SMA Length: 791.94
# SMA Reward: 1349.35
# SMA Entropy: 0.4605829007178545
# SMA Loss: 1.2899063228094019
# SMA PG Loss: 0.03456017247532145
# SMA V Loss: 2.519903982579708
# Max reward: 4390.0
# ---------- 61000 / 125000 ----------
# Num Games: 3500
# Num Frames: 2439960
# FPS: 353
# ETA: 2:00:37
# SMA Length: 795.115
# SMA Reward: 1346.65
# SMA Entropy: 0.5609757986664772
# SMA Loss: 1.0072228876245208
# SMA PG Loss: 0.032657918152690396
# SMA V Loss: 1.9603494581580163
# Max reward: 4390.0
# ---------- 61250 / 125000 ----------
# Num Games: 3514
# Num Frames: 2449960
# FPS: 353
# ETA: 2:00:09
# SMA Length: 794.665
# SMA Reward: 1323.3
# SMA Entropy: 0.5281894133612514
# SMA Loss: 1.3788569708773866
# SMA PG Loss: 0.06192817155562807
# SMA V Loss: 2.6444213792309164
# Max reward: 4390.0
# ---------- 61500 / 125000 ----------
# Num Games: 3526
# Num Frames: 2459960
# FPS: 353
# ETA: 1:59:40
# SMA Length: 796.675
# SMA Reward: 1323.25
# SMA Entropy: 0.6238125777989626
# SMA Loss: 1.3718001092784107
# SMA PG Loss: 0.022641344654839485
# SMA V Loss: 2.710793793015182
# Max reward: 4390.0
# ---------- 61750 / 125000 ----------
# Num Games: 3536
# Num Frames: 2469960
# FPS: 353
# ETA: 1:59:11
# SMA Length: 805.255
# SMA Reward: 1344.6
# SMA Entropy: 0.5656910452246666
# SMA Loss: 1.4215591890993529
# SMA PG Loss: 0.004619182015521801
# SMA V Loss: 2.845193839520216
# Max reward: 4390.0
# ---------- 62000 / 125000 ----------
# Num Games: 3548
# Num Frames: 2479960
# FPS: 353
# ETA: 1:58:43
# SMA Length: 814.53
# SMA Reward: 1344.0
# SMA Entropy: 0.5186980376765132
# SMA Loss: 0.9593810406792909
# SMA PG Loss: -0.008937494839774445
# SMA V Loss: 1.9470110320299865
# Max reward: 4390.0
# ---------- 62250 / 125000 ----------
# Num Games: 3561
# Num Frames: 2489960
# FPS: 353
# ETA: 1:58:14
# SMA Length: 817.005
# SMA Reward: 1361.9
# SMA Entropy: 0.518210388571024
# SMA Loss: 1.276563918449683
# SMA PG Loss: 0.017689322246005758
# SMA V Loss: 2.528113447781652
# Max reward: 4390.0
# ---------- 62500 / 125000 ----------
# Num Games: 3573
# Num Frames: 2499960
# FPS: 353
# ETA: 1:57:45
# SMA Length: 817.53
# SMA Reward: 1360.2
# SMA Entropy: 0.5639568528532982
# SMA Loss: 0.9483555170032196
# SMA PG Loss: -0.031462264790316115
# SMA V Loss: 1.9709147300571204
# Max reward: 4390.0
# ---------- 62750 / 125000 ----------
# Num Games: 3585
# Num Frames: 2509960
# FPS: 353
# ETA: 1:57:17
# SMA Length: 820.29
# SMA Reward: 1353.35
# SMA Entropy: 0.6016520001739264
# SMA Loss: 1.0890755252295639
# SMA PG Loss: 0.01737109281355515
# SMA V Loss: 2.155441916286945
# Max reward: 4390.0
# ---------- 63000 / 125000 ----------
# Num Games: 3594
# Num Frames: 2519960
# FPS: 353
# ETA: 1:56:48
# SMA Length: 833.38
# SMA Reward: 1367.8
# SMA Entropy: 0.7287073089182377
# SMA Loss: 1.0873829759750515
# SMA PG Loss: -0.015028628086438402
# SMA V Loss: 2.219397345688194
# Max reward: 4390.0
# ---------- 63250 / 125000 ----------
# Num Games: 3606
# Num Frames: 2529960
# FPS: 353
# ETA: 1:56:19
# SMA Length: 839.26
# SMA Reward: 1364.0
# SMA Entropy: 0.44623860850930214
# SMA Loss: 0.8803823458403349
# SMA PG Loss: -0.006330510307452642
# SMA V Loss: 1.7823504975438118
# Max reward: 4390.0
# ---------- 63500 / 125000 ----------
# Num Games: 3617
# Num Frames: 2539960
# FPS: 353
# ETA: 1:55:51
# SMA Length: 848.92
# SMA Reward: 1376.35
# SMA Entropy: 0.5519830284267664
# SMA Loss: 1.3205462683783844
# SMA PG Loss: 0.005585103494813666
# SMA V Loss: 2.6409620236605407
# Max reward: 4390.0
# ---------- 63750 / 125000 ----------
# Num Games: 3630
# Num Frames: 2549960
# FPS: 353
# ETA: 1:55:22
# SMA Length: 857.79
# SMA Reward: 1385.1
# SMA Entropy: 0.47491602655500176
# SMA Loss: 1.2805190813285299
# SMA PG Loss: -0.015794989770511164
# SMA V Loss: 2.602126441504806
# Max reward: 4390.0
# ---------- 64000 / 125000 ----------
# Num Games: 3642
# Num Frames: 2559960
# FPS: 353
# ETA: 1:54:54
# SMA Length: 858.12
# SMA Reward: 1371.65
# SMA Entropy: 0.5428730389475822
# SMA Loss: 1.4674308557785116
# ...
# SMA Entropy: 0.6567692886292934
# SMA Loss: 1.3324178949464112
# SMA PG Loss: 0.0818170046096202
# SMA V Loss: 2.5143371680378914
# Max reward: 4390.0
# ---------- 111000 / 125000 ----------
# Num Games: 5773
# Num Frames: 4439960
# FPS: 365
# ETA: 0:25:33
# SMA Length: 901.45
# SMA Reward: 1831.3
# SMA Entropy: 0.6659112686291337
# SMA Loss: 1.6752073793159798
# SMA PG Loss: 0.16649403326184256
# SMA V Loss: 3.030744942501187
# Max reward: 4390.0
# ---------- 111250 / 125000 ----------
# Num Games: 5783
# Num Frames: 4449960
# FPS: 365
# ETA: 0:25:05
# SMA Length: 896.565
# SMA Reward: 1810.95
# SMA Entropy: 0.5743492434918881
# SMA Loss: 1.6743025968107395
# SMA PG Loss: 0.09902758317621192
# SMA V Loss: 3.162037021368742
# Max reward: 4390.0
# ---------- 111500 / 125000 ----------
# Num Games: 5793
# Num Frames: 4459960
# FPS: 365
# ETA: 0:24:38
# SMA Length: 897.73
# SMA Reward: 1802.5
# SMA Entropy: 0.6091622045636177
# SMA Loss: 1.3402812384092249
# SMA PG Loss: 0.11306661326787434
# SMA V Loss: 2.466612494327128
# Max reward: 4390.0
# ---------- 111750 / 125000 ----------
# Num Games: 5804
# Num Frames: 4469960
# FPS: 365
# ETA: 0:24:10
# SMA Length: 897.765
# SMA Reward: 1809.0
# SMA Entropy: 0.5649442505463957
# SMA Loss: 1.370501875883201
# SMA PG Loss: 0.09128905692341505
# SMA V Loss: 2.569724585432559
# Max reward: 4390.0
# ---------- 112000 / 125000 ----------
# Num Games: 5819
# Num Frames: 4479960
# FPS: 365
# ETA: 0:23:43
# SMA Length: 888.465
# SMA Reward: 1783.3
# SMA Entropy: 0.525932769626379
# SMA Loss: 1.6982795567135327
# SMA PG Loss: 0.1373282963327074
# SMA V Loss: 3.132421202734113
# Max reward: 4390.0
# ---------- 112250 / 125000 ----------
# Num Games: 5831
# Num Frames: 4489960
# FPS: 365
# ETA: 0:23:15
# SMA Length: 895.235
# SMA Reward: 1796.15
# SMA Entropy: 0.6643603694811463
# SMA Loss: 1.6545486006047576
# SMA PG Loss: 0.07816584787753528
# SMA V Loss: 3.1660526941530405
# Max reward: 4390.0
# ---------- 112500 / 125000 ----------
# Num Games: 5847
# Num Frames: 4499960
# FPS: 365
# ETA: 0:22:47
# SMA Length: 879.43
# SMA Reward: 1756.8
# SMA Entropy: 0.5653209400549531
# SMA Loss: 1.6479690189566463
# SMA PG Loss: 0.1276502689512563
# SMA V Loss: 3.051943928580731
# Max reward: 4390.0
# ---------- 112750 / 125000 ----------
# Num Games: 5857
# Num Frames: 4509960
# FPS: 365
# ETA: 0:22:20
# SMA Length: 873.425
# SMA Reward: 1739.65
# SMA Entropy: 0.5868428260833025
# SMA Loss: 1.1991622343380004
# SMA PG Loss: 0.09130109084755532
# SMA V Loss: 2.22745914356783
# Max reward: 4390.0
# ---------- 113000 / 125000 ----------
# Num Games: 5870
# Num Frames: 4519960
# FPS: 365
# ETA: 0:21:52
# SMA Length: 860.53
# SMA Reward: 1688.2
# SMA Entropy: 0.5432444496452808
# SMA Loss: 1.4120621698372997
# SMA PG Loss: 0.11718636216101004
# SMA V Loss: 2.600616488829255
# Max reward: 4390.0
# ---------- 113250 / 125000 ----------
# Num Games: 5883
# Num Frames: 4529960
# FPS: 365
# ETA: 0:21:25
# SMA Length: 860.12
# SMA Reward: 1669.55
# SMA Entropy: 0.6861402270197868
# SMA Loss: 1.187668178770691
# SMA PG Loss: 0.09367764897448069
# SMA V Loss: 2.2017038920894265
# Max reward: 4390.0
# ---------- 113500 / 125000 ----------
# Num Games: 5892
# Num Frames: 4539960
# FPS: 365
# ETA: 0:20:57
# SMA Length: 860.08
# SMA Reward: 1653.1
# SMA Entropy: 0.7075326769519598
# SMA Loss: 1.005734751834534
# SMA PG Loss: 0.08564356867296738
# SMA V Loss: 1.8543330110237002
# Max reward: 4390.0
# ---------- 113750 / 125000 ----------
# Num Games: 5905
# Num Frames: 4549960
# FPS: 365
# ETA: 0:20:30
# SMA Length: 846.795
# SMA Reward: 1620.4
# SMA Entropy: 0.5718925239890814
# SMA Loss: 1.5541085224831477
# SMA PG Loss: 0.1375596703874544
# SMA V Loss: 2.844535532519221
# Max reward: 4390.0
# ---------- 114000 / 125000 ----------
# Num Games: 5917
# Num Frames: 4559960
# FPS: 365
# ETA: 0:20:02
# SMA Length: 836.59
# SMA Reward: 1592.95
# SMA Entropy: 0.6191239838674665
# SMA Loss: 1.3141839252691716
# SMA PG Loss: 0.07628367924698978
# SMA V Loss: 2.488182967398316
# Max reward: 4390.0
# ---------- 114250 / 125000 ----------
# Num Games: 5928
# Num Frames: 4569960
# FPS: 365
# ETA: 0:19:35
# SMA Length: 842.645
# SMA Reward: 1581.95
# SMA Entropy: 0.6619421270489693
# SMA Loss: 1.064806810247246
# SMA PG Loss: 0.06824469315135502
# SMA V Loss: 2.0063630574569107
# Max reward: 4390.0
# ---------- 114500 / 125000 ----------
# Num Games: 5937
# Num Frames: 4579960
# FPS: 366
# ETA: 0:19:07
# SMA Length: 847.375
# SMA Reward: 1583.5
# SMA Entropy: 0.6646605604887008
# SMA Loss: 1.0931737196468747
# SMA PG Loss: 0.09358213084255113
# SMA V Loss: 2.012476348541677
# Max reward: 4390.0
# ---------- 114750 / 125000 ----------
# Num Games: 5950
# Num Frames: 4589960
# FPS: 366
# ETA: 0:18:40
# SMA Length: 847.75
# SMA Reward: 1588.85
# SMA Entropy: 0.6611828522942961
# SMA Loss: 1.1985838749934918
# SMA PG Loss: 0.07570763194496977
# SMA V Loss: 2.2589761530049146
# Max reward: 4390.0
# ---------- 115000 / 125000 ----------
# Num Games: 5960
# Num Frames: 4599960
# FPS: 366
# ETA: 0:18:12
# SMA Length: 850.33
# SMA Reward: 1579.15
# SMA Entropy: 0.6341329534351826
# SMA Loss: 1.3392095242324284
# SMA PG Loss: 0.08230117962812074
# SMA V Loss: 2.5264993599802255
# Max reward: 4390.0
# ---------- 115250 / 125000 ----------
# Num Games: 5971
# Num Frames: 4609960
# FPS: 366
# ETA: 0:17:45
# SMA Length: 849.395
# SMA Reward: 1578.1
# SMA Entropy: 0.6659252716600895
# SMA Loss: 1.2832920683384872
# SMA PG Loss: 0.08419518131832775
# SMA V Loss: 2.4115122497454284
# Max reward: 4390.0
# ---------- 115500 / 125000 ----------
# Num Games: 5982
# Num Frames: 4619960
# FPS: 366
# ETA: 0:17:17
# SMA Length: 857.975
# SMA Reward: 1599.75
# SMA Entropy: 0.7055246614664793
# SMA Loss: 1.2043591989390552
# SMA PG Loss: 0.1143160579178948
# SMA V Loss: 2.1941967762075363
# Max reward: 4390.0
# ---------- 115750 / 125000 ----------
# Num Games: 5993
# Num Frames: 4629960
# FPS: 366
# ETA: 0:16:50
# SMA Length: 861.65
# SMA Reward: 1607.9
# SMA Entropy: 0.6897010796144605
# SMA Loss: 0.9687507783679757
# SMA PG Loss: 0.05932996174728032
# SMA V Loss: 1.832635651100427
# Max reward: 4390.0
# ---------- 116000 / 125000 ----------
# Num Games: 6003
# Num Frames: 4639960
# FPS: 366
# ETA: 0:16:22
# SMA Length: 865.08
# SMA Reward: 1634.3
# SMA Entropy: 0.669872948974371
# SMA Loss: 1.289718494520057
# SMA PG Loss: 0.12699985436047428
# SMA V Loss: 2.3388347708433868
# Max reward: 4570.0
# ---------- 116250 / 125000 ----------
# Num Games: 6013
# Num Frames: 4649960
# FPS: 366
# ETA: 0:15:55
# SMA Length: 871.875
# SMA Reward: 1644.1
# SMA Entropy: 0.7729805861413479
# SMA Loss: 1.3795694639836438
# SMA PG Loss: 0.11964977470430313
# SMA V Loss: 2.53529895786196
# Max reward: 4570.0
# ---------- 116500 / 125000 ----------
# Num Games: 6023
# Num Frames: 4659960
# FPS: 366
# ETA: 0:15:27
# SMA Length: 875.22
# SMA Reward: 1660.65
# SMA Entropy: 0.6646522372215986
# SMA Loss: 0.8760431416635401
# SMA PG Loss: 0.046264694461424366
# SMA V Loss: 1.6728499297611414
# Max reward: 4570.0
# ---------- 116750 / 125000 ----------
# Num Games: 6034
# Num Frames: 4669960
# FPS: 366
# ETA: 0:15:00
# SMA Length: 891.99
# SMA Reward: 1685.3
# SMA Entropy: 0.8176238144934177
# SMA Loss: 1.0033600655500776
# SMA PG Loss: 0.06646878422936425
# SMA V Loss: 1.8901350119896234
# Max reward: 4570.0
# ---------- 117000 / 125000 ----------
# Num Games: 6044
# Num Frames: 4679960
# FPS: 366
# ETA: 0:14:32
# SMA Length: 899.34
# SMA Reward: 1691.75
# SMA Entropy: 0.5793122012913227
# SMA Loss: 1.3418611597060226
# SMA PG Loss: 0.11939285115393432
# SMA V Loss: 2.4565228939428927
# Max reward: 4570.0
# ---------- 117250 / 125000 ----------
# Num Games: 6059
# Num Frames: 4689960
# FPS: 366
# ETA: 0:14:05
# SMA Length: 902.475
# SMA Reward: 1686.05
# SMA Entropy: 0.6018508349359035
# SMA Loss: 1.5844351333589293
# SMA PG Loss: 0.07208854013726523
# SMA V Loss: 3.0367302664741875
# Max reward: 4570.0
# ---------- 117500 / 125000 ----------
# Num Games: 6067
# Num Frames: 4699960
# FPS: 366
# ETA: 0:13:38
# SMA Length: 910.82
# SMA Reward: 1703.5
# SMA Entropy: 0.6890962612628937
# SMA Loss: 1.1053715035901406
# SMA PG Loss: 0.09599098724400391
# SMA V Loss: 2.032542951721698
# Max reward: 4570.0
# ---------- 117750 / 125000 ----------
# Num Games: 6076
# Num Frames: 4709960
# FPS: 366
# ETA: 0:13:10
# SMA Length: 914.55
# SMA Reward: 1719.15
# SMA Entropy: 0.6688583771139384
# SMA Loss: 1.1892359711340397
# SMA PG Loss: 0.09957506278304208
# SMA V Loss: 2.192698990087956
# Max reward: 4570.0
# ---------- 118000 / 125000 ----------
# Num Games: 6088
# Num Frames: 4719960
# FPS: 366
# ETA: 0:12:43
# SMA Length: 920.165
# SMA Reward: 1726.3
# SMA Entropy: 0.6688407401740551
# SMA Loss: 0.921195929790847
# SMA PG Loss: 0.04015054750663694
# SMA V Loss: 1.7754675604775547
# Max reward: 4570.0
# ---------- 118250 / 125000 ----------
# Num Games: 6099
# Num Frames: 4729960
# FPS: 366
# ETA: 0:12:15
# SMA Length: 925.505
# SMA Reward: 1741.3
# SMA Entropy: 0.742375454455614
# SMA Loss: 1.1747432693070732
# SMA PG Loss: 0.07677555002279406
# SMA V Loss: 2.210782925579697
# Max reward: 4570.0
# ---------- 118500 / 125000 ----------
# Num Games: 6111
# Num Frames: 4739960
# FPS: 367
# ETA: 0:11:48
# SMA Length: 930.49
# SMA Reward: 1750.25
# SMA Entropy: 0.5913395819813013
# SMA Loss: 1.7574475157959386
# SMA PG Loss: 0.14144807802746073
# SMA V Loss: 3.243825702890754
# Max reward: 4570.0
# ---------- 118750 / 125000 ----------
# Num Games: 6122
# Num Frames: 4749960
# FPS: 367
# ETA: 0:11:21
# SMA Length: 927.09
# SMA Reward: 1751.8
# SMA Entropy: 0.6463381564989686
# SMA Loss: 1.7023671593237668
# SMA PG Loss: 0.12247848417959176
# SMA V Loss: 3.172704091519117
# Max reward: 4570.0
# ---------- 119000 / 125000 ----------
# Num Games: 6135
# Num Frames: 4759960
# FPS: 367
# ETA: 0:10:53
# SMA Length: 919.345
# SMA Reward: 1750.0
# SMA Entropy: 0.5300924918800592
# SMA Loss: 1.2646810472314245
# SMA PG Loss: 0.1195593496793299
# SMA V Loss: 2.3008451775927097
# Max reward: 4570.0
# ---------- 119250 / 125000 ----------
# Num Games: 6144
# Num Frames: 4769960
# FPS: 367
# ETA: 0:10:26
# SMA Length: 927.145
# SMA Reward: 1749.4
# SMA Entropy: 0.86141398742795
# SMA Loss: 1.0305460950394627
# SMA PG Loss: 0.06599613269674592
# SMA V Loss: 1.9463281963765622
# Max reward: 4570.0
# ---------- 119500 / 125000 ----------
# Num Games: 6154
# Num Frames: 4779960
# FPS: 367
# ETA: 0:09:59
# SMA Length: 925.4
# SMA Reward: 1744.75
# SMA Entropy: 0.6650307847559452
# SMA Loss: 1.347748946149368
# SMA PG Loss: 0.13077207957059728
# SMA V Loss: 2.447254350874573
# Max reward: 4570.0
# ---------- 119750 / 125000 ----------
# Num Games: 6167
# Num Frames: 4789960
# FPS: 367
# ETA: 0:09:31
# SMA Length: 922.545
# SMA Reward: 1731.35
# SMA Entropy: 0.6762437070906162
# SMA Loss: 1.4523296837857924
# SMA PG Loss: 0.12654094774625263
# SMA V Loss: 2.6651023678854107
# Max reward: 4570.0
# ---------- 120000 / 125000 ----------
# Num Games: 6178
# Num Frames: 4799960
# FPS: 367
# ETA: 0:09:04
# SMA Length: 917.375
# SMA Reward: 1725.8
# SMA Entropy: 0.6842984264343976
# SMA Loss: 1.1088865422597154
# SMA PG Loss: 0.07697324887216382
# SMA V Loss: 2.0775125507079064
# Max reward: 4570.0
# ---------- 120250 / 125000 ----------
# Num Games: 6191
# Num Frames: 4809960
# FPS: 367
# ETA: 0:08:37
# SMA Length: 915.55
# SMA Reward: 1729.55
# SMA Entropy: 0.6391575684398413
# SMA Loss: 1.4883768472936936
# SMA PG Loss: 0.12890224237577058
# SMA V Loss: 2.7317323352210225
# Max reward: 4570.0
# ---------- 120500 / 125000 ----------
# Num Games: 6200
# Num Frames: 4819960
# FPS: 367
# ETA: 0:08:09
# SMA Length: 918.51
# SMA Reward: 1722.0
# SMA Entropy: 0.8138323977589608
# SMA Loss: 0.9252739753760397
# SMA PG Loss: 0.05328402237966657
# SMA V Loss: 1.7602565836720168
# Max reward: 4570.0
# ---------- 120750 / 125000 ----------
# Num Games: 6212
# Num Frames: 4829960
# FPS: 367
# ETA: 0:07:42
# SMA Length: 904.405
# SMA Reward: 1674.35
# SMA Entropy: 0.5399141159653663
# SMA Loss: 1.2835281352954917
# SMA PG Loss: 0.06977461690694327
# SMA V Loss: 2.438305353987962
# Max reward: 4570.0
# ---------- 121000 / 125000 ----------
# Num Games: 6219
# Num Frames: 4839960
# FPS: 367
# ETA: 0:07:15
# SMA Length: 906.235
# SMA Reward: 1680.5
# SMA Entropy: 0.7708044685423374
# SMA Loss: 0.7393987032002769
# SMA PG Loss: 0.06397197889651579
# SMA V Loss: 1.3662695344537497
# Max reward: 4570.0
# ---------- 121250 / 125000 ----------
# Num Games: 6233
# Num Frames: 4849960
# FPS: 367
# ETA: 0:06:48
# SMA Length: 912.395
# SMA Reward: 1697.65
# SMA Entropy: 0.7108149060234428
# SMA Loss: 0.9874177899037022
# SMA PG Loss: 0.05613069798097058
# SMA V Loss: 1.8767904995009304
# Max reward: 4570.0
# ---------- 121500 / 125000 ----------
# Num Games: 6243
# Num Frames: 4859960
# FPS: 367
# ETA: 0:06:20
# SMA Length: 912.91
# SMA Reward: 1701.8
# SMA Entropy: 0.5970075427182019
# SMA Loss: 1.035889537903713
# SMA PG Loss: 0.06308643994125304
# SMA V Loss: 1.9575463633611798
# Max reward: 4570.0
# ---------- 121750 / 125000 ----------
# Num Games: 6254
# Num Frames: 4869960
# FPS: 367
# ETA: 0:05:53
# SMA Length: 911.24
# SMA Reward: 1702.35
# SMA Entropy: 0.633193752542138
# SMA Loss: 1.6055288034956903
# SMA PG Loss: 0.1358595040877117
# SMA V Loss: 2.952002539150417
# Max reward: 4570.0
# ---------- 122000 / 125000 ----------
# Num Games: 6263
# Num Frames: 4879960
# FPS: 367
# ETA: 0:05:26
# SMA Length: 920.165
# SMA Reward: 1717.4
# SMA Entropy: 0.7269337689131499
# SMA Loss: 1.0525421650265343
# SMA PG Loss: 0.06260097982711159
# SMA V Loss: 1.9944210500083863
# Max reward: 4570.0
# ---------- 122250 / 125000 ----------
# Num Games: 6274
# Num Frames: 4889960
# FPS: 367
# ETA: 0:04:59
# SMA Length: 920.105
# SMA Reward: 1715.2
# SMA Entropy: 0.7890504409372806
# SMA Loss: 1.308889100109227
# SMA PG Loss: 0.10690967892151093
# SMA V Loss: 2.419739839490503
# Max reward: 4570.0
# ---------- 122500 / 125000 ----------
# Num Games: 6283
# Num Frames: 4899960
# FPS: 368
# ETA: 0:04:31
# SMA Length: 925.59
# SMA Reward: 1719.1
# SMA Entropy: 0.7853581438958644
# SMA Loss: 0.7629551615589298
# SMA PG Loss: 0.0585190002474701
# SMA V Loss: 1.424579499727115
# Max reward: 4570.0
# ---------- 122750 / 125000 ----------
# Num Games: 6291
# Num Frames: 4909960
# FPS: 368
# ETA: 0:04:04
# SMA Length: 929.36
# SMA Reward: 1733.55
# SMA Entropy: 0.7796230347454548
# SMA Loss: 0.9170994608826004
# SMA PG Loss: 0.090417666870635
# SMA V Loss: 1.6689560386165976
# Max reward: 4570.0
# ---------- 123000 / 125000 ----------
# Num Games: 6299
# Num Frames: 4919960
# FPS: 368
# ETA: 0:03:37
# SMA Length: 937.44
# SMA Reward: 1742.6
# SMA Entropy: 0.7233985479176045
# SMA Loss: 1.0047925097763073
# SMA PG Loss: 0.05905187913944246
# SMA V Loss: 1.9059493066649884
# Max reward: 4570.0
# ---------- 123250 / 125000 ----------
# Num Games: 6310
# Num Frames: 4929960
# FPS: 368
# ETA: 0:03:10
# SMA Length: 944.26
# SMA Reward: 1750.45
# SMA Entropy: 0.6721595897804946
# SMA Loss: 1.50320909563452
# SMA PG Loss: 0.10932729891093913
# SMA V Loss: 2.801206742189825
# Max reward: 4570.0
# ---------- 123500 / 125000 ----------
# Num Games: 6320
# Num Frames: 4939960
# FPS: 368
# ETA: 0:02:43
# SMA Length: 954.37
# SMA Reward: 1765.65
# SMA Entropy: 0.6940079171210527
# SMA Loss: 1.1153397911775391
# SMA PG Loss: 0.10873695971618873
# SMA V Loss: 2.0270858182758094
# Max reward: 4570.0
# ---------- 123750 / 125000 ----------
# Num Games: 6333
# Num Frames: 4949960
# FPS: 368
# ETA: 0:02:15
# SMA Length: 965.55
# SMA Reward: 1778.45
# SMA Entropy: 0.6850657973624766
# SMA Loss: 1.1256211606878788
# SMA PG Loss: 0.09262930355034768
# SMA V Loss: 2.0796850476041437
# Max reward: 4570.0
# ---------- 124000 / 125000 ----------
# Num Games: 6343
# Num Frames: 4959960
# FPS: 368
# ETA: 0:01:48
# SMA Length: 950.61
# SMA Reward: 1747.6
# SMA Entropy: 0.6079496280848979
# SMA Loss: 1.6664596360805444
# SMA PG Loss: 0.12897152780555188
# SMA V Loss: 3.0871351514197887
# Max reward: 4570.0
# ---------- 124250 / 125000 ----------
# Num Games: 6355
# Num Frames: 4969960
# FPS: 368
# ETA: 0:01:21
# SMA Length: 955.295
# SMA Reward: 1741.4
# SMA Entropy: 0.6823537716269493
# SMA Loss: 1.554008801598102
# SMA PG Loss: 0.1324725088484047
# SMA V Loss: 2.8567196519114075
# Max reward: 4570.0
# ---------- 124500 / 125000 ----------
# Num Games: 6364
# Num Frames: 4979960
# FPS: 368
# ETA: 0:00:54
# SMA Length: 955.435
# SMA Reward: 1745.9
# SMA Entropy: 0.7803503956645728
# SMA Loss: 0.8807005917234346
# SMA PG Loss: 0.07571085885027287
# SMA V Loss: 1.6255864603631198
# Max reward: 4570.0
# ---------- 124750 / 125000 ----------
# Num Games: 6375
# Num Frames: 4989960
# FPS: 368
# ETA: 0:00:27
# SMA Length: 962.635
# SMA Reward: 1757.15
# SMA Entropy: 0.8274663835763931
# SMA Loss: 1.3576263494160958
# SMA PG Loss: 0.10681476242694771
# SMA V Loss: 2.518172518508509
# Max reward: 4570.0
# ---------- 125000 / 125000 ----------
# Num Games: 6387
# Num Frames: 4999960
# FPS: 368
# ETA: 0:00:00
# SMA Length: 969.525
# SMA Reward: 1764.25
# SMA Entropy: 0.6145262254029512
# SMA Loss: 1.4607369653263595
# SMA PG Loss: 0.11528029893186613
# SMA V Loss: 2.703203824851662
# Max reward: 4570.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set()

# %%
def plot_log(log, ylabel):
    # compute rolling avg and std
    df = pd.DataFrame(log, columns =['Frames', 'Iters', ylabel])
    sma_y = df[ylabel].rolling(500).mean()
    std_y = df[ylabel].rolling(500).std()
    
    # plot with seaborn
    fig, ax = plt.subplots(figsize=(10,10))
    ax.set_xlabel('Frames')
    ax.set_ylabel(ylabel)
    clrs = sns.color_palette("husl", 8)

    # fill standard deviation
    ax.plot(df['Frames'], sma_y, label=ylabel, c=clrs[0])
    ax.fill_between(df['Frames'], sma_y-std_y,  sma_y+std_y, 
                    alpha=0.3, facecolor=clrs[0]) 
    ax.legend(loc='upper left')
    plt.savefig(SAVE_PATH+ENV_NAME+'.'+ylabel+'.plt.png', 
                dpi=300, pad_inches=0)
    plt.show()

plot_log(logger.log['ep_r'], 'Reward')
plot_log(logger.log['ep_l'], 'Length')
plot_log(logger.log['loss'], 'Loss')
plot_log(logger.log['ent'], 'Entropy')

# %%
fig_all, ax_all = plt.subplots(2,2, figsize=(8,8))

## REWARD 
df = pd.DataFrame(logger.log['ep_r'], columns =['Frames', 'Iters', 'rwd'])
sma_y = df['rwd'].rolling(500).mean()
std_y = df['rwd'].rolling(500).std()

ax_all[0][0].set_ylabel('Reward')
clrs = sns.color_palette("husl", 8)

# fill standard deviation
ax_all[0][0].plot(df['Frames'], sma_y, label='Episode Reward', c=clrs[0])
ax_all[0][0].fill_between(df['Frames'], sma_y-std_y,  sma_y+std_y, 
                alpha=0.3, facecolor=clrs[0])

# make x axis nice
ax_all[0][0].set_xticklabels('')


## LENGTH 
df = pd.DataFrame(logger.log['ep_l'], columns =['Frames', 'Iters', 'Len'])
sma_y = df['Len'].rolling(500).mean()
std_y = df['Len'].rolling(500).std()

ax_all[0][1].set_ylabel('Length')
ax_all[0][1].yaxis.tick_right()
clrs = sns.color_palette("husl", 8)

# fill standard deviation
ax_all[0][1].plot(df['Frames'], sma_y, label='Episode Length', c=clrs[0])
ax_all[0][1].fill_between(df['Frames'], sma_y-std_y,  sma_y+std_y, 
                alpha=0.3, facecolor=clrs[0])

# make x axis nice
ax_all[0][1].set_xticklabels('')


## ENTROPY 
df = pd.DataFrame(logger.log['ent'], columns =['Frames', 'Iters', 'ent'])
sma_y = df['ent'].rolling(500).mean()
std_y = df['ent'].rolling(500).std()

ax_all[1][0].set_xlabel('Frames')
ax_all[1][0].set_ylabel('Entropy')
clrs = sns.color_palette("husl", 8)

# fill standard deviation
ax_all[1][0].plot(df['Frames'], sma_y, label='Entropy', c=clrs[0])
ax_all[1][0].fill_between(df['Frames'], sma_y-std_y,  sma_y+std_y, 
                alpha=0.3, facecolor=clrs[0])

# make x axis nice
xlabels = [f'{int(x)}M' for x in ax_all[1][0].get_xticks()/1e6]
ax_all[1][0].set_xticklabels(xlabels)


## LOSS 
df = pd.DataFrame(logger.log['loss'], columns =['Frames', 'Iters', 'Loss'])
sma_y = df['Loss'].rolling(500).mean()
std_y = df['Loss'].rolling(500).std()

ax_all[1][1].set_xlabel('Frames')
ax_all[1][1].set_ylabel('Loss')
ax_all[1][1].yaxis.tick_right()
clrs = sns.color_palette("husl", 8)

# fill standard deviation
ax_all[1][1].plot(df['Frames'], sma_y, label='Loss', c=clrs[0])
ax_all[1][1].fill_between(df['Frames'], sma_y-std_y,  sma_y+std_y, 
                alpha=0.3, facecolor=clrs[0])

# make x axis nice
xlabels = [f'{int(x)}M' for x in ax_all[1][1].get_xticks()/1e6]
ax_all[1][1].set_xticklabels(xlabels)

plt.savefig(SAVE_PATH+ENV_NAME+'_plot_thesis.png', 
            dpi=300, pad_inches=0, bbox_inches = 'tight')

plt.show()

# %% [markdown]
# # Save log for comparisons

# %%
import pickle
log = T.load('FINAL.'+ENV_NAME+'.checkpoint', map_location=T.device('cpu'))['logger'].log
pickle.dump(log, open('FINAL.'+ENV_NAME+'.log', 'wb'))
